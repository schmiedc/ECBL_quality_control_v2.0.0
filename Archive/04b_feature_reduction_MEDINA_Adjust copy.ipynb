# %%
import time
from datetime import date
import pandas as pd
import os
import glob
import pycytominer
import sys
import CBE_utils as CBE
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import gc
from pathlib import Path

# %%
import importlib
importlib.reload(CBE)
# Out:
# <module 'CBE_utils' from '/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/notebooks_revision/CBE_utils.py'>

# %%
input_path = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/output/"

annotation_dir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/annotation/"

# %%
# get folder list 
# load for each site the normalized files
# reduce the features selecting the correct feature list
folders = [name for name in os.listdir(input_path) if os.path.isdir(os.path.join(input_path, name))]

# %%
def extract_plate_info(path): 
     
    match = re.search(r'(\d{4}-\d{2}-\d{2}_[A-Za-z0-9]+_R\d)', path)
    full_id = match.group(1) if match else None

    # Extract the date string (e.g., 2024-06-05)
    date_match = re.search(r'(\d{4}-\d{2}-\d{2})', full_id) if full_id else None
    batch = date_match.group(1) if date_match else None

    id_match  = re.search(r'_([A-Za-z0-9]+)_R(\d)', full_id) if full_id else None
    plate = id_match.group(1) if id_match else None
    replicate = id_match.group(2) if id_match else None

    return {
        "path": path,
        "full_id": full_id,
        "batch": batch,
        "plate": plate,
        "replicate": f"R{replicate}" if replicate else None
    }

# %%
site_specific_path = os.path.join(input_path, 'MEDINA')

# loads mad_robustize normalized data
pattern = "[A-Z][0-9][0-9][0-9][0-9]_R[1-4]_mad_robustize.csv"
file_list = glob.glob(site_specific_path + os.sep + '*' + os.sep + pattern, recursive=True)

files = [extract_plate_info(path) for path in file_list]

file_dataframe = pd.DataFrame(files)

file_dataframe['plate_replicate'] = file_dataframe['plate'] + '_' + file_dataframe['replicate']

# %%
file_dataframe['batch'].unique
# Out:
# <bound method Series.unique of 0      2024-10-24
# 1      2024-12-18
# 2      2025-04-24
# 3      2024-12-18
# 4      2024-12-18
#           ...
# 299    2024-10-30
# 300    2024-09-20
# 301    2024-07-18
# 302    2024-09-11
# 303    2024-10-25
# Name: batch, Length: 304, dtype: object>

# %%
# Count occurrences per date
date_counts = file_dataframe['batch'].value_counts().reset_index()
date_counts.columns = ['date', 'count']
date_counts = date_counts.sort_values('date')

# Plot using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(data=date_counts, x='date', y='count', color='skyblue')
plt.title('Data Occurrence by Date')
plt.xlabel('Date')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# compute new feature set for each site using correlation based feature redcution
def reduced_features(dataset_to_reduce, name_pre_fix, site_name ):

    reduced_feature_dataframe = CBE.feature_reduction(dataset_to_reduce,
                                             variance_freq_cut=0.1,
                                             variance_unique_cut=0.1,
                                             outlier_cutoff=100,
                                             corr_threshold = 0.9,
                                             print_stats = True)

    filename_norm_reduced_features = site_name + "_" + name_pre_fix + "_reduced_features.csv"

    file_path_norm_reduced_features = os.path.join(site_specific_path, filename_norm_reduced_features)
    
    reduced_feature_dataframe.to_csv(file_path_norm_reduced_features, index=False)
    
    return CBE.get_feature_vector(reduced_feature_dataframe)

# %%
Data = []

site_specific_path = os.path.join(input_path, "MEDINA")


# loads mad_robustize normalized data
pattern = "[A-Z]*_R[1-4]_mad_robustize.csv"
file_list = glob.glob(site_specific_path + os.sep + '*' + os.sep + pattern, recursive=True)

files = [extract_plate_info(path) for path in file_list]

file_dataframe = pd.DataFrame(files)

file_dataframe['plate_replicate'] = file_dataframe['plate'] + '_' + file_dataframe['replicate']

# %%
# Split MEDINA dataset from 2025-04-23
file_dataframe['date'] = pd.to_datetime(file_dataframe['batch'])
cutoff_date = pd.Timestamp('2025-01-23')

file_dataframe_first_run = file_dataframe[file_dataframe['date'] < cutoff_date ]
file_dataframe_repeats = file_dataframe[file_dataframe['date'] >= cutoff_date ]

# %%
def concatenate_data(file_list):

    for file in file_list:
        
        plate_map_name = os.path.splitext(os.path.basename(file))[0]
        
        try:
            dataframe = pd.read_csv(file)
            row_count = dataframe.shape[0]

            Data.append(dataframe)
        
            print(f"INFO: {plate_map_name} has {row_count} rows")
        
        except Exception as e:
        
            print(f"Error reading file {file}: {e}")

    Data_aggregated = pd.concat(Data)
    Data_aggregated = Data_aggregated.reset_index(drop = True)

    return Data_aggregated

# %%
file_firstrun_list = file_dataframe_first_run['path'].tolist()
file_firstrun_aggregate = concatenate_data(file_firstrun_list)
MEDINA_firstrun_feature_set = reduced_features(file_firstrun_aggregate , 'firstrun', 'MEDINA')
len(MEDINA_firstrun_feature_set)

# %%
# Apply feature reduction to repeats
file_repeats_list = file_dataframe_repeats['path'].tolist()
file_repeats_aggregate = concatenate_data(file_repeats_list)
MEDINA_repeats_feature_set = reduced_features(file_repeats_aggregate , 'repeats', 'MEDINA')
len(MEDINA_repeats_feature_set)

# %%
# Split MEDINA dataset from 2025-04-23
file_dataframe['date'] = pd.to_datetime(file_dataframe['batch'])
cutoff_date = pd.Timestamp('2025-04-23')

file_dataframe_repeats = file_dataframe[file_dataframe['date'] >= cutoff_date ]

test_file_list = file_dataframe_repeats['path'].tolist()

test_aggregate = concatenate_data(test_file_list)
test_feature_set = reduced_features(test_aggregate , 'repeats', 'MEDINA')
len(test_feature_set)

# %%
# Remove batches MEDINA
remove_batch = ['2025-01-23', 
                '2025-02-05', 
                '2024-02-12']

remove_batch_df = pd.to_datetime(remove_batch)
file_dataframe['date'] = pd.to_datetime(file_dataframe['batch'])
file_dataframe_corrected = file_dataframe[~file_dataframe['date'].isin(remove_batch_df)]

# %%
file_firstrun_list = file_dataframe_corrected['path'].tolist()
file_firstrun_aggregate = concatenate_data(file_firstrun_list)
MEDINA_firstrun_feature_set = reduced_features(file_firstrun_aggregate , 'firstrun', 'MEDINA')
len(MEDINA_firstrun_feature_set)
# Out:
# INFO: C1041_R3_mad_robustize has 384 rows
# INFO: C1063_R2_mad_robustize has 384 rows
# INFO: C1080_R2_mad_robustize has 384 rows
# INFO: C1065_R2_mad_robustize has 384 rows
# INFO: C1069_R2_mad_robustize has 384 rows
# INFO: C1030_R4_mad_robustize has 384 rows
# INFO: C1060_R3_mad_robustize has 384 rows
# INFO: C1077_R2_mad_robustize has 384 rows
# INFO: C1023_R3_mad_robustize has 384 rows
# INFO: C1059_R2_mad_robustize has 384 rows
# INFO: C1029_R3_mad_robustize has 384 rows
# INFO: MED02_R1_mad_robustize has 384 rows
# INFO: C1020_R3_mad_robustize has 384 rows
# INFO: C1062_R2_mad_robustize has 384 rows
# INFO: C1011_R4_mad_robustize has 384 rows
# INFO: C1031_R3_mad_robustize has 384 rows
# INFO: C1074_R3_mad_robustize has 384 rows
# INFO: C1045_R3_mad_robustize has 384 rows
# INFO: C1072_R2_mad_robustize has 384 rows
# INFO: C1024_R3_mad_robustize has 384 rows
# INFO: C1062_R3_mad_robustize has 384 rows
# INFO: C1071_R2_mad_robustize has 384 rows
# INFO: C1059_R4_mad_robustize has 384 rows
# INFO: C1038_R2_mad_robustize has 384 rows
# INFO: C1013_R1_mad_robustize has 384 rows
# INFO: C1022_R2_mad_robustize has 384 rows
# INFO: C1032_R1_mad_robustize has 384 rows
# INFO: C1029_R4_mad_robustize has 384 rows
# INFO: C1024_R4_mad_robustize has 384 rows
# INFO: C1012_R4_mad_robustize has 384 rows
# INFO: C1049_R2_mad_robustize has 384 rows
# INFO: C1081_R3_mad_robustize has 384 rows
# INFO: C1025_R4_mad_robustize has 384 rows
# INFO: C1068_R2_mad_robustize has 384 rows
# INFO: C1052_R1_mad_robustize has 384 rows
# INFO: C1019_R3_mad_robustize has 384 rows
# INFO: C1027_R3_mad_robustize has 384 rows
# INFO: C1015_R1_mad_robustize has 384 rows
# INFO: C1080_R3_mad_robustize has 384 rows
# INFO: C1030_R3_mad_robustize has 384 rows
# INFO: C1022_R4_mad_robustize has 383 rows
# INFO: C1058_R3_mad_robustize has 384 rows
# INFO: C1028_R3_mad_robustize has 384 rows
# INFO: C1021_R3_mad_robustize has 384 rows
# INFO: C1038_R4_mad_robustize has 384 rows
# INFO: C1036_R4_mad_robustize has 384 rows
# INFO: C1071_R1_mad_robustize has 384 rows
# INFO: C1023_R2_mad_robustize has 384 rows
# INFO: C1030_R2_mad_robustize has 384 rows
# INFO: C1034_R1_mad_robustize has 384 rows
# INFO: C1063_R1_mad_robustize has 384 rows
# INFO: C1031_R1_mad_robustize has 384 rows
# INFO: C1083_R4_mad_robustize has 384 rows
# INFO: C1045_R4_mad_robustize has 384 rows
# INFO: C1055_R1_mad_robustize has 384 rows
# INFO: C1051_R4_mad_robustize has 384 rows
# INFO: C1053_R4_mad_robustize has 384 rows
# INFO: C1064_R2_mad_robustize has 384 rows
# INFO: C1015_R2_mad_robustize has 384 rows
# INFO: C1050_R4_mad_robustize has 384 rows
# INFO: C1011_R2_mad_robustize has 384 rows
# INFO: C1045_R2_mad_robustize has 384 rows
# INFO: C1041_R2_mad_robustize has 384 rows
# INFO: C1074_R4_mad_robustize has 384 rows
# INFO: C1013_R3_mad_robustize has 384 rows
# INFO: C1013_R4_mad_robustize has 384 rows
# INFO: C1050_R1_mad_robustize has 384 rows
# INFO: C1083_R1_mad_robustize has 384 rows
# INFO: C1057_R4_mad_robustize has 384 rows
# INFO: C1075_R3_mad_robustize has 384 rows
# INFO: C1015_R4_mad_robustize has 384 rows
# INFO: C1033_R1_mad_robustize has 384 rows
# INFO: C1048_R2_mad_robustize has 384 rows
# INFO: C1022_R3_mad_robustize has 384 rows
# INFO: C1055_R2_mad_robustize has 384 rows
# INFO: C1047_R1_mad_robustize has 384 rows
# INFO: C1072_R3_mad_robustize has 384 rows
# INFO: C1082_R4_mad_robustize has 384 rows
# INFO: C1014_R1_mad_robustize has 378 rows
# INFO: C1069_R3_mad_robustize has 384 rows
# INFO: C1051_R1_mad_robustize has 384 rows
# INFO: C1044_R4_mad_robustize has 384 rows
# INFO: C1043_R1_mad_robustize has 384 rows
# INFO: C1082_R1_mad_robustize has 384 rows
# INFO: C1045_R1_mad_robustize has 384 rows
# INFO: C1025_R3_mad_robustize has 384 rows
# INFO: C1071_R3_mad_robustize has 384 rows
# INFO: C1017_R3_mad_robustize has 384 rows
# INFO: C1041_R3_mad_robustize has 384 rows
# INFO: C1078_R4_mad_robustize has 384 rows
# INFO: C1021_R2_mad_robustize has 384 rows
# INFO: C1011_R3_mad_robustize has 384 rows
# INFO: C1055_R4_mad_robustize has 384 rows
# INFO: C1075_R1_mad_robustize has 384 rows
# INFO: C1031_R4_mad_robustize has 384 rows
# INFO: C1064_R3_mad_robustize has 384 rows
# INFO: C1069_R1_mad_robustize has 384 rows
# INFO: C1046_R4_mad_robustize has 384 rows
# INFO: C1059_R1_mad_robustize has 384 rows
# INFO: C1054_R3_mad_robustize has 384 rows
# INFO: C1041_R4_mad_robustize has 384 rows
# INFO: C1044_R2_mad_robustize has 383 rows
# INFO: C1078_R2_mad_robustize has 384 rows
# INFO: C1022_R1_mad_robustize has 384 rows
# INFO: C1049_R3_mad_robustize has 384 rows
# INFO: C1058_R2_mad_robustize has 384 rows
# INFO: C1063_R3_mad_robustize has 384 rows
# INFO: C1054_R1_mad_robustize has 384 rows
# INFO: C1066_R3_mad_robustize has 384 rows
# INFO: C1029_R1_mad_robustize has 384 rows
# INFO: C1018_R2_mad_robustize has 384 rows
# INFO: C1058_R4_mad_robustize has 384 rows
# INFO: C1034_R4_mad_robustize has 384 rows
# INFO: C1028_R2_mad_robustize has 384 rows
# INFO: C1027_R4_mad_robustize has 384 rows
# INFO: C1073_R4_mad_robustize has 384 rows
# INFO: C1055_R3_mad_robustize has 384 rows
# INFO: C1066_R1_mad_robustize has 384 rows
# INFO: C1040_R1_mad_robustize has 384 rows
# INFO: C1028_R1_mad_robustize has 384 rows
# INFO: C1035_R3_mad_robustize has 384 rows
# INFO: C1043_R2_mad_robustize has 384 rows
# INFO: C1072_R1_mad_robustize has 384 rows
# INFO: C1012_R2_mad_robustize has 384 rows
# INFO: C1039_R3_mad_robustize has 384 rows
# INFO: C1068_R1_mad_robustize has 384 rows
# INFO: C1017_R2_mad_robustize has 384 rows
# INFO: C1042_R3_mad_robustize has 384 rows
# INFO: C1052_R4_mad_robustize has 384 rows
# INFO: C1043_R4_mad_robustize has 384 rows
# INFO: C1077_R4_mad_robustize has 384 rows
# INFO: C1071_R4_mad_robustize has 384 rows
# INFO: C1021_R1_mad_robustize has 384 rows
# INFO: C1058_R1_mad_robustize has 384 rows
# INFO: C1027_R2_mad_robustize has 384 rows
# INFO: C1039_R2_mad_robustize has 384 rows
# INFO: C1081_R4_mad_robustize has 384 rows
# INFO: C1061_R2_mad_robustize has 384 rows
# INFO: C1054_R2_mad_robustize has 384 rows
# INFO: C1056_R2_mad_robustize has 384 rows
# INFO: C1053_R2_mad_robustize has 384 rows
# INFO: C1048_R4_mad_robustize has 384 rows
# INFO: C1079_R2_mad_robustize has 384 rows
# INFO: C1054_R4_mad_robustize has 384 rows
# INFO: C1064_R4_mad_robustize has 384 rows
# INFO: C1057_R3_mad_robustize has 384 rows
# INFO: C1020_R2_mad_robustize has 384 rows
# INFO: C1024_R2_mad_robustize has 384 rows
# INFO: C1067_R3_mad_robustize has 384 rows
# INFO: C1046_R1_mad_robustize has 384 rows
# INFO: C1025_R1_mad_robustize has 384 rows
# INFO: C1039_R1_mad_robustize has 384 rows
# INFO: C1031_R4_mad_robustize has 384 rows
# INFO: C1053_R3_mad_robustize has 384 rows
# INFO: C1050_R3_mad_robustize has 384 rows
# INFO: C1046_R2_mad_robustize has 384 rows
# INFO: C1042_R2_mad_robustize has 384 rows
# INFO: C1018_R4_mad_robustize has 384 rows
# INFO: C1041_R1_mad_robustize has 384 rows
# INFO: C1076_R1_mad_robustize has 384 rows
# INFO: C1062_R1_mad_robustize has 384 rows
# INFO: C1037_R2_mad_robustize has 384 rows
# INFO: C1074_R2_mad_robustize has 384 rows
# INFO: C1060_R2_mad_robustize has 384 rows
# INFO: C1029_R2_mad_robustize has 384 rows
# INFO: C1026_R2_mad_robustize has 384 rows
# INFO: C1081_R2_mad_robustize has 384 rows
# INFO: C1047_R2_mad_robustize has 384 rows
# INFO: C1072_R2_mad_robustize has 384 rows
# INFO: C1056_R4_mad_robustize has 384 rows
# INFO: C1025_R2_mad_robustize has 384 rows
# INFO: C1014_R4_mad_robustize has 384 rows
# INFO: C1011_R1_mad_robustize has 384 rows
# INFO: C1046_R3_mad_robustize has 384 rows
# INFO: C1036_R3_mad_robustize has 384 rows
# INFO: C1082_R2_mad_robustize has 384 rows
# INFO: C1013_R2_mad_robustize has 384 rows
# INFO: C1031_R2_mad_robustize has 384 rows
# INFO: C1037_R1_mad_robustize has 384 rows
# INFO: C1060_R4_mad_robustize has 384 rows
# INFO: C1070_R1_mad_robustize has 384 rows
# INFO: C1019_R4_mad_robustize has 384 rows
# INFO: C1077_R3_mad_robustize has 384 rows
# INFO: C1012_R3_mad_robustize has 384 rows
# INFO: C1020_R1_mad_robustize has 384 rows
# INFO: C1031_R2_mad_robustize has 384 rows
# INFO: C1024_R3_mad_robustize has 384 rows
# INFO: C1014_R3_mad_robustize has 384 rows
# INFO: C1040_R3_mad_robustize has 384 rows
# INFO: C1064_R1_mad_robustize has 384 rows
# INFO: C1043_R3_mad_robustize has 384 rows
# INFO: C1081_R1_mad_robustize has 384 rows
# INFO: C1052_R2_mad_robustize has 384 rows
# INFO: C1039_R4_mad_robustize has 384 rows
# INFO: C1012_R1_mad_robustize has 384 rows
# INFO: C1014_R2_mad_robustize has 384 rows
# INFO: C1042_R1_mad_robustize has 384 rows
# INFO: C1074_R1_mad_robustize has 384 rows
# INFO: C1076_R3_mad_robustize has 384 rows
# INFO: C1078_R1_mad_robustize has 384 rows
# INFO: C1028_R4_mad_robustize has 384 rows
# INFO: C1035_R1_mad_robustize has 384 rows
# INFO: C1051_R2_mad_robustize has 384 rows
# INFO: C1073_R2_mad_robustize has 384 rows
# INFO: C1076_R4_mad_robustize has 384 rows
# INFO: C1016_R4_mad_robustize has 384 rows
# INFO: C1018_R1_mad_robustize has 384 rows
# INFO: C1021_R4_mad_robustize has 384 rows
# INFO: C1080_R4_mad_robustize has 384 rows
# INFO: C1083_R3_mad_robustize has 384 rows
# INFO: C1059_R3_mad_robustize has 384 rows
# INFO: C1068_R3_mad_robustize has 384 rows
# INFO: C1080_R1_mad_robustize has 384 rows
# INFO: C1016_R1_mad_robustize has 384 rows
# INFO: C1060_R1_mad_robustize has 384 rows
# INFO: C1020_R4_mad_robustize has 384 rows
# INFO: C1075_R2_mad_robustize has 384 rows
# INFO: C1042_R4_mad_robustize has 384 rows
# INFO: C1067_R1_mad_robustize has 384 rows
# INFO: C1019_R1_mad_robustize has 384 rows
# INFO: C1032_R2_mad_robustize has 384 rows
# INFO: C1047_R3_mad_robustize has 384 rows
# INFO: C1035_R4_mad_robustize has 384 rows
# INFO: C1076_R2_mad_robustize has 384 rows
# INFO: C1026_R3_mad_robustize has 384 rows
# INFO: C1073_R3_mad_robustize has 384 rows
# INFO: C1026_R4_mad_robustize has 384 rows
# INFO: C1072_R4_mad_robustize has 384 rows
# INFO: C1065_R3_mad_robustize has 384 rows
# INFO: C1013_R1_mad_robustize has 384 rows
# INFO: C1040_R2_mad_robustize has 384 rows
# INFO: C1037_R4_mad_robustize has 384 rows
# INFO: C1070_R3_mad_robustize has 384 rows
# INFO: C1016_R2_mad_robustize has 384 rows
# INFO: C1036_R1_mad_robustize has 384 rows
# INFO: C1023_R1_mad_robustize has 384 rows
# INFO: C1032_R3_mad_robustize has 384 rows
# INFO: C1024_R1_mad_robustize has 311 rows
# INFO: C1033_R3_mad_robustize has 384 rows
# INFO: MED03_R1_mad_robustize has 384 rows
# INFO: C1051_R3_mad_robustize has 384 rows
# INFO: C1070_R2_mad_robustize has 384 rows
# INFO: C1053_R1_mad_robustize has 384 rows
# INFO: C1057_R1_mad_robustize has 384 rows
# INFO: C1034_R3_mad_robustize has 384 rows
# INFO: C1049_R1_mad_robustize has 384 rows
# INFO: C1065_R1_mad_robustize has 384 rows
# INFO: C1047_R4_mad_robustize has 384 rows
# INFO: C1017_R1_mad_robustize has 384 rows
# INFO: C1061_R1_mad_robustize has 384 rows
# INFO: C1048_R1_mad_robustize has 384 rows
# INFO: C1038_R1_mad_robustize has 384 rows
# INFO: C1056_R3_mad_robustize has 384 rows
# INFO: C1082_R3_mad_robustize has 384 rows
# INFO: C1075_R4_mad_robustize has 384 rows
# INFO: C1066_R2_mad_robustize has 384 rows
# INFO: C1048_R3_mad_robustize has 384 rows
# INFO: C1050_R2_mad_robustize has 384 rows
# INFO: C1081_R3_mad_robustize has 384 rows
# INFO: C1033_R2_mad_robustize has 384 rows
# INFO: C1073_R1_mad_robustize has 384 rows
# INFO: C1026_R3_mad_robustize has 384 rows
# INFO: C1052_R3_mad_robustize has 384 rows
# INFO: C1018_R3_mad_robustize has 384 rows
# INFO: C1033_R4_mad_robustize has 384 rows
# INFO: C1037_R3_mad_robustize has 384 rows
# INFO: C1016_R3_mad_robustize has 384 rows
# INFO: C1078_R3_mad_robustize has 384 rows
# INFO: C1044_R1_mad_robustize has 384 rows
# INFO: C1024_R1_mad_robustize has 384 rows
# INFO: C1023_R4_mad_robustize has 384 rows
# INFO: C1038_R3_mad_robustize has 384 rows
# INFO: C1032_R4_mad_robustize has 384 rows
# INFO: C1032_R1_mad_robustize has 384 rows
# INFO: C1034_R2_mad_robustize has 384 rows
# INFO: C1079_R1_mad_robustize has 384 rows
# INFO: C1036_R2_mad_robustize has 384 rows
# INFO: C1079_R3_mad_robustize has 384 rows
# INFO: C1017_R4_mad_robustize has 384 rows
# INFO: C1044_R3_mad_robustize has 384 rows
# INFO: C1026_R1_mad_robustize has 384 rows
# INFO: C1040_R4_mad_robustize has 384 rows
# INFO: C1077_R1_mad_robustize has 384 rows
# INFO: C1079_R4_mad_robustize has 384 rows
# INFO: C1061_R2_mad_robustize has 384 rows
# INFO: C1061_R3_mad_robustize has 384 rows
# INFO: C1057_R2_mad_robustize has 384 rows
# INFO: C1056_R1_mad_robustize has 384 rows
# INFO: C1030_R1_mad_robustize has 384 rows
# INFO: C1067_R2_mad_robustize has 384 rows
# INFO: C1015_R3_mad_robustize has 384 rows
# INFO: C1035_R2_mad_robustize has 384 rows
# INFO: C1019_R2_mad_robustize has 384 rows
# INFO: C1027_R1_mad_robustize has 384 rows
# INFO: C1049_R4_mad_robustize has 384 rows
# | Category           |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:-------------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features     |                2977 |                 2804 |         94.2 |                2120 |        71.2 |                     601 |            20.2 |
# | Intensity          |                 180 |                  180 |        100   |                 166 |        92.2 |                      31 |            17.2 |
# | Correlation        |                 180 |                  115 |         63.9 |                  91 |        50.6 |                      66 |            36.7 |
# | AreaShape          |                 162 |                  151 |         93.2 |                 127 |        78.4 |                     108 |            66.7 |
# | Granularity        |                 192 |                  192 |        100   |                 151 |        78.6 |                      64 |            33.3 |
# | Neighbors          |                  21 |                   12 |         57.1 |                   6 |        28.6 |                       4 |            19   |
# | RadialDistribution |                 366 |                  281 |         76.8 |                 271 |        74   |                     169 |            46.2 |
# | Texture            |                1872 |                 1872 |        100   |                1308 |        69.9 |                     159 |             8.5 |
# | MitoSkeleton       |                   4 |                    1 |         25   |                   0 |         0   |                       0 |             0   |
#
# | Category       |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:---------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features |                2977 |                 2804 |         94.2 |                2120 |        71.2 |                     601 |            20.2 |
# | Nucleus        |                 921 |                  886 |         96.2 |                 655 |        71.1 |                     171 |            18.6 |
# | Cell           |                1035 |                  998 |         96.4 |                 741 |        71.6 |                     196 |            18.9 |
# | Cytoplasm      |                1021 |                  920 |         90.1 |                 724 |        70.9 |                     234 |            22.9 |
# 601

# %%
def apply_reduction(reduced_feature_set, site_name):
    
    dataframes_normalized_reduced_dict = {}

    site_specific_path = os.path.join(input_path, site_name)

    pattern = "[A-Z][0-9][0-9][0-9][0-9]_R[1-4]_mad_robustize.csv"
    file_list = glob.glob(site_specific_path + os.sep + '*' + os.sep + pattern, recursive=True)

    for file in file_list:
    
        plate_map_name = os.path.splitext(os.path.basename(file))[0]
    
        try:
        
            dataframe = pd.read_csv(file)
            row_count = dataframe.shape[0]
        
            print(f"INFO: {plate_map_name} has {row_count} rows")

            features = CBE.get_feature_vector(dataframe)
            metadata = set(dataframe.columns) - set(features)

            number_features = len(features)

            print(f"INFO: {plate_map_name} has {number_features} features")

            features_to_remove = [item for item in features if item not in reduced_feature_set]
    
            dataframe_reduced_features = dataframe.drop(columns = features_to_remove)

            reduced_features = CBE.get_feature_vector(dataframe_reduced_features)

            number_reduced_features = len(reduced_features)

            print(f"INFO: {plate_map_name} has {number_reduced_features} features after feature reduction")
    
            filename_norm_reduced_data = plate_map_name + "_reduced-corr.csv"
    
            path_norm_reduced_data = os.path.dirname(file)
            file_path_norm_reduced_data = os.path.join(path_norm_reduced_data, filename_norm_reduced_data)
    
            dataframe_reduced_features.to_csv(file_path_norm_reduced_data, index=False)
    
            print(f"INFO: Saved {filename_norm_reduced_data}")

            # dict_key = dataframe_reduced_features['Metadata_staining_date'][0].astype(str) + "_" + dataframe_reduced_features['Metadata_source'][0] + "_" + dataframe_reduced_features['Metadata_plate_map_name'][0]

            # dataframes_normalized_reduced_dict[dict_key] = dataframe_reduced_features
        
        except Exception as e:
        
            print(f"Error reading file {plate_map_name}: {e}")

# %%
apply_reduction(MEDINA_firstrun_feature_set, 'MEDINA')
# Out:
# INFO: C1041_R3_mad_robustize has 384 rows
# INFO: C1041_R3_mad_robustize has 2977 features
# INFO: C1041_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1041_R3_mad_robustize_reduced-corr.csv
# INFO: C1063_R2_mad_robustize has 384 rows
# INFO: C1063_R2_mad_robustize has 2977 features
# INFO: C1063_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1063_R2_mad_robustize_reduced-corr.csv
# INFO: C1080_R2_mad_robustize has 384 rows
# INFO: C1080_R2_mad_robustize has 2977 features
# INFO: C1080_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1080_R2_mad_robustize_reduced-corr.csv
# INFO: C1065_R2_mad_robustize has 384 rows
# INFO: C1065_R2_mad_robustize has 2977 features
# INFO: C1065_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1065_R2_mad_robustize_reduced-corr.csv
# INFO: C1069_R2_mad_robustize has 384 rows
# INFO: C1069_R2_mad_robustize has 2977 features
# INFO: C1069_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1069_R2_mad_robustize_reduced-corr.csv
# INFO: C1030_R4_mad_robustize has 384 rows
# INFO: C1030_R4_mad_robustize has 2977 features
# INFO: C1030_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1030_R4_mad_robustize_reduced-corr.csv
# INFO: C1060_R3_mad_robustize has 384 rows
# INFO: C1060_R3_mad_robustize has 2977 features
# INFO: C1060_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1060_R3_mad_robustize_reduced-corr.csv
# INFO: C1077_R2_mad_robustize has 384 rows
# INFO: C1077_R2_mad_robustize has 2977 features
# INFO: C1077_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1077_R2_mad_robustize_reduced-corr.csv
# INFO: C1023_R3_mad_robustize has 384 rows
# INFO: C1023_R3_mad_robustize has 2977 features
# INFO: C1023_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1023_R3_mad_robustize_reduced-corr.csv
# INFO: C1062_R4_mad_robustize has 384 rows
# INFO: C1062_R4_mad_robustize has 2977 features
# INFO: C1062_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1062_R4_mad_robustize_reduced-corr.csv
# INFO: C1059_R2_mad_robustize has 384 rows
# INFO: C1059_R2_mad_robustize has 2977 features
# INFO: C1059_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1059_R2_mad_robustize_reduced-corr.csv
# INFO: C1029_R3_mad_robustize has 384 rows
# INFO: C1029_R3_mad_robustize has 2977 features
# INFO: C1029_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1029_R3_mad_robustize_reduced-corr.csv
# INFO: C1020_R3_mad_robustize has 384 rows
# INFO: C1020_R3_mad_robustize has 2977 features
# INFO: C1020_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1020_R3_mad_robustize_reduced-corr.csv
# INFO: C1062_R2_mad_robustize has 384 rows
# INFO: C1062_R2_mad_robustize has 2977 features
# INFO: C1062_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1062_R2_mad_robustize_reduced-corr.csv
# INFO: C1011_R4_mad_robustize has 384 rows
# INFO: C1011_R4_mad_robustize has 2977 features
# INFO: C1011_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1011_R4_mad_robustize_reduced-corr.csv
# INFO: C1031_R3_mad_robustize has 384 rows
# INFO: C1031_R3_mad_robustize has 2977 features
# INFO: C1031_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1031_R3_mad_robustize_reduced-corr.csv
# INFO: C1074_R3_mad_robustize has 384 rows
# INFO: C1074_R3_mad_robustize has 2977 features
# INFO: C1074_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1074_R3_mad_robustize_reduced-corr.csv
# INFO: C1045_R3_mad_robustize has 384 rows
# INFO: C1045_R3_mad_robustize has 2977 features
# INFO: C1045_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1045_R3_mad_robustize_reduced-corr.csv
# INFO: C1072_R2_mad_robustize has 384 rows
# INFO: C1072_R2_mad_robustize has 2977 features
# INFO: C1072_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1072_R2_mad_robustize_reduced-corr.csv
# INFO: C1024_R3_mad_robustize has 384 rows
# INFO: C1024_R3_mad_robustize has 2977 features
# INFO: C1024_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1024_R3_mad_robustize_reduced-corr.csv
# INFO: C1062_R3_mad_robustize has 384 rows
# INFO: C1062_R3_mad_robustize has 2977 features
# INFO: C1062_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1062_R3_mad_robustize_reduced-corr.csv
# INFO: C1071_R2_mad_robustize has 384 rows
# INFO: C1071_R2_mad_robustize has 2977 features
# INFO: C1071_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1071_R2_mad_robustize_reduced-corr.csv
# INFO: C1059_R4_mad_robustize has 384 rows
# INFO: C1059_R4_mad_robustize has 2977 features
# INFO: C1059_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1059_R4_mad_robustize_reduced-corr.csv
# INFO: C1038_R2_mad_robustize has 384 rows
# INFO: C1038_R2_mad_robustize has 2977 features
# INFO: C1038_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1038_R2_mad_robustize_reduced-corr.csv
# INFO: C1013_R1_mad_robustize has 384 rows
# INFO: C1013_R1_mad_robustize has 2977 features
# INFO: C1013_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1013_R1_mad_robustize_reduced-corr.csv
# INFO: C1022_R2_mad_robustize has 384 rows
# INFO: C1022_R2_mad_robustize has 2977 features
# INFO: C1022_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1022_R2_mad_robustize_reduced-corr.csv
# INFO: C1032_R1_mad_robustize has 384 rows
# INFO: C1032_R1_mad_robustize has 2977 features
# INFO: C1032_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1032_R1_mad_robustize_reduced-corr.csv
# INFO: C1029_R4_mad_robustize has 384 rows
# INFO: C1029_R4_mad_robustize has 2977 features
# INFO: C1029_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1029_R4_mad_robustize_reduced-corr.csv
# INFO: C1024_R4_mad_robustize has 384 rows
# INFO: C1024_R4_mad_robustize has 2977 features
# INFO: C1024_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1024_R4_mad_robustize_reduced-corr.csv
# INFO: C1012_R4_mad_robustize has 384 rows
# INFO: C1012_R4_mad_robustize has 2977 features
# INFO: C1012_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1012_R4_mad_robustize_reduced-corr.csv
# INFO: C1049_R2_mad_robustize has 384 rows
# INFO: C1049_R2_mad_robustize has 2977 features
# INFO: C1049_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1049_R2_mad_robustize_reduced-corr.csv
# INFO: C1081_R3_mad_robustize has 384 rows
# INFO: C1081_R3_mad_robustize has 2977 features
# INFO: C1081_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1081_R3_mad_robustize_reduced-corr.csv
# INFO: C1025_R4_mad_robustize has 384 rows
# INFO: C1025_R4_mad_robustize has 2977 features
# INFO: C1025_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1025_R4_mad_robustize_reduced-corr.csv
# INFO: C1068_R2_mad_robustize has 384 rows
# INFO: C1068_R2_mad_robustize has 2977 features
# INFO: C1068_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1068_R2_mad_robustize_reduced-corr.csv
# INFO: C1052_R1_mad_robustize has 384 rows
# INFO: C1052_R1_mad_robustize has 2977 features
# INFO: C1052_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1052_R1_mad_robustize_reduced-corr.csv
# INFO: C1019_R3_mad_robustize has 384 rows
# INFO: C1019_R3_mad_robustize has 2977 features
# INFO: C1019_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1019_R3_mad_robustize_reduced-corr.csv
# INFO: C1027_R3_mad_robustize has 384 rows
# INFO: C1027_R3_mad_robustize has 2977 features
# INFO: C1027_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1027_R3_mad_robustize_reduced-corr.csv
# INFO: C1015_R1_mad_robustize has 384 rows
# INFO: C1015_R1_mad_robustize has 2977 features
# INFO: C1015_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1015_R1_mad_robustize_reduced-corr.csv
# INFO: C1080_R3_mad_robustize has 384 rows
# INFO: C1080_R3_mad_robustize has 2977 features
# INFO: C1080_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1080_R3_mad_robustize_reduced-corr.csv
# INFO: C1030_R3_mad_robustize has 384 rows
# INFO: C1030_R3_mad_robustize has 2977 features
# INFO: C1030_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1030_R3_mad_robustize_reduced-corr.csv
# INFO: C1022_R4_mad_robustize has 383 rows
# INFO: C1022_R4_mad_robustize has 2977 features
# INFO: C1022_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1022_R4_mad_robustize_reduced-corr.csv
# INFO: C1058_R3_mad_robustize has 384 rows
# INFO: C1058_R3_mad_robustize has 2977 features
# INFO: C1058_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1058_R3_mad_robustize_reduced-corr.csv
# INFO: C1028_R3_mad_robustize has 384 rows
# INFO: C1028_R3_mad_robustize has 2977 features
# INFO: C1028_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1028_R3_mad_robustize_reduced-corr.csv
# INFO: C1021_R3_mad_robustize has 384 rows
# INFO: C1021_R3_mad_robustize has 2977 features
# INFO: C1021_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1021_R3_mad_robustize_reduced-corr.csv
# INFO: C1038_R4_mad_robustize has 384 rows
# INFO: C1038_R4_mad_robustize has 2977 features
# INFO: C1038_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1038_R4_mad_robustize_reduced-corr.csv
# INFO: C1036_R4_mad_robustize has 384 rows
# INFO: C1036_R4_mad_robustize has 2977 features
# INFO: C1036_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1036_R4_mad_robustize_reduced-corr.csv
# INFO: C1071_R1_mad_robustize has 384 rows
# INFO: C1071_R1_mad_robustize has 2977 features
# INFO: C1071_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1071_R1_mad_robustize_reduced-corr.csv
# INFO: C1023_R2_mad_robustize has 384 rows
# INFO: C1023_R2_mad_robustize has 2977 features
# INFO: C1023_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1023_R2_mad_robustize_reduced-corr.csv
# INFO: C1030_R2_mad_robustize has 384 rows
# INFO: C1030_R2_mad_robustize has 2977 features
# INFO: C1030_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1030_R2_mad_robustize_reduced-corr.csv
# INFO: C1034_R1_mad_robustize has 384 rows
# INFO: C1034_R1_mad_robustize has 2977 features
# INFO: C1034_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1034_R1_mad_robustize_reduced-corr.csv
# INFO: C1063_R1_mad_robustize has 384 rows
# INFO: C1063_R1_mad_robustize has 2977 features
# INFO: C1063_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1063_R1_mad_robustize_reduced-corr.csv
# INFO: C1031_R1_mad_robustize has 384 rows
# INFO: C1031_R1_mad_robustize has 2977 features
# INFO: C1031_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1031_R1_mad_robustize_reduced-corr.csv
# INFO: C1083_R4_mad_robustize has 384 rows
# INFO: C1083_R4_mad_robustize has 2977 features
# INFO: C1083_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1083_R4_mad_robustize_reduced-corr.csv
# INFO: C1045_R4_mad_robustize has 384 rows
# INFO: C1045_R4_mad_robustize has 2977 features
# INFO: C1045_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1045_R4_mad_robustize_reduced-corr.csv
# INFO: C1055_R1_mad_robustize has 384 rows
# INFO: C1055_R1_mad_robustize has 2977 features
# INFO: C1055_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1055_R1_mad_robustize_reduced-corr.csv
# INFO: C1051_R4_mad_robustize has 384 rows
# INFO: C1051_R4_mad_robustize has 2977 features
# INFO: C1051_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1051_R4_mad_robustize_reduced-corr.csv
# INFO: C1053_R4_mad_robustize has 384 rows
# INFO: C1053_R4_mad_robustize has 2977 features
# INFO: C1053_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1053_R4_mad_robustize_reduced-corr.csv
# INFO: C1064_R2_mad_robustize has 384 rows
# INFO: C1064_R2_mad_robustize has 2977 features
# INFO: C1064_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1064_R2_mad_robustize_reduced-corr.csv
# INFO: C1015_R2_mad_robustize has 384 rows
# INFO: C1015_R2_mad_robustize has 2977 features
# INFO: C1015_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1015_R2_mad_robustize_reduced-corr.csv
# INFO: C1050_R4_mad_robustize has 384 rows
# INFO: C1050_R4_mad_robustize has 2977 features
# INFO: C1050_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1050_R4_mad_robustize_reduced-corr.csv
# INFO: C1011_R2_mad_robustize has 384 rows
# INFO: C1011_R2_mad_robustize has 2977 features
# INFO: C1011_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1011_R2_mad_robustize_reduced-corr.csv
# INFO: C1045_R2_mad_robustize has 384 rows
# INFO: C1045_R2_mad_robustize has 2977 features
# INFO: C1045_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1045_R2_mad_robustize_reduced-corr.csv
# INFO: C1041_R2_mad_robustize has 384 rows
# INFO: C1041_R2_mad_robustize has 2977 features
# INFO: C1041_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1041_R2_mad_robustize_reduced-corr.csv
# INFO: C1074_R4_mad_robustize has 384 rows
# INFO: C1074_R4_mad_robustize has 2977 features
# INFO: C1074_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1074_R4_mad_robustize_reduced-corr.csv
# INFO: C1013_R3_mad_robustize has 384 rows
# INFO: C1013_R3_mad_robustize has 2977 features
# INFO: C1013_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1013_R3_mad_robustize_reduced-corr.csv
# INFO: C1013_R4_mad_robustize has 384 rows
# INFO: C1013_R4_mad_robustize has 2977 features
# INFO: C1013_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1013_R4_mad_robustize_reduced-corr.csv
# INFO: C1050_R1_mad_robustize has 384 rows
# INFO: C1050_R1_mad_robustize has 2977 features
# INFO: C1050_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1050_R1_mad_robustize_reduced-corr.csv
# INFO: C1083_R1_mad_robustize has 384 rows
# INFO: C1083_R1_mad_robustize has 2977 features
# INFO: C1083_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1083_R1_mad_robustize_reduced-corr.csv
# INFO: C1057_R4_mad_robustize has 384 rows
# INFO: C1057_R4_mad_robustize has 2977 features
# INFO: C1057_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1057_R4_mad_robustize_reduced-corr.csv
# INFO: C1075_R3_mad_robustize has 384 rows
# INFO: C1075_R3_mad_robustize has 2977 features
# INFO: C1075_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1075_R3_mad_robustize_reduced-corr.csv
# INFO: C1015_R4_mad_robustize has 384 rows
# INFO: C1015_R4_mad_robustize has 2977 features
# INFO: C1015_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1015_R4_mad_robustize_reduced-corr.csv
# INFO: C1033_R1_mad_robustize has 384 rows
# INFO: C1033_R1_mad_robustize has 2977 features
# INFO: C1033_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1033_R1_mad_robustize_reduced-corr.csv
# INFO: C1048_R2_mad_robustize has 384 rows
# INFO: C1048_R2_mad_robustize has 2977 features
# INFO: C1048_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1048_R2_mad_robustize_reduced-corr.csv
# INFO: C1022_R3_mad_robustize has 384 rows
# INFO: C1022_R3_mad_robustize has 2977 features
# INFO: C1022_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1022_R3_mad_robustize_reduced-corr.csv
# INFO: C1055_R2_mad_robustize has 384 rows
# INFO: C1055_R2_mad_robustize has 2977 features
# INFO: C1055_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1055_R2_mad_robustize_reduced-corr.csv
# INFO: C1047_R1_mad_robustize has 384 rows
# INFO: C1047_R1_mad_robustize has 2977 features
# INFO: C1047_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1047_R1_mad_robustize_reduced-corr.csv
# INFO: C1072_R3_mad_robustize has 384 rows
# INFO: C1072_R3_mad_robustize has 2977 features
# INFO: C1072_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1072_R3_mad_robustize_reduced-corr.csv
# INFO: C1082_R4_mad_robustize has 384 rows
# INFO: C1082_R4_mad_robustize has 2977 features
# INFO: C1082_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1082_R4_mad_robustize_reduced-corr.csv
# INFO: C1014_R1_mad_robustize has 378 rows
# INFO: C1014_R1_mad_robustize has 2977 features
# INFO: C1014_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1014_R1_mad_robustize_reduced-corr.csv
# INFO: C1069_R3_mad_robustize has 384 rows
# INFO: C1069_R3_mad_robustize has 2977 features
# INFO: C1069_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1069_R3_mad_robustize_reduced-corr.csv
# INFO: C1051_R1_mad_robustize has 384 rows
# INFO: C1051_R1_mad_robustize has 2977 features
# INFO: C1051_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1051_R1_mad_robustize_reduced-corr.csv
# INFO: C1044_R4_mad_robustize has 384 rows
# INFO: C1044_R4_mad_robustize has 2977 features
# INFO: C1044_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1044_R4_mad_robustize_reduced-corr.csv
# INFO: C1043_R1_mad_robustize has 384 rows
# INFO: C1043_R1_mad_robustize has 2977 features
# INFO: C1043_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1043_R1_mad_robustize_reduced-corr.csv
# INFO: C1082_R1_mad_robustize has 384 rows
# INFO: C1082_R1_mad_robustize has 2977 features
# INFO: C1082_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1082_R1_mad_robustize_reduced-corr.csv
# INFO: C1045_R1_mad_robustize has 384 rows
# INFO: C1045_R1_mad_robustize has 2977 features
# INFO: C1045_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1045_R1_mad_robustize_reduced-corr.csv
# INFO: C1025_R3_mad_robustize has 384 rows
# INFO: C1025_R3_mad_robustize has 2977 features
# INFO: C1025_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1025_R3_mad_robustize_reduced-corr.csv
# INFO: C1071_R3_mad_robustize has 384 rows
# INFO: C1071_R3_mad_robustize has 2977 features
# INFO: C1071_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1071_R3_mad_robustize_reduced-corr.csv
# INFO: C1017_R3_mad_robustize has 384 rows
# INFO: C1017_R3_mad_robustize has 2977 features
# INFO: C1017_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1017_R3_mad_robustize_reduced-corr.csv
# INFO: C1041_R3_mad_robustize has 384 rows
# INFO: C1041_R3_mad_robustize has 2977 features
# INFO: C1041_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1041_R3_mad_robustize_reduced-corr.csv
# INFO: C1078_R4_mad_robustize has 384 rows
# INFO: C1078_R4_mad_robustize has 2977 features
# INFO: C1078_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1078_R4_mad_robustize_reduced-corr.csv
# INFO: C1021_R2_mad_robustize has 384 rows
# INFO: C1021_R2_mad_robustize has 2977 features
# INFO: C1021_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1021_R2_mad_robustize_reduced-corr.csv
# INFO: C1011_R3_mad_robustize has 384 rows
# INFO: C1011_R3_mad_robustize has 2977 features
# INFO: C1011_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1011_R3_mad_robustize_reduced-corr.csv
# INFO: C1055_R4_mad_robustize has 384 rows
# INFO: C1055_R4_mad_robustize has 2977 features
# INFO: C1055_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1055_R4_mad_robustize_reduced-corr.csv
# INFO: C1075_R1_mad_robustize has 384 rows
# INFO: C1075_R1_mad_robustize has 2977 features
# INFO: C1075_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1075_R1_mad_robustize_reduced-corr.csv
# INFO: C1031_R4_mad_robustize has 384 rows
# INFO: C1031_R4_mad_robustize has 2977 features
# INFO: C1031_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1031_R4_mad_robustize_reduced-corr.csv
# INFO: C1064_R3_mad_robustize has 384 rows
# INFO: C1064_R3_mad_robustize has 2977 features
# INFO: C1064_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1064_R3_mad_robustize_reduced-corr.csv
# INFO: C1069_R1_mad_robustize has 384 rows
# INFO: C1069_R1_mad_robustize has 2977 features
# INFO: C1069_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1069_R1_mad_robustize_reduced-corr.csv
# INFO: C1046_R4_mad_robustize has 384 rows
# INFO: C1046_R4_mad_robustize has 2977 features
# INFO: C1046_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1046_R4_mad_robustize_reduced-corr.csv
# INFO: C1059_R1_mad_robustize has 384 rows
# INFO: C1059_R1_mad_robustize has 2977 features
# INFO: C1059_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1059_R1_mad_robustize_reduced-corr.csv
# INFO: C1054_R3_mad_robustize has 384 rows
# INFO: C1054_R3_mad_robustize has 2977 features
# INFO: C1054_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1054_R3_mad_robustize_reduced-corr.csv
# INFO: C1041_R4_mad_robustize has 384 rows
# INFO: C1041_R4_mad_robustize has 2977 features
# INFO: C1041_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1041_R4_mad_robustize_reduced-corr.csv
# INFO: C1044_R2_mad_robustize has 383 rows
# INFO: C1044_R2_mad_robustize has 2977 features
# INFO: C1044_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1044_R2_mad_robustize_reduced-corr.csv
# INFO: C1078_R2_mad_robustize has 384 rows
# INFO: C1078_R2_mad_robustize has 2977 features
# INFO: C1078_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1078_R2_mad_robustize_reduced-corr.csv
# INFO: C1022_R1_mad_robustize has 384 rows
# INFO: C1022_R1_mad_robustize has 2977 features
# INFO: C1022_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1022_R1_mad_robustize_reduced-corr.csv
# INFO: C1049_R3_mad_robustize has 384 rows
# INFO: C1049_R3_mad_robustize has 2977 features
# INFO: C1049_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1049_R3_mad_robustize_reduced-corr.csv
# INFO: C1058_R2_mad_robustize has 384 rows
# INFO: C1058_R2_mad_robustize has 2977 features
# INFO: C1058_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1058_R2_mad_robustize_reduced-corr.csv
# INFO: C1063_R3_mad_robustize has 384 rows
# INFO: C1063_R3_mad_robustize has 2977 features
# INFO: C1063_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1063_R3_mad_robustize_reduced-corr.csv
# INFO: C1054_R1_mad_robustize has 384 rows
# INFO: C1054_R1_mad_robustize has 2977 features
# INFO: C1054_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1054_R1_mad_robustize_reduced-corr.csv
# INFO: C1066_R3_mad_robustize has 384 rows
# INFO: C1066_R3_mad_robustize has 2977 features
# INFO: C1066_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1066_R3_mad_robustize_reduced-corr.csv
# INFO: C1029_R1_mad_robustize has 384 rows
# INFO: C1029_R1_mad_robustize has 2977 features
# INFO: C1029_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1029_R1_mad_robustize_reduced-corr.csv
# INFO: C1018_R2_mad_robustize has 384 rows
# INFO: C1018_R2_mad_robustize has 2977 features
# INFO: C1018_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1018_R2_mad_robustize_reduced-corr.csv
# INFO: C1058_R4_mad_robustize has 384 rows
# INFO: C1058_R4_mad_robustize has 2977 features
# INFO: C1058_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1058_R4_mad_robustize_reduced-corr.csv
# INFO: C1034_R4_mad_robustize has 384 rows
# INFO: C1034_R4_mad_robustize has 2977 features
# INFO: C1034_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1034_R4_mad_robustize_reduced-corr.csv
# INFO: C1028_R2_mad_robustize has 384 rows
# INFO: C1028_R2_mad_robustize has 2977 features
# INFO: C1028_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1028_R2_mad_robustize_reduced-corr.csv
# INFO: C1027_R4_mad_robustize has 384 rows
# INFO: C1027_R4_mad_robustize has 2977 features
# INFO: C1027_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1027_R4_mad_robustize_reduced-corr.csv
# INFO: C1073_R4_mad_robustize has 384 rows
# INFO: C1073_R4_mad_robustize has 2977 features
# INFO: C1073_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1073_R4_mad_robustize_reduced-corr.csv
# INFO: C1055_R3_mad_robustize has 384 rows
# INFO: C1055_R3_mad_robustize has 2977 features
# INFO: C1055_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1055_R3_mad_robustize_reduced-corr.csv
# INFO: C1066_R1_mad_robustize has 384 rows
# INFO: C1066_R1_mad_robustize has 2977 features
# INFO: C1066_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1066_R1_mad_robustize_reduced-corr.csv
# INFO: C1040_R1_mad_robustize has 384 rows
# INFO: C1040_R1_mad_robustize has 2977 features
# INFO: C1040_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1040_R1_mad_robustize_reduced-corr.csv
# INFO: C1028_R1_mad_robustize has 384 rows
# INFO: C1028_R1_mad_robustize has 2977 features
# INFO: C1028_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1028_R1_mad_robustize_reduced-corr.csv
# INFO: C1035_R3_mad_robustize has 384 rows
# INFO: C1035_R3_mad_robustize has 2977 features
# INFO: C1035_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1035_R3_mad_robustize_reduced-corr.csv
# INFO: C1043_R2_mad_robustize has 384 rows
# INFO: C1043_R2_mad_robustize has 2977 features
# INFO: C1043_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1043_R2_mad_robustize_reduced-corr.csv
# INFO: C1072_R1_mad_robustize has 384 rows
# INFO: C1072_R1_mad_robustize has 2977 features
# INFO: C1072_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1072_R1_mad_robustize_reduced-corr.csv
# INFO: C1012_R2_mad_robustize has 384 rows
# INFO: C1012_R2_mad_robustize has 2977 features
# INFO: C1012_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1012_R2_mad_robustize_reduced-corr.csv
# INFO: C1039_R3_mad_robustize has 384 rows
# INFO: C1039_R3_mad_robustize has 2977 features
# INFO: C1039_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1039_R3_mad_robustize_reduced-corr.csv
# INFO: C1068_R1_mad_robustize has 384 rows
# INFO: C1068_R1_mad_robustize has 2977 features
# INFO: C1068_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1068_R1_mad_robustize_reduced-corr.csv
# INFO: C1017_R2_mad_robustize has 384 rows
# INFO: C1017_R2_mad_robustize has 2977 features
# INFO: C1017_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1017_R2_mad_robustize_reduced-corr.csv
# INFO: C1042_R3_mad_robustize has 384 rows
# INFO: C1042_R3_mad_robustize has 2977 features
# INFO: C1042_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1042_R3_mad_robustize_reduced-corr.csv
# INFO: C1052_R4_mad_robustize has 384 rows
# INFO: C1052_R4_mad_robustize has 2977 features
# INFO: C1052_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1052_R4_mad_robustize_reduced-corr.csv
# INFO: C1043_R4_mad_robustize has 384 rows
# INFO: C1043_R4_mad_robustize has 2977 features
# INFO: C1043_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1043_R4_mad_robustize_reduced-corr.csv
# INFO: C1077_R4_mad_robustize has 384 rows
# INFO: C1077_R4_mad_robustize has 2977 features
# INFO: C1077_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1077_R4_mad_robustize_reduced-corr.csv
# INFO: C1071_R4_mad_robustize has 384 rows
# INFO: C1071_R4_mad_robustize has 2977 features
# INFO: C1071_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1071_R4_mad_robustize_reduced-corr.csv
# INFO: C1021_R1_mad_robustize has 384 rows
# INFO: C1021_R1_mad_robustize has 2977 features
# INFO: C1021_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1021_R1_mad_robustize_reduced-corr.csv
# INFO: C1058_R1_mad_robustize has 384 rows
# INFO: C1058_R1_mad_robustize has 2977 features
# INFO: C1058_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1058_R1_mad_robustize_reduced-corr.csv
# INFO: C1027_R2_mad_robustize has 384 rows
# INFO: C1027_R2_mad_robustize has 2977 features
# INFO: C1027_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1027_R2_mad_robustize_reduced-corr.csv
# INFO: C1039_R2_mad_robustize has 384 rows
# INFO: C1039_R2_mad_robustize has 2977 features
# INFO: C1039_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1039_R2_mad_robustize_reduced-corr.csv
# INFO: C1081_R4_mad_robustize has 384 rows
# INFO: C1081_R4_mad_robustize has 2977 features
# INFO: C1081_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1081_R4_mad_robustize_reduced-corr.csv
# INFO: C1061_R2_mad_robustize has 384 rows
# INFO: C1061_R2_mad_robustize has 2977 features
# INFO: C1061_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1061_R2_mad_robustize_reduced-corr.csv
# INFO: C1054_R2_mad_robustize has 384 rows
# INFO: C1054_R2_mad_robustize has 2977 features
# INFO: C1054_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1054_R2_mad_robustize_reduced-corr.csv
# INFO: C1083_R2_mad_robustize has 384 rows
# INFO: C1083_R2_mad_robustize has 2977 features
# INFO: C1083_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1083_R2_mad_robustize_reduced-corr.csv
# INFO: C1056_R2_mad_robustize has 384 rows
# INFO: C1056_R2_mad_robustize has 2977 features
# INFO: C1056_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1056_R2_mad_robustize_reduced-corr.csv
# INFO: C1053_R2_mad_robustize has 384 rows
# INFO: C1053_R2_mad_robustize has 2977 features
# INFO: C1053_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1053_R2_mad_robustize_reduced-corr.csv
# INFO: C1048_R4_mad_robustize has 384 rows
# INFO: C1048_R4_mad_robustize has 2977 features
# INFO: C1048_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1048_R4_mad_robustize_reduced-corr.csv
# INFO: C1079_R2_mad_robustize has 384 rows
# INFO: C1079_R2_mad_robustize has 2977 features
# INFO: C1079_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1079_R2_mad_robustize_reduced-corr.csv
# INFO: C1054_R4_mad_robustize has 384 rows
# INFO: C1054_R4_mad_robustize has 2977 features
# INFO: C1054_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1054_R4_mad_robustize_reduced-corr.csv
# INFO: C1064_R4_mad_robustize has 384 rows
# INFO: C1064_R4_mad_robustize has 2977 features
# INFO: C1064_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1064_R4_mad_robustize_reduced-corr.csv
# INFO: C1057_R3_mad_robustize has 384 rows
# INFO: C1057_R3_mad_robustize has 2977 features
# INFO: C1057_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1057_R3_mad_robustize_reduced-corr.csv
# INFO: C1020_R2_mad_robustize has 384 rows
# INFO: C1020_R2_mad_robustize has 2977 features
# INFO: C1020_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1020_R2_mad_robustize_reduced-corr.csv
# INFO: C1024_R2_mad_robustize has 384 rows
# INFO: C1024_R2_mad_robustize has 2977 features
# INFO: C1024_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1024_R2_mad_robustize_reduced-corr.csv
# INFO: C1067_R3_mad_robustize has 384 rows
# INFO: C1067_R3_mad_robustize has 2977 features
# INFO: C1067_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1067_R3_mad_robustize_reduced-corr.csv
# INFO: C1046_R1_mad_robustize has 384 rows
# INFO: C1046_R1_mad_robustize has 2977 features
# INFO: C1046_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1046_R1_mad_robustize_reduced-corr.csv
# INFO: C1025_R1_mad_robustize has 384 rows
# INFO: C1025_R1_mad_robustize has 2977 features
# INFO: C1025_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1025_R1_mad_robustize_reduced-corr.csv
# INFO: C1039_R1_mad_robustize has 384 rows
# INFO: C1039_R1_mad_robustize has 2977 features
# INFO: C1039_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1039_R1_mad_robustize_reduced-corr.csv
# INFO: C1031_R4_mad_robustize has 384 rows
# INFO: C1031_R4_mad_robustize has 2977 features
# INFO: C1031_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1031_R4_mad_robustize_reduced-corr.csv
# INFO: C1053_R3_mad_robustize has 384 rows
# INFO: C1053_R3_mad_robustize has 2977 features
# INFO: C1053_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1053_R3_mad_robustize_reduced-corr.csv
# INFO: C1050_R3_mad_robustize has 384 rows
# INFO: C1050_R3_mad_robustize has 2977 features
# INFO: C1050_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1050_R3_mad_robustize_reduced-corr.csv
# INFO: C1068_R4_mad_robustize has 384 rows
# INFO: C1068_R4_mad_robustize has 2977 features
# INFO: C1068_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1068_R4_mad_robustize_reduced-corr.csv
# INFO: C1046_R2_mad_robustize has 384 rows
# INFO: C1046_R2_mad_robustize has 2977 features
# INFO: C1046_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1046_R2_mad_robustize_reduced-corr.csv
# INFO: C1042_R2_mad_robustize has 384 rows
# INFO: C1042_R2_mad_robustize has 2977 features
# INFO: C1042_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1042_R2_mad_robustize_reduced-corr.csv
# INFO: C1018_R4_mad_robustize has 384 rows
# INFO: C1018_R4_mad_robustize has 2977 features
# INFO: C1018_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1018_R4_mad_robustize_reduced-corr.csv
# INFO: C1041_R1_mad_robustize has 384 rows
# INFO: C1041_R1_mad_robustize has 2977 features
# INFO: C1041_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1041_R1_mad_robustize_reduced-corr.csv
# INFO: C1076_R1_mad_robustize has 384 rows
# INFO: C1076_R1_mad_robustize has 2977 features
# INFO: C1076_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1076_R1_mad_robustize_reduced-corr.csv
# INFO: C1062_R1_mad_robustize has 384 rows
# INFO: C1062_R1_mad_robustize has 2977 features
# INFO: C1062_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1062_R1_mad_robustize_reduced-corr.csv
# INFO: C1037_R2_mad_robustize has 384 rows
# INFO: C1037_R2_mad_robustize has 2977 features
# INFO: C1037_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1037_R2_mad_robustize_reduced-corr.csv
# INFO: C1063_R4_mad_robustize has 384 rows
# INFO: C1063_R4_mad_robustize has 2977 features
# INFO: C1063_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1063_R4_mad_robustize_reduced-corr.csv
# INFO: C1074_R2_mad_robustize has 384 rows
# INFO: C1074_R2_mad_robustize has 2977 features
# INFO: C1074_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1074_R2_mad_robustize_reduced-corr.csv
# INFO: C1060_R2_mad_robustize has 384 rows
# INFO: C1060_R2_mad_robustize has 2977 features
# INFO: C1060_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1060_R2_mad_robustize_reduced-corr.csv
# INFO: C1029_R2_mad_robustize has 384 rows
# INFO: C1029_R2_mad_robustize has 2977 features
# INFO: C1029_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1029_R2_mad_robustize_reduced-corr.csv
# INFO: C1026_R2_mad_robustize has 384 rows
# INFO: C1026_R2_mad_robustize has 2977 features
# INFO: C1026_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1026_R2_mad_robustize_reduced-corr.csv
# INFO: C1081_R2_mad_robustize has 384 rows
# INFO: C1081_R2_mad_robustize has 2977 features
# INFO: C1081_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1081_R2_mad_robustize_reduced-corr.csv
# INFO: C1047_R2_mad_robustize has 384 rows
# INFO: C1047_R2_mad_robustize has 2977 features
# INFO: C1047_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1047_R2_mad_robustize_reduced-corr.csv
# INFO: C1072_R2_mad_robustize has 384 rows
# INFO: C1072_R2_mad_robustize has 2977 features
# INFO: C1072_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1072_R2_mad_robustize_reduced-corr.csv
# INFO: C1056_R4_mad_robustize has 384 rows
# INFO: C1056_R4_mad_robustize has 2977 features
# INFO: C1056_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1056_R4_mad_robustize_reduced-corr.csv
# INFO: C1025_R2_mad_robustize has 384 rows
# INFO: C1025_R2_mad_robustize has 2977 features
# INFO: C1025_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1025_R2_mad_robustize_reduced-corr.csv
# INFO: C1014_R4_mad_robustize has 384 rows
# INFO: C1014_R4_mad_robustize has 2977 features
# INFO: C1014_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1014_R4_mad_robustize_reduced-corr.csv
# INFO: C1011_R1_mad_robustize has 384 rows
# INFO: C1011_R1_mad_robustize has 2977 features
# INFO: C1011_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1011_R1_mad_robustize_reduced-corr.csv
# INFO: C1064_R4_mad_robustize has 9 rows
# INFO: C1064_R4_mad_robustize has 2977 features
# INFO: C1064_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1064_R4_mad_robustize_reduced-corr.csv
# INFO: C1046_R3_mad_robustize has 384 rows
# INFO: C1046_R3_mad_robustize has 2977 features
# INFO: C1046_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1046_R3_mad_robustize_reduced-corr.csv
# INFO: C1036_R3_mad_robustize has 384 rows
# INFO: C1036_R3_mad_robustize has 2977 features
# INFO: C1036_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1036_R3_mad_robustize_reduced-corr.csv
# INFO: C1082_R2_mad_robustize has 384 rows
# INFO: C1082_R2_mad_robustize has 2977 features
# INFO: C1082_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1082_R2_mad_robustize_reduced-corr.csv
# INFO: C1013_R2_mad_robustize has 384 rows
# INFO: C1013_R2_mad_robustize has 2977 features
# INFO: C1013_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1013_R2_mad_robustize_reduced-corr.csv
# INFO: C1031_R2_mad_robustize has 384 rows
# INFO: C1031_R2_mad_robustize has 2977 features
# INFO: C1031_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1031_R2_mad_robustize_reduced-corr.csv
# INFO: C1037_R1_mad_robustize has 384 rows
# INFO: C1037_R1_mad_robustize has 2977 features
# INFO: C1037_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1037_R1_mad_robustize_reduced-corr.csv
# INFO: C1060_R4_mad_robustize has 384 rows
# INFO: C1060_R4_mad_robustize has 2977 features
# INFO: C1060_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1060_R4_mad_robustize_reduced-corr.csv
# INFO: C1070_R1_mad_robustize has 384 rows
# INFO: C1070_R1_mad_robustize has 2977 features
# INFO: C1070_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1070_R1_mad_robustize_reduced-corr.csv
# INFO: C1066_R4_mad_robustize has 384 rows
# INFO: C1066_R4_mad_robustize has 2977 features
# INFO: C1066_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1066_R4_mad_robustize_reduced-corr.csv
# INFO: C1019_R4_mad_robustize has 384 rows
# INFO: C1019_R4_mad_robustize has 2977 features
# INFO: C1019_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1019_R4_mad_robustize_reduced-corr.csv
# INFO: C1077_R3_mad_robustize has 384 rows
# INFO: C1077_R3_mad_robustize has 2977 features
# INFO: C1077_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1077_R3_mad_robustize_reduced-corr.csv
# INFO: C1012_R3_mad_robustize has 384 rows
# INFO: C1012_R3_mad_robustize has 2977 features
# INFO: C1012_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1012_R3_mad_robustize_reduced-corr.csv
# INFO: C1020_R1_mad_robustize has 384 rows
# INFO: C1020_R1_mad_robustize has 2977 features
# INFO: C1020_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1020_R1_mad_robustize_reduced-corr.csv
# INFO: C1031_R2_mad_robustize has 384 rows
# INFO: C1031_R2_mad_robustize has 2977 features
# INFO: C1031_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1031_R2_mad_robustize_reduced-corr.csv
# INFO: C1024_R3_mad_robustize has 384 rows
# INFO: C1024_R3_mad_robustize has 2977 features
# INFO: C1024_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1024_R3_mad_robustize_reduced-corr.csv
# INFO: C1014_R3_mad_robustize has 384 rows
# INFO: C1014_R3_mad_robustize has 2977 features
# INFO: C1014_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1014_R3_mad_robustize_reduced-corr.csv
# INFO: C1040_R3_mad_robustize has 384 rows
# INFO: C1040_R3_mad_robustize has 2977 features
# INFO: C1040_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1040_R3_mad_robustize_reduced-corr.csv
# INFO: C1064_R1_mad_robustize has 384 rows
# INFO: C1064_R1_mad_robustize has 2977 features
# INFO: C1064_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1064_R1_mad_robustize_reduced-corr.csv
# INFO: C1043_R3_mad_robustize has 384 rows
# INFO: C1043_R3_mad_robustize has 2977 features
# INFO: C1043_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1043_R3_mad_robustize_reduced-corr.csv
# INFO: C1081_R1_mad_robustize has 384 rows
# INFO: C1081_R1_mad_robustize has 2977 features
# INFO: C1081_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1081_R1_mad_robustize_reduced-corr.csv
# INFO: C1052_R2_mad_robustize has 384 rows
# INFO: C1052_R2_mad_robustize has 2977 features
# INFO: C1052_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1052_R2_mad_robustize_reduced-corr.csv
# INFO: C1039_R4_mad_robustize has 384 rows
# INFO: C1039_R4_mad_robustize has 2977 features
# INFO: C1039_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1039_R4_mad_robustize_reduced-corr.csv
# INFO: C1012_R1_mad_robustize has 384 rows
# INFO: C1012_R1_mad_robustize has 2977 features
# INFO: C1012_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1012_R1_mad_robustize_reduced-corr.csv
# INFO: C1014_R2_mad_robustize has 384 rows
# INFO: C1014_R2_mad_robustize has 2977 features
# INFO: C1014_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1014_R2_mad_robustize_reduced-corr.csv
# INFO: C1042_R1_mad_robustize has 384 rows
# INFO: C1042_R1_mad_robustize has 2977 features
# INFO: C1042_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1042_R1_mad_robustize_reduced-corr.csv
# INFO: C1074_R1_mad_robustize has 384 rows
# INFO: C1074_R1_mad_robustize has 2977 features
# INFO: C1074_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1074_R1_mad_robustize_reduced-corr.csv
# INFO: C1076_R3_mad_robustize has 384 rows
# INFO: C1076_R3_mad_robustize has 2977 features
# INFO: C1076_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1076_R3_mad_robustize_reduced-corr.csv
# INFO: C1067_R4_mad_robustize has 383 rows
# INFO: C1067_R4_mad_robustize has 2977 features
# INFO: C1067_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1067_R4_mad_robustize_reduced-corr.csv
# INFO: C1078_R1_mad_robustize has 384 rows
# INFO: C1078_R1_mad_robustize has 2977 features
# INFO: C1078_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1078_R1_mad_robustize_reduced-corr.csv
# INFO: C1028_R4_mad_robustize has 384 rows
# INFO: C1028_R4_mad_robustize has 2977 features
# INFO: C1028_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1028_R4_mad_robustize_reduced-corr.csv
# INFO: C1035_R1_mad_robustize has 384 rows
# INFO: C1035_R1_mad_robustize has 2977 features
# INFO: C1035_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1035_R1_mad_robustize_reduced-corr.csv
# INFO: C1051_R2_mad_robustize has 384 rows
# INFO: C1051_R2_mad_robustize has 2977 features
# INFO: C1051_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1051_R2_mad_robustize_reduced-corr.csv
# INFO: C1073_R2_mad_robustize has 384 rows
# INFO: C1073_R2_mad_robustize has 2977 features
# INFO: C1073_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1073_R2_mad_robustize_reduced-corr.csv
# INFO: C1076_R4_mad_robustize has 384 rows
# INFO: C1076_R4_mad_robustize has 2977 features
# INFO: C1076_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1076_R4_mad_robustize_reduced-corr.csv
# INFO: C1016_R4_mad_robustize has 384 rows
# INFO: C1016_R4_mad_robustize has 2977 features
# INFO: C1016_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1016_R4_mad_robustize_reduced-corr.csv
# INFO: C1070_R4_mad_robustize has 384 rows
# INFO: C1070_R4_mad_robustize has 2977 features
# INFO: C1070_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1070_R4_mad_robustize_reduced-corr.csv
# INFO: C1018_R1_mad_robustize has 384 rows
# INFO: C1018_R1_mad_robustize has 2977 features
# INFO: C1018_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1018_R1_mad_robustize_reduced-corr.csv
# INFO: C1021_R4_mad_robustize has 384 rows
# INFO: C1021_R4_mad_robustize has 2977 features
# INFO: C1021_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1021_R4_mad_robustize_reduced-corr.csv
# INFO: C1080_R4_mad_robustize has 384 rows
# INFO: C1080_R4_mad_robustize has 2977 features
# INFO: C1080_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1080_R4_mad_robustize_reduced-corr.csv
# INFO: C1083_R3_mad_robustize has 384 rows
# INFO: C1083_R3_mad_robustize has 2977 features
# INFO: C1083_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1083_R3_mad_robustize_reduced-corr.csv
# INFO: C1059_R3_mad_robustize has 384 rows
# INFO: C1059_R3_mad_robustize has 2977 features
# INFO: C1059_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1059_R3_mad_robustize_reduced-corr.csv
# INFO: C1068_R3_mad_robustize has 384 rows
# INFO: C1068_R3_mad_robustize has 2977 features
# INFO: C1068_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1068_R3_mad_robustize_reduced-corr.csv
# INFO: C1080_R1_mad_robustize has 384 rows
# INFO: C1080_R1_mad_robustize has 2977 features
# INFO: C1080_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1080_R1_mad_robustize_reduced-corr.csv
# INFO: C1016_R1_mad_robustize has 384 rows
# INFO: C1016_R1_mad_robustize has 2977 features
# INFO: C1016_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1016_R1_mad_robustize_reduced-corr.csv
# INFO: C1060_R1_mad_robustize has 384 rows
# INFO: C1060_R1_mad_robustize has 2977 features
# INFO: C1060_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1060_R1_mad_robustize_reduced-corr.csv
# INFO: C1020_R4_mad_robustize has 384 rows
# INFO: C1020_R4_mad_robustize has 2977 features
# INFO: C1020_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1020_R4_mad_robustize_reduced-corr.csv
# INFO: C1075_R2_mad_robustize has 384 rows
# INFO: C1075_R2_mad_robustize has 2977 features
# INFO: C1075_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1075_R2_mad_robustize_reduced-corr.csv
# INFO: C1042_R4_mad_robustize has 384 rows
# INFO: C1042_R4_mad_robustize has 2977 features
# INFO: C1042_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1042_R4_mad_robustize_reduced-corr.csv
# INFO: C1067_R1_mad_robustize has 384 rows
# INFO: C1067_R1_mad_robustize has 2977 features
# INFO: C1067_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1067_R1_mad_robustize_reduced-corr.csv
# INFO: C1019_R1_mad_robustize has 384 rows
# INFO: C1019_R1_mad_robustize has 2977 features
# INFO: C1019_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1019_R1_mad_robustize_reduced-corr.csv
# INFO: C1032_R2_mad_robustize has 384 rows
# INFO: C1032_R2_mad_robustize has 2977 features
# ...
# INFO: C1047_R3_mad_robustize has 2977 features
# INFO: C1047_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1047_R3_mad_robustize_reduced-corr.csv
# INFO: C1035_R4_mad_robustize has 384 rows
# INFO: C1035_R4_mad_robustize has 2977 features
# INFO: C1035_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1035_R4_mad_robustize_reduced-corr.csv
# INFO: C1076_R2_mad_robustize has 384 rows
# INFO: C1076_R2_mad_robustize has 2977 features
# INFO: C1076_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1076_R2_mad_robustize_reduced-corr.csv
# INFO: C1026_R3_mad_robustize has 384 rows
# INFO: C1026_R3_mad_robustize has 2977 features
# INFO: C1026_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1026_R3_mad_robustize_reduced-corr.csv
# INFO: C1073_R3_mad_robustize has 384 rows
# INFO: C1073_R3_mad_robustize has 2977 features
# INFO: C1073_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1073_R3_mad_robustize_reduced-corr.csv
# INFO: C1026_R4_mad_robustize has 384 rows
# INFO: C1026_R4_mad_robustize has 2977 features
# INFO: C1026_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1026_R4_mad_robustize_reduced-corr.csv
# INFO: C1072_R4_mad_robustize has 384 rows
# INFO: C1072_R4_mad_robustize has 2977 features
# INFO: C1072_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1072_R4_mad_robustize_reduced-corr.csv
# INFO: C1065_R3_mad_robustize has 384 rows
# INFO: C1065_R3_mad_robustize has 2977 features
# INFO: C1065_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1065_R3_mad_robustize_reduced-corr.csv
# INFO: C1013_R1_mad_robustize has 384 rows
# INFO: C1013_R1_mad_robustize has 2977 features
# INFO: C1013_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1013_R1_mad_robustize_reduced-corr.csv
# INFO: C1040_R2_mad_robustize has 384 rows
# INFO: C1040_R2_mad_robustize has 2977 features
# INFO: C1040_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1040_R2_mad_robustize_reduced-corr.csv
# INFO: C1037_R4_mad_robustize has 384 rows
# INFO: C1037_R4_mad_robustize has 2977 features
# INFO: C1037_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1037_R4_mad_robustize_reduced-corr.csv
# INFO: C1070_R3_mad_robustize has 384 rows
# INFO: C1070_R3_mad_robustize has 2977 features
# INFO: C1070_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1070_R3_mad_robustize_reduced-corr.csv
# INFO: C1016_R2_mad_robustize has 384 rows
# INFO: C1016_R2_mad_robustize has 2977 features
# INFO: C1016_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1016_R2_mad_robustize_reduced-corr.csv
# INFO: C1036_R1_mad_robustize has 384 rows
# INFO: C1036_R1_mad_robustize has 2977 features
# INFO: C1036_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1036_R1_mad_robustize_reduced-corr.csv
# INFO: C1023_R1_mad_robustize has 384 rows
# INFO: C1023_R1_mad_robustize has 2977 features
# INFO: C1023_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1023_R1_mad_robustize_reduced-corr.csv
# INFO: C1032_R3_mad_robustize has 384 rows
# INFO: C1032_R3_mad_robustize has 2977 features
# INFO: C1032_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1032_R3_mad_robustize_reduced-corr.csv
# INFO: C1024_R1_mad_robustize has 311 rows
# INFO: C1024_R1_mad_robustize has 2977 features
# INFO: C1024_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1024_R1_mad_robustize_reduced-corr.csv
# INFO: C1033_R3_mad_robustize has 384 rows
# INFO: C1033_R3_mad_robustize has 2977 features
# INFO: C1033_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1033_R3_mad_robustize_reduced-corr.csv
# INFO: C1051_R3_mad_robustize has 384 rows
# INFO: C1051_R3_mad_robustize has 2977 features
# INFO: C1051_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1051_R3_mad_robustize_reduced-corr.csv
# INFO: C1070_R2_mad_robustize has 384 rows
# INFO: C1070_R2_mad_robustize has 2977 features
# INFO: C1070_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1070_R2_mad_robustize_reduced-corr.csv
# INFO: C1053_R1_mad_robustize has 384 rows
# INFO: C1053_R1_mad_robustize has 2977 features
# INFO: C1053_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1053_R1_mad_robustize_reduced-corr.csv
# INFO: C1057_R1_mad_robustize has 384 rows
# INFO: C1057_R1_mad_robustize has 2977 features
# INFO: C1057_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1057_R1_mad_robustize_reduced-corr.csv
# INFO: C1034_R3_mad_robustize has 384 rows
# INFO: C1034_R3_mad_robustize has 2977 features
# INFO: C1034_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1034_R3_mad_robustize_reduced-corr.csv
# INFO: C1049_R1_mad_robustize has 384 rows
# INFO: C1049_R1_mad_robustize has 2977 features
# INFO: C1049_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1049_R1_mad_robustize_reduced-corr.csv
# INFO: C1065_R1_mad_robustize has 384 rows
# INFO: C1065_R1_mad_robustize has 2977 features
# INFO: C1065_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1065_R1_mad_robustize_reduced-corr.csv
# INFO: C1047_R4_mad_robustize has 384 rows
# INFO: C1047_R4_mad_robustize has 2977 features
# INFO: C1047_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1047_R4_mad_robustize_reduced-corr.csv
# INFO: C1017_R1_mad_robustize has 384 rows
# INFO: C1017_R1_mad_robustize has 2977 features
# INFO: C1017_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1017_R1_mad_robustize_reduced-corr.csv
# INFO: C1061_R1_mad_robustize has 384 rows
# INFO: C1061_R1_mad_robustize has 2977 features
# INFO: C1061_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1061_R1_mad_robustize_reduced-corr.csv
# INFO: C1065_R4_mad_robustize has 384 rows
# INFO: C1065_R4_mad_robustize has 2977 features
# INFO: C1065_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1065_R4_mad_robustize_reduced-corr.csv
# INFO: C1048_R1_mad_robustize has 384 rows
# INFO: C1048_R1_mad_robustize has 2977 features
# INFO: C1048_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1048_R1_mad_robustize_reduced-corr.csv
# INFO: C1038_R1_mad_robustize has 384 rows
# INFO: C1038_R1_mad_robustize has 2977 features
# INFO: C1038_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1038_R1_mad_robustize_reduced-corr.csv
# INFO: C1056_R3_mad_robustize has 384 rows
# INFO: C1056_R3_mad_robustize has 2977 features
# INFO: C1056_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1056_R3_mad_robustize_reduced-corr.csv
# INFO: C1082_R3_mad_robustize has 384 rows
# INFO: C1082_R3_mad_robustize has 2977 features
# INFO: C1082_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1082_R3_mad_robustize_reduced-corr.csv
# INFO: C1075_R4_mad_robustize has 384 rows
# INFO: C1075_R4_mad_robustize has 2977 features
# INFO: C1075_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1075_R4_mad_robustize_reduced-corr.csv
# INFO: C1066_R2_mad_robustize has 384 rows
# INFO: C1066_R2_mad_robustize has 2977 features
# INFO: C1066_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1066_R2_mad_robustize_reduced-corr.csv
# INFO: C1048_R3_mad_robustize has 384 rows
# INFO: C1048_R3_mad_robustize has 2977 features
# INFO: C1048_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1048_R3_mad_robustize_reduced-corr.csv
# INFO: C1050_R2_mad_robustize has 384 rows
# INFO: C1050_R2_mad_robustize has 2977 features
# INFO: C1050_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1050_R2_mad_robustize_reduced-corr.csv
# INFO: C1081_R3_mad_robustize has 384 rows
# INFO: C1081_R3_mad_robustize has 2977 features
# INFO: C1081_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1081_R3_mad_robustize_reduced-corr.csv
# INFO: C1033_R2_mad_robustize has 384 rows
# INFO: C1033_R2_mad_robustize has 2977 features
# INFO: C1033_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1033_R2_mad_robustize_reduced-corr.csv
# INFO: C1073_R1_mad_robustize has 384 rows
# INFO: C1073_R1_mad_robustize has 2977 features
# INFO: C1073_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1073_R1_mad_robustize_reduced-corr.csv
# INFO: C1026_R3_mad_robustize has 384 rows
# INFO: C1026_R3_mad_robustize has 2977 features
# INFO: C1026_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1026_R3_mad_robustize_reduced-corr.csv
# INFO: C1052_R3_mad_robustize has 384 rows
# INFO: C1052_R3_mad_robustize has 2977 features
# INFO: C1052_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1052_R3_mad_robustize_reduced-corr.csv
# INFO: C1018_R3_mad_robustize has 384 rows
# INFO: C1018_R3_mad_robustize has 2977 features
# INFO: C1018_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1018_R3_mad_robustize_reduced-corr.csv
# INFO: C1033_R4_mad_robustize has 384 rows
# INFO: C1033_R4_mad_robustize has 2977 features
# INFO: C1033_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1033_R4_mad_robustize_reduced-corr.csv
# INFO: C1037_R3_mad_robustize has 384 rows
# INFO: C1037_R3_mad_robustize has 2977 features
# INFO: C1037_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1037_R3_mad_robustize_reduced-corr.csv
# INFO: C1016_R3_mad_robustize has 384 rows
# INFO: C1016_R3_mad_robustize has 2977 features
# INFO: C1016_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1016_R3_mad_robustize_reduced-corr.csv
# INFO: C1078_R3_mad_robustize has 384 rows
# INFO: C1078_R3_mad_robustize has 2977 features
# INFO: C1078_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1078_R3_mad_robustize_reduced-corr.csv
# INFO: C1044_R1_mad_robustize has 384 rows
# INFO: C1044_R1_mad_robustize has 2977 features
# INFO: C1044_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1044_R1_mad_robustize_reduced-corr.csv
# INFO: C1024_R1_mad_robustize has 384 rows
# INFO: C1024_R1_mad_robustize has 2977 features
# INFO: C1024_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1024_R1_mad_robustize_reduced-corr.csv
# INFO: C1023_R4_mad_robustize has 384 rows
# INFO: C1023_R4_mad_robustize has 2977 features
# INFO: C1023_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1023_R4_mad_robustize_reduced-corr.csv
# INFO: C1038_R3_mad_robustize has 384 rows
# INFO: C1038_R3_mad_robustize has 2977 features
# INFO: C1038_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1038_R3_mad_robustize_reduced-corr.csv
# INFO: C1032_R4_mad_robustize has 384 rows
# INFO: C1032_R4_mad_robustize has 2977 features
# INFO: C1032_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1032_R4_mad_robustize_reduced-corr.csv
# INFO: C1032_R1_mad_robustize has 384 rows
# INFO: C1032_R1_mad_robustize has 2977 features
# INFO: C1032_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1032_R1_mad_robustize_reduced-corr.csv
# INFO: C1034_R2_mad_robustize has 384 rows
# INFO: C1034_R2_mad_robustize has 2977 features
# INFO: C1034_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1034_R2_mad_robustize_reduced-corr.csv
# INFO: C1079_R1_mad_robustize has 384 rows
# INFO: C1079_R1_mad_robustize has 2977 features
# INFO: C1079_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1079_R1_mad_robustize_reduced-corr.csv
# INFO: C1036_R2_mad_robustize has 384 rows
# INFO: C1036_R2_mad_robustize has 2977 features
# INFO: C1036_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1036_R2_mad_robustize_reduced-corr.csv
# INFO: C1079_R3_mad_robustize has 384 rows
# INFO: C1079_R3_mad_robustize has 2977 features
# INFO: C1079_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1079_R3_mad_robustize_reduced-corr.csv
# INFO: C1061_R4_mad_robustize has 384 rows
# INFO: C1061_R4_mad_robustize has 2977 features
# INFO: C1061_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1061_R4_mad_robustize_reduced-corr.csv
# INFO: C1017_R4_mad_robustize has 384 rows
# INFO: C1017_R4_mad_robustize has 2977 features
# INFO: C1017_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1017_R4_mad_robustize_reduced-corr.csv
# INFO: C1044_R3_mad_robustize has 384 rows
# INFO: C1044_R3_mad_robustize has 2977 features
# INFO: C1044_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1044_R3_mad_robustize_reduced-corr.csv
# INFO: C1069_R4_mad_robustize has 384 rows
# INFO: C1069_R4_mad_robustize has 2977 features
# INFO: C1069_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1069_R4_mad_robustize_reduced-corr.csv
# INFO: C1026_R1_mad_robustize has 384 rows
# INFO: C1026_R1_mad_robustize has 2977 features
# INFO: C1026_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1026_R1_mad_robustize_reduced-corr.csv
# INFO: C1040_R4_mad_robustize has 384 rows
# INFO: C1040_R4_mad_robustize has 2977 features
# INFO: C1040_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1040_R4_mad_robustize_reduced-corr.csv
# INFO: C1077_R1_mad_robustize has 384 rows
# INFO: C1077_R1_mad_robustize has 2977 features
# INFO: C1077_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1077_R1_mad_robustize_reduced-corr.csv
# INFO: C1079_R4_mad_robustize has 384 rows
# INFO: C1079_R4_mad_robustize has 2977 features
# INFO: C1079_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1079_R4_mad_robustize_reduced-corr.csv
# INFO: C1061_R2_mad_robustize has 384 rows
# INFO: C1061_R2_mad_robustize has 2977 features
# INFO: C1061_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1061_R2_mad_robustize_reduced-corr.csv
# INFO: C1061_R3_mad_robustize has 384 rows
# INFO: C1061_R3_mad_robustize has 2977 features
# INFO: C1061_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1061_R3_mad_robustize_reduced-corr.csv
# INFO: C1057_R2_mad_robustize has 384 rows
# INFO: C1057_R2_mad_robustize has 2977 features
# INFO: C1057_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1057_R2_mad_robustize_reduced-corr.csv
# INFO: C1056_R1_mad_robustize has 384 rows
# INFO: C1056_R1_mad_robustize has 2977 features
# INFO: C1056_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1056_R1_mad_robustize_reduced-corr.csv
# INFO: C1030_R1_mad_robustize has 384 rows
# INFO: C1030_R1_mad_robustize has 2977 features
# INFO: C1030_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1030_R1_mad_robustize_reduced-corr.csv
# INFO: C1067_R2_mad_robustize has 384 rows
# INFO: C1067_R2_mad_robustize has 2977 features
# INFO: C1067_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1067_R2_mad_robustize_reduced-corr.csv
# INFO: C1015_R3_mad_robustize has 384 rows
# INFO: C1015_R3_mad_robustize has 2977 features
# INFO: C1015_R3_mad_robustize has 601 features after feature reduction
# INFO: Saved C1015_R3_mad_robustize_reduced-corr.csv
# INFO: C1035_R2_mad_robustize has 384 rows
# INFO: C1035_R2_mad_robustize has 2977 features
# INFO: C1035_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1035_R2_mad_robustize_reduced-corr.csv
# INFO: C1019_R2_mad_robustize has 384 rows
# INFO: C1019_R2_mad_robustize has 2977 features
# INFO: C1019_R2_mad_robustize has 601 features after feature reduction
# INFO: Saved C1019_R2_mad_robustize_reduced-corr.csv
# INFO: C1027_R1_mad_robustize has 384 rows
# INFO: C1027_R1_mad_robustize has 2977 features
# INFO: C1027_R1_mad_robustize has 601 features after feature reduction
# INFO: Saved C1027_R1_mad_robustize_reduced-corr.csv
# INFO: C1049_R4_mad_robustize has 384 rows
# INFO: C1049_R4_mad_robustize has 2977 features
# INFO: C1049_R4_mad_robustize has 601 features after feature reduction
# INFO: Saved C1049_R4_mad_robustize_reduced-corr.csv
