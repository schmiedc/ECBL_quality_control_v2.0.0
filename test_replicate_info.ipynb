# %%
import time
from datetime import date
import pandas as pd
import os
import glob
import re

# %%
basedir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/output/IMTM/"

# %%
R1_test = pd.read_csv(basedir + "2024-05-30_C1230_R1/C1230_R1.csv" )

# %%
R2_test = pd.read_csv(basedir + "2024-05-30_C1230_R2/C1230_R2.csv" )

# %%
R3_test = pd.read_csv(basedir + "2024-06-03_C1230_R3/C1230_R3.csv" )

# %%
R4_test = pd.read_csv(basedir + "2024-06-03_C1230_R4/C1230_R4.csv" )

# %%
R1_test.head()
# Out:
#   Metadata_Batch Metadata_Plate Metadata_Well_randomized  \
# 0     HepG2_10uM        C1230R1                      A01
# 1     HepG2_10uM        C1230R1                      A02
# 2     HepG2_10uM        C1230R1                      A03
# 3     HepG2_10uM        C1230R1                      A04
# 4     HepG2_10uM        C1230R1                      A05
#
#    Metadata_Object_Count  Nuc_AreaShape_Area  Nuc_AreaShape_BoundingBoxArea  \
# 0                   1273               425.0                          575.0
# 1                   1372               418.0                          572.0
# 2                   1134               421.0                          572.0
# 3                   1508               427.0                          580.0
# 4                   1233               422.0                          575.0
#
#    Nuc_AreaShape_BoundingBoxMaximum_X  Nuc_AreaShape_BoundingBoxMaximum_Y  \
# 0                               465.0                               533.0
# ...

# %%
R2_test.head()
# Out:
#   Metadata_Batch Metadata_Plate Metadata_Well_randomized  \
# 0     HepG2_10uM        C1230R2                      A01
# 1     HepG2_10uM        C1230R2                      A02
# 2     HepG2_10uM        C1230R2                      A03
# 3     HepG2_10uM        C1230R2                      A04
# 4     HepG2_10uM        C1230R2                      A05
#
#    Metadata_Object_Count  Nuc_AreaShape_Area  Nuc_AreaShape_BoundingBoxArea  \
# 0                   1113               413.0                          552.0
# 1                   1217               394.0                          529.0
# 2                   1390               406.0                          550.0
# 3                   1284               422.0                          572.0
# 4                   1273               414.0                          561.0
#
#    Nuc_AreaShape_BoundingBoxMaximum_X  Nuc_AreaShape_BoundingBoxMaximum_Y  \
# 0                               551.0                               525.0
# ...

# %%
R3_test.head()
# Out:
#   Metadata_Batch Metadata_Plate Metadata_Well_randomized  \
# 0     HepG2_10uM        C1230R3                      A01
# 1     HepG2_10uM        C1230R3                      A02
# 2     HepG2_10uM        C1230R3                      A03
# 3     HepG2_10uM        C1230R3                      A04
# 4     HepG2_10uM        C1230R3                      A05
#
#    Metadata_Object_Count  Nuc_AreaShape_Area  Nuc_AreaShape_BoundingBoxArea  \
# 0                   1196               403.0                          550.0
# 1                   1247               408.0                          550.0
# 2                   1263               388.0                          528.0
# 3                   1229               402.0                          550.0
# 4                   1344               400.0                          532.0
#
#    Nuc_AreaShape_BoundingBoxMaximum_X  Nuc_AreaShape_BoundingBoxMaximum_Y  \
# 0                               533.5                               505.0
# ...

# %%
R4_test.head()
# Out:
#   Metadata_Batch Metadata_Plate Metadata_Well_randomized  \
# 0     HepG2_10uM        C1230R4                      A01
# 1     HepG2_10uM        C1230R4                      A02
# 2     HepG2_10uM        C1230R4                      A03
# 3     HepG2_10uM        C1230R4                      A04
# 4     HepG2_10uM        C1230R4                      A05
#
#    Metadata_Object_Count  Nuc_AreaShape_Area  Nuc_AreaShape_BoundingBoxArea  \
# 0                   1220               410.5                          552.0
# 1                   1257               416.0                          567.0
# 2                   1330               401.0                          550.0
# 3                   1291               406.0                          550.0
# 4                   1307               397.0                          540.0
#
#    Nuc_AreaShape_BoundingBoxMaximum_X  Nuc_AreaShape_BoundingBoxMaximum_Y  \
# 0                               504.0                               499.5
# ...
