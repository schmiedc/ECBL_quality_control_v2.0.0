# %%
import time
from datetime import date
import pandas as pd
import os
import glob
import pycytominer
import sys
import CBE_utils as CBE
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import gc

# %%
import importlib
importlib.reload(CBE)
# Out:
# <module 'CBE_utils' from '/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/notebooks_revision/CBE_utils.py'>

# %%
input_path = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/output/"

annotation_dir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/annotation/"
feature_dir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/reduced_features/"

# %% [markdown]
# # Test
# input_path = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/test_output/"
#
# annotation_dir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/test_annotation/"

# %% [markdown]
# input_path = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/tech_test_output/"
#
# annotation_dir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/annotation/"
# feature_dir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/reduced_features/"

# %%
# get folder list 
# load for each site the normalized files
# reduce the features selecting the correct feature list
folders = [name for name in os.listdir(input_path) if os.path.isdir(os.path.join(input_path, name))]

# %% [markdown]
# # Correlation based feature reduction

# %%
# compute new feature set for each site using correlation based feature redcution

def reduced_features(site_name):
    
    Data = []

    site_specific_path = os.path.join(input_path, site_name)
     
    # loads mad_robustize normalized data
    pattern = "[A-Z]*_R[1-4]_mad_robustize.csv"
    file_list = glob.glob(site_specific_path + os.sep + '*' + os.sep + pattern, recursive=True)

    for file in file_list:
        
        plate_map_name = os.path.splitext(os.path.basename(file))[0]
        
        try:
            dataframe = pd.read_csv(file)
            row_count = dataframe.shape[0]

            Data.append(dataframe)
        
            print(f"INFO: {plate_map_name} has {row_count} rows")
        
        except Exception as e:
        
            print(f"Error reading file {filename}: {e}")

    print("Feature reduction with correlation threshold 0.9 and Outlier threshold 100")

    Data_aggregated = pd.concat(Data)
    Data_aggregated = Data_aggregated.reset_index(drop = True)
    reduced_feature_dataframe = CBE.feature_reduction(Data_aggregated,
                                             variance_freq_cut=0.1,
                                             variance_unique_cut=0.1,
                                             outlier_cutoff=100,
                                             corr_threshold = 0.9,
                                             print_stats = True)
    
    filename_norm_reduced_features = site_name+ "_reduced_features.csv"

    file_path_norm_reduced_features = os.path.join(site_specific_path, filename_norm_reduced_features)
    
    reduced_feature_dataframe.to_csv(file_path_norm_reduced_features, index=False)
    
    return CBE.get_feature_vector(reduced_feature_dataframe)

# %%
def apply_reduction(reduced_feature_set, site_name):
    
    dataframes_normalized_reduced_dict = {}

    site_specific_path = os.path.join(input_path, site_name)

    pattern = "[A-Z][0-9][0-9][0-9][0-9]_R[1-4]_mad_robustize.csv"
    file_list = glob.glob(site_specific_path + os.sep + '*' + os.sep + pattern, recursive=True)

    for file in file_list:
    
        plate_map_name = os.path.splitext(os.path.basename(file))[0]
    
        try:
        
            dataframe = pd.read_csv(file)
            row_count = dataframe.shape[0]
        
            print(f"INFO: {plate_map_name} has {row_count} rows")

            features = CBE.get_feature_vector(dataframe)
            metadata = set(dataframe.columns) - set(features)

            number_features = len(features)

            print(f"INFO: {plate_map_name} has {number_features} features")

            features_to_remove = [item for item in features if item not in reduced_feature_set]
    
            dataframe_reduced_features = dataframe.drop(columns = features_to_remove)

            reduced_features = CBE.get_feature_vector(dataframe_reduced_features)

            number_reduced_features = len(reduced_features)

            print(f"INFO: {plate_map_name} has {number_reduced_features} features after feature reduction")
    
            filename_norm_reduced_data = plate_map_name + "_reduced-corr.csv"
    
            path_norm_reduced_data = os.path.dirname(file)
            file_path_norm_reduced_data = os.path.join(path_norm_reduced_data, filename_norm_reduced_data)
    
            dataframe_reduced_features.to_csv(file_path_norm_reduced_data, index=False)
    
            print(f"INFO: Saved {filename_norm_reduced_data}")

            dict_key = dataframe_reduced_features['Metadata_staining_date'][0].astype(str) + "_" + dataframe_reduced_features['Metadata_source'][0] + "_" + dataframe_reduced_features['Metadata_plate_map_name'][0]

            dataframes_normalized_reduced_dict[dict_key] = dataframe_reduced_features
        
        except Exception as e:
        
            print(f"Error reading file {plate_map_name}: {e}")

# %%
fmp_feature_set = reduced_features('FMP')
apply_reduction(fmp_feature_set, 'FMP')
len(fmp_feature_set)

# %%
imtm_feature_set = reduced_features('IMTM')
apply_reduction(imtm_feature_set, 'IMTM')
len(imtm_feature_set)

# %%
# Some batches make issues with MEDINA. Addressed in 04b workbook
# medina_feature_set = reduced_features('MEDINA')
# apply_reduction(medina_feature_set, 'MEDINA')
# len(medina_feature_set)

# %%
usc_feature_set = reduced_features('USC')
apply_reduction(usc_feature_set, 'USC')
len(usc_feature_set)
# Out:
# INFO: C1216_R4_mad_robustize has 384 rows
# INFO: C1221_R2_mad_robustize has 384 rows
# INFO: C1157_R1_mad_robustize has 384 rows
# INFO: C1169_R4_mad_robustize has 384 rows
# INFO: C1167_R4_mad_robustize has 384 rows
# INFO: C1184_R1_mad_robustize has 384 rows
# INFO: C1179_R3_mad_robustize has 384 rows
# INFO: C1181_R4_mad_robustize has 384 rows
# INFO: C1213_R3_mad_robustize has 384 rows
# INFO: C1227_R2_mad_robustize has 384 rows
# INFO: C1166_R2_mad_robustize has 384 rows
# INFO: C1188_R3_mad_robustize has 384 rows
# INFO: C1182_R3_mad_robustize has 384 rows
# INFO: C1162_R4_mad_robustize has 384 rows
# INFO: C1159_R1_mad_robustize has 384 rows
# INFO: C1202_R4_mad_robustize has 384 rows
# INFO: C1196_R1_mad_robustize has 384 rows
# INFO: C1193_R1_mad_robustize has 384 rows
# INFO: C1193_R4_mad_robustize has 384 rows
# INFO: C1175_R1_mad_robustize has 384 rows
# INFO: C1193_R3_mad_robustize has 384 rows
# INFO: C1192_R3_mad_robustize has 384 rows
# INFO: C1158_R2_mad_robustize has 384 rows
# INFO: C1205_R3_mad_robustize has 384 rows
# INFO: C1222_R4_mad_robustize has 384 rows
# INFO: C1176_R2_mad_robustize has 384 rows
# INFO: C1203_R4_mad_robustize has 384 rows
# INFO: C1184_R4_mad_robustize has 384 rows
# INFO: C1186_R1_mad_robustize has 384 rows
# INFO: C1227_R1_mad_robustize has 384 rows
# INFO: C1178_R2_mad_robustize has 384 rows
# INFO: C1204_R2_mad_robustize has 384 rows
# INFO: C1164_R4_mad_robustize has 384 rows
# INFO: C1163_R3_mad_robustize has 384 rows
# INFO: C1198_R1_mad_robustize has 384 rows
# INFO: C1172_R3_mad_robustize has 384 rows
# INFO: C1205_R2_mad_robustize has 384 rows
# INFO: C1198_R4_mad_robustize has 384 rows
# INFO: C1205_R1_mad_robustize has 384 rows
# INFO: C1160_R1_mad_robustize has 384 rows
# INFO: C1159_R2_mad_robustize has 384 rows
# INFO: C1209_R4_mad_robustize has 384 rows
# INFO: USC03_R1_mad_robustize has 384 rows
# INFO: C1212_R3_mad_robustize has 384 rows
# INFO: C1224_R3_mad_robustize has 384 rows
# INFO: C1177_R1_mad_robustize has 384 rows
# INFO: C1185_R2_mad_robustize has 384 rows
# INFO: C1195_R4_mad_robustize has 384 rows
# INFO: C1215_R3_mad_robustize has 384 rows
# INFO: C1218_R4_mad_robustize has 384 rows
# INFO: C1225_R3_mad_robustize has 384 rows
# INFO: C1179_R1_mad_robustize has 384 rows
# INFO: C1226_R3_mad_robustize has 384 rows
# INFO: C1171_R2_mad_robustize has 384 rows
# INFO: C1201_R3_mad_robustize has 384 rows
# INFO: C1193_R2_mad_robustize has 384 rows
# INFO: C1212_R1_mad_robustize has 384 rows
# INFO: C1220_R3_mad_robustize has 384 rows
# INFO: C1176_R1_mad_robustize has 384 rows
# INFO: C1207_R4_mad_robustize has 384 rows
# INFO: C1173_R1_mad_robustize has 384 rows
# INFO: C1183_R1_mad_robustize has 384 rows
# INFO: C1187_R1_mad_robustize has 384 rows
# INFO: C1201_R1_mad_robustize has 384 rows
# INFO: USC05_R1_mad_robustize has 384 rows
# INFO: C1177_R4_mad_robustize has 384 rows
# INFO: C1189_R4_mad_robustize has 384 rows
# INFO: C1180_R3_mad_robustize has 384 rows
# INFO: C1221_R4_mad_robustize has 384 rows
# INFO: C1160_R2_mad_robustize has 384 rows
# INFO: C1191_R2_mad_robustize has 384 rows
# INFO: C1184_R3_mad_robustize has 384 rows
# INFO: C1194_R2_mad_robustize has 384 rows
# INFO: C1227_R4_mad_robustize has 384 rows
# INFO: C1178_R1_mad_robustize has 384 rows
# INFO: C1172_R4_mad_robustize has 384 rows
# INFO: C1224_R1_mad_robustize has 384 rows
# INFO: C1165_R1_mad_robustize has 384 rows
# INFO: C1204_R4_mad_robustize has 384 rows
# INFO: C1217_R2_mad_robustize has 384 rows
# INFO: C1158_R4_mad_robustize has 384 rows
# INFO: C1174_R2_mad_robustize has 384 rows
# INFO: C1160_R4_mad_robustize has 384 rows
# INFO: C1194_R4_mad_robustize has 384 rows
# INFO: C1185_R3_mad_robustize has 384 rows
# INFO: C1214_R2_mad_robustize has 384 rows
# INFO: C1210_R3_mad_robustize has 384 rows
# INFO: C1182_R4_mad_robustize has 384 rows
# INFO: C1190_R3_mad_robustize has 384 rows
# INFO: C1210_R4_mad_robustize has 384 rows
# INFO: C1163_R1_mad_robustize has 384 rows
# INFO: C1214_R4_mad_robustize has 384 rows
# INFO: C1192_R1_mad_robustize has 384 rows
# INFO: C1206_R2_mad_robustize has 384 rows
# INFO: C1211_R2_mad_robustize has 384 rows
# INFO: C1181_R3_mad_robustize has 384 rows
# INFO: C1193_R2_mad_robustize has 384 rows
# INFO: C1198_R2_mad_robustize has 384 rows
# INFO: C1171_R4_mad_robustize has 384 rows
# INFO: C1168_R4_mad_robustize has 384 rows
# INFO: C1180_R4_mad_robustize has 384 rows
# INFO: C1167_R1_mad_robustize has 384 rows
# INFO: C1229_R1_mad_robustize has 384 rows
# INFO: C1182_R3_mad_robustize has 384 rows
# INFO: C1223_R2_mad_robustize has 384 rows
# INFO: C1188_R2_mad_robustize has 384 rows
# INFO: C1163_R4_mad_robustize has 384 rows
# INFO: C1164_R3_mad_robustize has 384 rows
# INFO: C1170_R1_mad_robustize has 384 rows
# INFO: C1225_R2_mad_robustize has 384 rows
# INFO: C1203_R2_mad_robustize has 384 rows
# INFO: C1192_R4_mad_robustize has 384 rows
# INFO: C1166_R1_mad_robustize has 384 rows
# INFO: C1222_R3_mad_robustize has 384 rows
# INFO: C1159_R2_mad_robustize has 384 rows
# INFO: C1204_R3_mad_robustize has 384 rows
# INFO: C1160_R3_mad_robustize has 194 rows
# INFO: C1207_R1_mad_robustize has 384 rows
# INFO: C1192_R2_mad_robustize has 384 rows
# INFO: C1166_R4_mad_robustize has 384 rows
# INFO: C1172_R1_mad_robustize has 384 rows
# INFO: C1212_R2_mad_robustize has 384 rows
# INFO: C1195_R3_mad_robustize has 384 rows
# INFO: C1163_R3_mad_robustize has 384 rows
# INFO: C1182_R4_mad_robustize has 384 rows
# INFO: C1159_R3_mad_robustize has 384 rows
# INFO: USC04_R1_mad_robustize has 384 rows
# INFO: C1201_R4_mad_robustize has 384 rows
# INFO: C1173_R4_mad_robustize has 384 rows
# INFO: C1226_R1_mad_robustize has 384 rows
# INFO: C1200_R2_mad_robustize has 384 rows
# INFO: C1191_R1_mad_robustize has 384 rows
# INFO: C1186_R2_mad_robustize has 384 rows
# INFO: C1197_R1_mad_robustize has 384 rows
# INFO: C1210_R2_mad_robustize has 384 rows
# INFO: C1192_R1_mad_robustize has 384 rows
# INFO: C1159_R1_mad_robustize has 384 rows
# INFO: C1157_R4_mad_robustize has 384 rows
# INFO: C1194_R3_mad_robustize has 384 rows
# INFO: C1187_R3_mad_robustize has 384 rows
# INFO: C1170_R2_mad_robustize has 384 rows
# INFO: C1165_R2_mad_robustize has 384 rows
# INFO: C1172_R4_mad_robustize has 384 rows
# INFO: C1183_R4_mad_robustize has 384 rows
# INFO: C1226_R2_mad_robustize has 384 rows
# INFO: C1225_R4_mad_robustize has 384 rows
# INFO: C1157_R2_mad_robustize has 384 rows
# INFO: C1204_R1_mad_robustize has 384 rows
# INFO: C1161_R2_mad_robustize has 384 rows
# INFO: C1165_R4_mad_robustize has 384 rows
# INFO: C1226_R1_mad_robustize has 384 rows
# INFO: C1176_R4_mad_robustize has 384 rows
# INFO: C1202_R2_mad_robustize has 384 rows
# INFO: C1185_R1_mad_robustize has 384 rows
# INFO: C1157_R4_mad_robustize has 384 rows
# INFO: C1179_R2_mad_robustize has 384 rows
# INFO: C1208_R1_mad_robustize has 384 rows
# INFO: C1162_R2_mad_robustize has 384 rows
# INFO: C1215_R2_mad_robustize has 384 rows
# INFO: C1219_R2_mad_robustize has 384 rows
# INFO: C1212_R4_mad_robustize has 384 rows
# INFO: C1181_R2_mad_robustize has 384 rows
# INFO: C1207_R3_mad_robustize has 383 rows
# INFO: C1227_R3_mad_robustize has 384 rows
# INFO: C1178_R3_mad_robustize has 384 rows
# INFO: C1162_R4_mad_robustize has 384 rows
# INFO: C1217_R4_mad_robustize has 384 rows
# INFO: C1162_R1_mad_robustize has 384 rows
# INFO: C1229_R3_mad_robustize has 384 rows
# INFO: C1213_R2_mad_robustize has 384 rows
# INFO: C1162_R3_mad_robustize has 384 rows
# INFO: C1218_R2_mad_robustize has 384 rows
# INFO: C1221_R3_mad_robustize has 384 rows
# INFO: C1180_R2_mad_robustize has 384 rows
# INFO: C1162_R3_mad_robustize has 384 rows
# INFO: C1184_R2_mad_robustize has 384 rows
# INFO: C1169_R1_mad_robustize has 384 rows
# INFO: C1195_R1_mad_robustize has 384 rows
# INFO: C1218_R1_mad_robustize has 384 rows
# INFO: C1219_R1_mad_robustize has 384 rows
# INFO: C1206_R3_mad_robustize has 384 rows
# INFO: C1186_R2_mad_robustize has 384 rows
# INFO: C1170_R4_mad_robustize has 384 rows
# INFO: C1197_R4_mad_robustize has 384 rows
# INFO: C1215_R4_mad_robustize has 384 rows
# INFO: C1213_R1_mad_robustize has 384 rows
# INFO: C1168_R2_mad_robustize has 384 rows
# INFO: C1198_R3_mad_robustize has 384 rows
# INFO: C1162_R1_mad_robustize has 384 rows
# INFO: C1215_R1_mad_robustize has 384 rows
# INFO: C1197_R2_mad_robustize has 384 rows
# INFO: C1184_R4_mad_robustize has 384 rows
# INFO: C1196_R1_mad_robustize has 384 rows
# INFO: C1188_R2_mad_robustize has 384 rows
# INFO: C1161_R4_mad_robustize has 384 rows
# INFO: C1216_R1_mad_robustize has 384 rows
# INFO: C1209_R2_mad_robustize has 384 rows
# INFO: C1222_R1_mad_robustize has 384 rows
# INFO: C1209_R1_mad_robustize has 384 rows
# INFO: C1211_R1_mad_robustize has 384 rows
# INFO: C1172_R2_mad_robustize has 383 rows
# INFO: C1183_R2_mad_robustize has 384 rows
# INFO: C1214_R3_mad_robustize has 384 rows
# INFO: C1158_R1_mad_robustize has 384 rows
# INFO: C1171_R1_mad_robustize has 384 rows
# INFO: C1180_R1_mad_robustize has 384 rows
# INFO: USC02_R1_mad_robustize has 384 rows
# INFO: C1189_R4_mad_robustize has 384 rows
# INFO: C1196_R3_mad_robustize has 384 rows
# INFO: C1205_R4_mad_robustize has 384 rows
# INFO: C1216_R3_mad_robustize has 384 rows
# INFO: C1168_R3_mad_robustize has 384 rows
# INFO: C1202_R1_mad_robustize has 384 rows
# INFO: C1165_R3_mad_robustize has 384 rows
# INFO: C1222_R2_mad_robustize has 384 rows
# INFO: C1159_R3_mad_robustize has 384 rows
# INFO: C1164_R2_mad_robustize has 384 rows
# INFO: C1221_R1_mad_robustize has 384 rows
# INFO: C1163_R2_mad_robustize has 384 rows
# INFO: C1180_R1_mad_robustize has 384 rows
# INFO: C1214_R1_mad_robustize has 384 rows
# INFO: C1189_R2_mad_robustize has 384 rows
# INFO: C1185_R4_mad_robustize has 194 rows
# INFO: C1187_R4_mad_robustize has 384 rows
# INFO: C1160_R2_mad_robustize has 384 rows
# INFO: C1191_R1_mad_robustize has 384 rows
# INFO: C1177_R3_mad_robustize has 384 rows
# INFO: C1177_R2_mad_robustize has 384 rows
# INFO: C1229_R2_mad_robustize has 384 rows
# INFO: C1188_R4_mad_robustize has 384 rows
# INFO: C1186_R3_mad_robustize has 384 rows
# INFO: C1208_R3_mad_robustize has 384 rows
# INFO: C1206_R4_mad_robustize has 384 rows
# INFO: C1201_R2_mad_robustize has 384 rows
# INFO: C1216_R2_mad_robustize has 384 rows
# INFO: C1159_R4_mad_robustize has 384 rows
# INFO: C1200_R4_mad_robustize has 384 rows
# INFO: C1191_R4_mad_robustize has 384 rows
# INFO: C1175_R4_mad_robustize has 384 rows
# INFO: C1186_R1_mad_robustize has 384 rows
# INFO: C1176_R3_mad_robustize has 384 rows
# INFO: C1220_R4_mad_robustize has 384 rows
# INFO: C1224_R1_mad_robustize has 384 rows
# INFO: C1161_R3_mad_robustize has 384 rows
# INFO: C1175_R2_mad_robustize has 384 rows
# INFO: C1196_R2_mad_robustize has 384 rows
# INFO: C1171_R3_mad_robustize has 384 rows
# INFO: C1203_R3_mad_robustize has 384 rows
# INFO: C1173_R3_mad_robustize has 384 rows
# INFO: C1223_R1_mad_robustize has 384 rows
# INFO: C1212_R1_mad_robustize has 384 rows
# INFO: C1174_R4_mad_robustize has 384 rows
# INFO: C1173_R2_mad_robustize has 384 rows
# INFO: C1167_R3_mad_robustize has 384 rows
# INFO: C1228_R4_mad_robustize has 384 rows
# INFO: C1161_R1_mad_robustize has 384 rows
# INFO: C1158_R4_mad_robustize has 384 rows
# INFO: C1179_R4_mad_robustize has 384 rows
# INFO: C1208_R2_mad_robustize has 384 rows
# INFO: C1181_R1_mad_robustize has 384 rows
# INFO: C1193_R4_mad_robustize has 384 rows
# INFO: C1188_R1_mad_robustize has 384 rows
# INFO: C1209_R3_mad_robustize has 384 rows
# INFO: C1200_R1_mad_robustize has 384 rows
# INFO: C1191_R3_mad_robustize has 384 rows
# INFO: C1203_R1_mad_robustize has 384 rows
# INFO: C1160_R3_mad_robustize has 384 rows
# INFO: C1228_R1_mad_robustize has 384 rows
# INFO: C1185_R4_mad_robustize has 384 rows
# INFO: C1160_R4_mad_robustize has 384 rows
# INFO: C1199_R2_mad_robustize has 384 rows
# INFO: C1182_R2_mad_robustize has 384 rows
# INFO: C1175_R3_mad_robustize has 384 rows
# INFO: C1220_R2_mad_robustize has 384 rows
# INFO: USC01_R1_mad_robustize has 384 rows
# INFO: C1199_R4_mad_robustize has 384 rows
# INFO: C1190_R4_mad_robustize has 384 rows
# INFO: C1202_R3_mad_robustize has 384 rows
# INFO: C1186_R4_mad_robustize has 384 rows
# INFO: C1210_R1_mad_robustize has 384 rows
# INFO: C1169_R3_mad_robustize has 384 rows
# INFO: C1182_R1_mad_robustize has 384 rows
# INFO: C1187_R3_mad_robustize has 384 rows
# INFO: C1226_R4_mad_robustize has 384 rows
# INFO: C1206_R1_mad_robustize has 384 rows
# INFO: C1208_R4_mad_robustize has 384 rows
# INFO: C1228_R3_mad_robustize has 384 rows
# INFO: USC06_R1_mad_robustize has 384 rows
# INFO: C1224_R2_mad_robustize has 384 rows
# INFO: C1199_R3_mad_robustize has 384 rows
# INFO: C1200_R3_mad_robustize has 384 rows
# INFO: C1157_R3_mad_robustize has 384 rows
# INFO: C1183_R3_mad_robustize has 384 rows
# INFO: C1228_R2_mad_robustize has 384 rows
# INFO: C1174_R3_mad_robustize has 384 rows
# INFO: C1164_R1_mad_robustize has 384 rows
# INFO: C1189_R1_mad_robustize has 384 rows
# INFO: C1169_R2_mad_robustize has 384 rows
# INFO: C1197_R3_mad_robustize has 384 rows
# INFO: C1178_R4_mad_robustize has 384 rows
# INFO: C1157_R3_mad_robustize has 384 rows
# INFO: C1166_R3_mad_robustize has 384 rows
# INFO: C1225_R1_mad_robustize has 384 rows
# INFO: C1194_R1_mad_robustize has 384 rows
# INFO: C1217_R1_mad_robustize has 384 rows
# INFO: C1158_R3_mad_robustize has 384 rows
# INFO: C1211_R3_mad_robustize has 384 rows
# INFO: C1190_R1_mad_robustize has 384 rows
# INFO: C1158_R2_mad_robustize has 384 rows
# INFO: C1163_R1_mad_robustize has 384 rows
# INFO: C1229_R4_mad_robustize has 384 rows
# INFO: C1168_R1_mad_robustize has 384 rows
# INFO: C1170_R3_mad_robustize has 384 rows
# INFO: C1187_R2_mad_robustize has 384 rows
# INFO: C1190_R2_mad_robustize has 384 rows
# INFO: C1224_R4_mad_robustize has 384 rows
# INFO: C1220_R1_mad_robustize has 384 rows
# INFO: C1196_R4_mad_robustize has 384 rows
# INFO: C1199_R1_mad_robustize has 384 rows
# INFO: C1223_R3_mad_robustize has 384 rows
# INFO: C1223_R4_mad_robustize has 384 rows
# INFO: C1217_R3_mad_robustize has 384 rows
# INFO: C1189_R3_mad_robustize has 384 rows
# INFO: C1174_R1_mad_robustize has 384 rows
# INFO: C1211_R4_mad_robustize has 384 rows
# INFO: C1165_R3_mad_robustize has 384 rows
# INFO: C1219_R3_mad_robustize has 384 rows
# INFO: C1207_R2_mad_robustize has 384 rows
# INFO: C1157_R2_mad_robustize has 384 rows
# INFO: C1218_R3_mad_robustize has 384 rows
# INFO: C1219_R4_mad_robustize has 384 rows
# INFO: C1195_R2_mad_robustize has 384 rows
# INFO: C1213_R4_mad_robustize has 384 rows
# INFO: C1167_R2_mad_robustize has 384 rows
# Feature reduction with correlation threshold 0.9 and Outlier threshold 100
# | Category           |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:-------------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features     |                2977 |                 2807 |         94.3 |                2307 |        77.5 |                     613 |            20.6 |
# | Intensity          |                 180 |                  180 |        100   |                 149 |        82.8 |                      24 |            13.3 |
# | Correlation        |                 180 |                  120 |         66.7 |                  94 |        52.2 |                      73 |            40.6 |
# | AreaShape          |                 162 |                  152 |         93.8 |                 142 |        87.7 |                     109 |            67.3 |
# | Granularity        |                 192 |                  191 |         99.5 |                 170 |        88.5 |                      67 |            34.9 |
# | Neighbors          |                  21 |                   12 |         57.1 |                   5 |        23.8 |                       3 |            14.3 |
# | RadialDistribution |                 366 |                  279 |         76.2 |                 256 |        69.9 |                     163 |            44.5 |
# | Texture            |                1872 |                 1872 |        100   |                1491 |        79.6 |                     174 |             9.3 |
# | MitoSkeleton       |                   4 |                    1 |         25   |                   0 |         0   |                       0 |             0   |
#
# | Category       |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:---------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features |                2977 |                 2807 |         94.3 |                2307 |        77.5 |                     613 |            20.6 |
# | Nucleus        |                 921 |                  887 |         96.3 |                 720 |        78.2 |                     196 |            21.3 |
# | Cell           |                1035 |                  999 |         96.5 |                 822 |        79.4 |                     204 |            19.7 |
# | Cytoplasm      |                1021 |                  921 |         90.2 |                 765 |        74.9 |                     213 |            20.9 |
# INFO: C1216_R4_mad_robustize has 384 rows
# INFO: C1216_R4_mad_robustize has 2977 features
# INFO: C1216_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1216_R4_mad_robustize_reduced-corr.csv
# Error reading file C1216_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1221_R2_mad_robustize has 384 rows
# INFO: C1221_R2_mad_robustize has 2977 features
# INFO: C1221_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1221_R2_mad_robustize_reduced-corr.csv
# Error reading file C1221_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1157_R1_mad_robustize has 384 rows
# INFO: C1157_R1_mad_robustize has 2977 features
# INFO: C1157_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1157_R1_mad_robustize_reduced-corr.csv
# Error reading file C1157_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1169_R4_mad_robustize has 384 rows
# INFO: C1169_R4_mad_robustize has 2977 features
# INFO: C1169_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1169_R4_mad_robustize_reduced-corr.csv
# Error reading file C1169_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1167_R4_mad_robustize has 384 rows
# INFO: C1167_R4_mad_robustize has 2977 features
# INFO: C1167_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1167_R4_mad_robustize_reduced-corr.csv
# Error reading file C1167_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1184_R1_mad_robustize has 384 rows
# INFO: C1184_R1_mad_robustize has 2977 features
# INFO: C1184_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1184_R1_mad_robustize_reduced-corr.csv
# Error reading file C1184_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1179_R3_mad_robustize has 384 rows
# INFO: C1179_R3_mad_robustize has 2977 features
# INFO: C1179_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1179_R3_mad_robustize_reduced-corr.csv
# Error reading file C1179_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1181_R4_mad_robustize has 384 rows
# INFO: C1181_R4_mad_robustize has 2977 features
# INFO: C1181_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1181_R4_mad_robustize_reduced-corr.csv
# Error reading file C1181_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1213_R3_mad_robustize has 384 rows
# INFO: C1213_R3_mad_robustize has 2977 features
# INFO: C1213_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1213_R3_mad_robustize_reduced-corr.csv
# Error reading file C1213_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1227_R2_mad_robustize has 384 rows
# INFO: C1227_R2_mad_robustize has 2977 features
# INFO: C1227_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1227_R2_mad_robustize_reduced-corr.csv
# Error reading file C1227_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1166_R2_mad_robustize has 384 rows
# INFO: C1166_R2_mad_robustize has 2977 features
# INFO: C1166_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1166_R2_mad_robustize_reduced-corr.csv
# Error reading file C1166_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1188_R3_mad_robustize has 384 rows
# INFO: C1188_R3_mad_robustize has 2977 features
# INFO: C1188_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1188_R3_mad_robustize_reduced-corr.csv
# Error reading file C1188_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1182_R3_mad_robustize has 384 rows
# INFO: C1182_R3_mad_robustize has 2977 features
# INFO: C1182_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1182_R3_mad_robustize_reduced-corr.csv
# Error reading file C1182_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1162_R4_mad_robustize has 384 rows
# INFO: C1162_R4_mad_robustize has 2977 features
# INFO: C1162_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1162_R4_mad_robustize_reduced-corr.csv
# Error reading file C1162_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1159_R1_mad_robustize has 384 rows
# INFO: C1159_R1_mad_robustize has 2977 features
# INFO: C1159_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1159_R1_mad_robustize_reduced-corr.csv
# Error reading file C1159_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1202_R4_mad_robustize has 384 rows
# INFO: C1202_R4_mad_robustize has 2977 features
# INFO: C1202_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1202_R4_mad_robustize_reduced-corr.csv
# Error reading file C1202_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1196_R1_mad_robustize has 384 rows
# INFO: C1196_R1_mad_robustize has 2977 features
# INFO: C1196_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1196_R1_mad_robustize_reduced-corr.csv
# Error reading file C1196_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1193_R1_mad_robustize has 384 rows
# INFO: C1193_R1_mad_robustize has 2977 features
# INFO: C1193_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1193_R1_mad_robustize_reduced-corr.csv
# Error reading file C1193_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1193_R4_mad_robustize has 384 rows
# INFO: C1193_R4_mad_robustize has 2977 features
# INFO: C1193_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1193_R4_mad_robustize_reduced-corr.csv
# Error reading file C1193_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1175_R1_mad_robustize has 384 rows
# INFO: C1175_R1_mad_robustize has 2977 features
# INFO: C1175_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1175_R1_mad_robustize_reduced-corr.csv
# Error reading file C1175_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1193_R3_mad_robustize has 384 rows
# INFO: C1193_R3_mad_robustize has 2977 features
# INFO: C1193_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1193_R3_mad_robustize_reduced-corr.csv
# Error reading file C1193_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1192_R3_mad_robustize has 384 rows
# INFO: C1192_R3_mad_robustize has 2977 features
# INFO: C1192_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1192_R3_mad_robustize_reduced-corr.csv
# Error reading file C1192_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1158_R2_mad_robustize has 384 rows
# INFO: C1158_R2_mad_robustize has 2977 features
# INFO: C1158_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1158_R2_mad_robustize_reduced-corr.csv
# Error reading file C1158_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1205_R3_mad_robustize has 384 rows
# INFO: C1205_R3_mad_robustize has 2977 features
# INFO: C1205_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1205_R3_mad_robustize_reduced-corr.csv
# Error reading file C1205_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1222_R4_mad_robustize has 384 rows
# INFO: C1222_R4_mad_robustize has 2977 features
# INFO: C1222_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1222_R4_mad_robustize_reduced-corr.csv
# Error reading file C1222_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1176_R2_mad_robustize has 384 rows
# INFO: C1176_R2_mad_robustize has 2977 features
# INFO: C1176_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1176_R2_mad_robustize_reduced-corr.csv
# Error reading file C1176_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1203_R4_mad_robustize has 384 rows
# INFO: C1203_R4_mad_robustize has 2977 features
# INFO: C1203_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1203_R4_mad_robustize_reduced-corr.csv
# Error reading file C1203_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1184_R4_mad_robustize has 384 rows
# INFO: C1184_R4_mad_robustize has 2977 features
# INFO: C1184_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1184_R4_mad_robustize_reduced-corr.csv
# Error reading file C1184_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1186_R1_mad_robustize has 384 rows
# INFO: C1186_R1_mad_robustize has 2977 features
# INFO: C1186_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1186_R1_mad_robustize_reduced-corr.csv
# Error reading file C1186_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1227_R1_mad_robustize has 384 rows
# INFO: C1227_R1_mad_robustize has 2977 features
# INFO: C1227_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1227_R1_mad_robustize_reduced-corr.csv
# Error reading file C1227_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1178_R2_mad_robustize has 384 rows
# INFO: C1178_R2_mad_robustize has 2977 features
# INFO: C1178_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1178_R2_mad_robustize_reduced-corr.csv
# Error reading file C1178_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1204_R2_mad_robustize has 384 rows
# INFO: C1204_R2_mad_robustize has 2977 features
# INFO: C1204_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1204_R2_mad_robustize_reduced-corr.csv
# Error reading file C1204_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1164_R4_mad_robustize has 384 rows
# INFO: C1164_R4_mad_robustize has 2977 features
# INFO: C1164_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1164_R4_mad_robustize_reduced-corr.csv
# Error reading file C1164_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1163_R3_mad_robustize has 384 rows
# INFO: C1163_R3_mad_robustize has 2977 features
# INFO: C1163_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1163_R3_mad_robustize_reduced-corr.csv
# Error reading file C1163_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1198_R1_mad_robustize has 384 rows
# INFO: C1198_R1_mad_robustize has 2977 features
# INFO: C1198_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1198_R1_mad_robustize_reduced-corr.csv
# Error reading file C1198_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1172_R3_mad_robustize has 384 rows
# INFO: C1172_R3_mad_robustize has 2977 features
# INFO: C1172_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1172_R3_mad_robustize_reduced-corr.csv
# Error reading file C1172_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1205_R2_mad_robustize has 384 rows
# INFO: C1205_R2_mad_robustize has 2977 features
# INFO: C1205_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1205_R2_mad_robustize_reduced-corr.csv
# Error reading file C1205_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1198_R4_mad_robustize has 384 rows
# INFO: C1198_R4_mad_robustize has 2977 features
# INFO: C1198_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1198_R4_mad_robustize_reduced-corr.csv
# Error reading file C1198_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1205_R1_mad_robustize has 384 rows
# INFO: C1205_R1_mad_robustize has 2977 features
# INFO: C1205_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1205_R1_mad_robustize_reduced-corr.csv
# Error reading file C1205_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1160_R1_mad_robustize has 384 rows
# INFO: C1160_R1_mad_robustize has 2977 features
# INFO: C1160_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1160_R1_mad_robustize_reduced-corr.csv
# Error reading file C1160_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1159_R2_mad_robustize has 384 rows
# INFO: C1159_R2_mad_robustize has 2977 features
# INFO: C1159_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1159_R2_mad_robustize_reduced-corr.csv
# Error reading file C1159_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1209_R4_mad_robustize has 384 rows
# INFO: C1209_R4_mad_robustize has 2977 features
# INFO: C1209_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1209_R4_mad_robustize_reduced-corr.csv
# Error reading file C1209_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1212_R3_mad_robustize has 384 rows
# INFO: C1212_R3_mad_robustize has 2977 features
# INFO: C1212_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1212_R3_mad_robustize_reduced-corr.csv
# Error reading file C1212_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1224_R3_mad_robustize has 384 rows
# INFO: C1224_R3_mad_robustize has 2977 features
# INFO: C1224_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1224_R3_mad_robustize_reduced-corr.csv
# Error reading file C1224_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1177_R1_mad_robustize has 384 rows
# INFO: C1177_R1_mad_robustize has 2977 features
# INFO: C1177_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1177_R1_mad_robustize_reduced-corr.csv
# Error reading file C1177_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1185_R2_mad_robustize has 384 rows
# INFO: C1185_R2_mad_robustize has 2977 features
# INFO: C1185_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1185_R2_mad_robustize_reduced-corr.csv
# Error reading file C1185_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1195_R4_mad_robustize has 384 rows
# INFO: C1195_R4_mad_robustize has 2977 features
# INFO: C1195_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1195_R4_mad_robustize_reduced-corr.csv
# Error reading file C1195_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1215_R3_mad_robustize has 384 rows
# INFO: C1215_R3_mad_robustize has 2977 features
# INFO: C1215_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1215_R3_mad_robustize_reduced-corr.csv
# Error reading file C1215_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1218_R4_mad_robustize has 384 rows
# INFO: C1218_R4_mad_robustize has 2977 features
# INFO: C1218_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1218_R4_mad_robustize_reduced-corr.csv
# Error reading file C1218_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1225_R3_mad_robustize has 384 rows
# INFO: C1225_R3_mad_robustize has 2977 features
# INFO: C1225_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1225_R3_mad_robustize_reduced-corr.csv
# Error reading file C1225_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1179_R1_mad_robustize has 384 rows
# INFO: C1179_R1_mad_robustize has 2977 features
# INFO: C1179_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1179_R1_mad_robustize_reduced-corr.csv
# Error reading file C1179_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1226_R3_mad_robustize has 384 rows
# INFO: C1226_R3_mad_robustize has 2977 features
# INFO: C1226_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1226_R3_mad_robustize_reduced-corr.csv
# Error reading file C1226_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1171_R2_mad_robustize has 384 rows
# INFO: C1171_R2_mad_robustize has 2977 features
# INFO: C1171_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1171_R2_mad_robustize_reduced-corr.csv
# Error reading file C1171_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1201_R3_mad_robustize has 384 rows
# INFO: C1201_R3_mad_robustize has 2977 features
# INFO: C1201_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1201_R3_mad_robustize_reduced-corr.csv
# Error reading file C1201_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1193_R2_mad_robustize has 384 rows
# INFO: C1193_R2_mad_robustize has 2977 features
# INFO: C1193_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1193_R2_mad_robustize_reduced-corr.csv
# Error reading file C1193_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1212_R1_mad_robustize has 384 rows
# INFO: C1212_R1_mad_robustize has 2977 features
# INFO: C1212_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1212_R1_mad_robustize_reduced-corr.csv
# Error reading file C1212_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1220_R3_mad_robustize has 384 rows
# INFO: C1220_R3_mad_robustize has 2977 features
# INFO: C1220_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1220_R3_mad_robustize_reduced-corr.csv
# Error reading file C1220_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1176_R1_mad_robustize has 384 rows
# INFO: C1176_R1_mad_robustize has 2977 features
# INFO: C1176_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1176_R1_mad_robustize_reduced-corr.csv
# Error reading file C1176_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1207_R4_mad_robustize has 384 rows
# INFO: C1207_R4_mad_robustize has 2977 features
# INFO: C1207_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1207_R4_mad_robustize_reduced-corr.csv
# Error reading file C1207_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1173_R1_mad_robustize has 384 rows
# INFO: C1173_R1_mad_robustize has 2977 features
# INFO: C1173_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1173_R1_mad_robustize_reduced-corr.csv
# Error reading file C1173_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1183_R1_mad_robustize has 384 rows
# INFO: C1183_R1_mad_robustize has 2977 features
# INFO: C1183_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1183_R1_mad_robustize_reduced-corr.csv
# Error reading file C1183_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1187_R1_mad_robustize has 384 rows
# INFO: C1187_R1_mad_robustize has 2977 features
# INFO: C1187_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1187_R1_mad_robustize_reduced-corr.csv
# Error reading file C1187_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1201_R1_mad_robustize has 384 rows
# INFO: C1201_R1_mad_robustize has 2977 features
# INFO: C1201_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1201_R1_mad_robustize_reduced-corr.csv
# Error reading file C1201_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1177_R4_mad_robustize has 384 rows
# INFO: C1177_R4_mad_robustize has 2977 features
# INFO: C1177_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1177_R4_mad_robustize_reduced-corr.csv
# Error reading file C1177_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1189_R4_mad_robustize has 384 rows
# INFO: C1189_R4_mad_robustize has 2977 features
# INFO: C1189_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1189_R4_mad_robustize_reduced-corr.csv
# Error reading file C1189_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1180_R3_mad_robustize has 384 rows
# INFO: C1180_R3_mad_robustize has 2977 features
# INFO: C1180_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1180_R3_mad_robustize_reduced-corr.csv
# Error reading file C1180_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1221_R4_mad_robustize has 384 rows
# INFO: C1221_R4_mad_robustize has 2977 features
# INFO: C1221_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1221_R4_mad_robustize_reduced-corr.csv
# Error reading file C1221_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1160_R2_mad_robustize has 384 rows
# INFO: C1160_R2_mad_robustize has 2977 features
# INFO: C1160_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1160_R2_mad_robustize_reduced-corr.csv
# Error reading file C1160_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1191_R2_mad_robustize has 384 rows
# INFO: C1191_R2_mad_robustize has 2977 features
# INFO: C1191_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1191_R2_mad_robustize_reduced-corr.csv
# Error reading file C1191_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1184_R3_mad_robustize has 384 rows
# INFO: C1184_R3_mad_robustize has 2977 features
# INFO: C1184_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1184_R3_mad_robustize_reduced-corr.csv
# Error reading file C1184_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1194_R2_mad_robustize has 384 rows
# INFO: C1194_R2_mad_robustize has 2977 features
# INFO: C1194_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1194_R2_mad_robustize_reduced-corr.csv
# Error reading file C1194_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1227_R4_mad_robustize has 384 rows
# INFO: C1227_R4_mad_robustize has 2977 features
# INFO: C1227_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1227_R4_mad_robustize_reduced-corr.csv
# Error reading file C1227_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1178_R1_mad_robustize has 384 rows
# INFO: C1178_R1_mad_robustize has 2977 features
# INFO: C1178_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1178_R1_mad_robustize_reduced-corr.csv
# Error reading file C1178_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1172_R4_mad_robustize has 384 rows
# INFO: C1172_R4_mad_robustize has 2977 features
# INFO: C1172_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1172_R4_mad_robustize_reduced-corr.csv
# Error reading file C1172_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1224_R1_mad_robustize has 384 rows
# INFO: C1224_R1_mad_robustize has 2977 features
# INFO: C1224_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1224_R1_mad_robustize_reduced-corr.csv
# Error reading file C1224_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1165_R1_mad_robustize has 384 rows
# INFO: C1165_R1_mad_robustize has 2977 features
# INFO: C1165_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1165_R1_mad_robustize_reduced-corr.csv
# Error reading file C1165_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1204_R4_mad_robustize has 384 rows
# INFO: C1204_R4_mad_robustize has 2977 features
# INFO: C1204_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1204_R4_mad_robustize_reduced-corr.csv
# Error reading file C1204_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1217_R2_mad_robustize has 384 rows
# INFO: C1217_R2_mad_robustize has 2977 features
# INFO: C1217_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1217_R2_mad_robustize_reduced-corr.csv
# Error reading file C1217_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1158_R4_mad_robustize has 384 rows
# INFO: C1158_R4_mad_robustize has 2977 features
# INFO: C1158_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1158_R4_mad_robustize_reduced-corr.csv
# Error reading file C1158_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1174_R2_mad_robustize has 384 rows
# INFO: C1174_R2_mad_robustize has 2977 features
# INFO: C1174_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1174_R2_mad_robustize_reduced-corr.csv
# Error reading file C1174_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1160_R4_mad_robustize has 384 rows
# INFO: C1160_R4_mad_robustize has 2977 features
# INFO: C1160_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1160_R4_mad_robustize_reduced-corr.csv
# Error reading file C1160_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1194_R4_mad_robustize has 384 rows
# INFO: C1194_R4_mad_robustize has 2977 features
# INFO: C1194_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1194_R4_mad_robustize_reduced-corr.csv
# Error reading file C1194_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1185_R3_mad_robustize has 384 rows
# INFO: C1185_R3_mad_robustize has 2977 features
# INFO: C1185_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1185_R3_mad_robustize_reduced-corr.csv
# Error reading file C1185_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1214_R2_mad_robustize has 384 rows
# INFO: C1214_R2_mad_robustize has 2977 features
# INFO: C1214_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1214_R2_mad_robustize_reduced-corr.csv
# Error reading file C1214_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1210_R3_mad_robustize has 384 rows
# INFO: C1210_R3_mad_robustize has 2977 features
# INFO: C1210_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1210_R3_mad_robustize_reduced-corr.csv
# Error reading file C1210_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1182_R4_mad_robustize has 384 rows
# INFO: C1182_R4_mad_robustize has 2977 features
# INFO: C1182_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1182_R4_mad_robustize_reduced-corr.csv
# Error reading file C1182_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1190_R3_mad_robustize has 384 rows
# INFO: C1190_R3_mad_robustize has 2977 features
# INFO: C1190_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1190_R3_mad_robustize_reduced-corr.csv
# Error reading file C1190_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1210_R4_mad_robustize has 384 rows
# INFO: C1210_R4_mad_robustize has 2977 features
# INFO: C1210_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1210_R4_mad_robustize_reduced-corr.csv
# Error reading file C1210_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1163_R1_mad_robustize has 384 rows
# INFO: C1163_R1_mad_robustize has 2977 features
# INFO: C1163_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1163_R1_mad_robustize_reduced-corr.csv
# Error reading file C1163_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1214_R4_mad_robustize has 384 rows
# INFO: C1214_R4_mad_robustize has 2977 features
# INFO: C1214_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1214_R4_mad_robustize_reduced-corr.csv
# Error reading file C1214_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1192_R1_mad_robustize has 384 rows
# INFO: C1192_R1_mad_robustize has 2977 features
# INFO: C1192_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1192_R1_mad_robustize_reduced-corr.csv
# Error reading file C1192_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1206_R2_mad_robustize has 384 rows
# INFO: C1206_R2_mad_robustize has 2977 features
# INFO: C1206_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1206_R2_mad_robustize_reduced-corr.csv
# Error reading file C1206_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1211_R2_mad_robustize has 384 rows
# INFO: C1211_R2_mad_robustize has 2977 features
# INFO: C1211_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1211_R2_mad_robustize_reduced-corr.csv
# Error reading file C1211_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1181_R3_mad_robustize has 384 rows
# INFO: C1181_R3_mad_robustize has 2977 features
# INFO: C1181_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1181_R3_mad_robustize_reduced-corr.csv
# Error reading file C1181_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1193_R2_mad_robustize has 384 rows
# INFO: C1193_R2_mad_robustize has 2977 features
# INFO: C1193_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1193_R2_mad_robustize_reduced-corr.csv
# Error reading file C1193_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1198_R2_mad_robustize has 384 rows
# INFO: C1198_R2_mad_robustize has 2977 features
# INFO: C1198_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1198_R2_mad_robustize_reduced-corr.csv
# Error reading file C1198_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1171_R4_mad_robustize has 384 rows
# INFO: C1171_R4_mad_robustize has 2977 features
# INFO: C1171_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1171_R4_mad_robustize_reduced-corr.csv
# Error reading file C1171_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1168_R4_mad_robustize has 384 rows
# INFO: C1168_R4_mad_robustize has 2977 features
# INFO: C1168_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1168_R4_mad_robustize_reduced-corr.csv
# Error reading file C1168_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1180_R4_mad_robustize has 384 rows
# INFO: C1180_R4_mad_robustize has 2977 features
# INFO: C1180_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1180_R4_mad_robustize_reduced-corr.csv
# Error reading file C1180_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1167_R1_mad_robustize has 384 rows
# INFO: C1167_R1_mad_robustize has 2977 features
# INFO: C1167_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1167_R1_mad_robustize_reduced-corr.csv
# Error reading file C1167_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1229_R1_mad_robustize has 384 rows
# INFO: C1229_R1_mad_robustize has 2977 features
# INFO: C1229_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1229_R1_mad_robustize_reduced-corr.csv
# Error reading file C1229_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1182_R3_mad_robustize has 384 rows
# INFO: C1182_R3_mad_robustize has 2977 features
# INFO: C1182_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1182_R3_mad_robustize_reduced-corr.csv
# Error reading file C1182_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1223_R2_mad_robustize has 384 rows
# INFO: C1223_R2_mad_robustize has 2977 features
# INFO: C1223_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1223_R2_mad_robustize_reduced-corr.csv
# Error reading file C1223_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1188_R2_mad_robustize has 384 rows
# INFO: C1188_R2_mad_robustize has 2977 features
# INFO: C1188_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1188_R2_mad_robustize_reduced-corr.csv
# Error reading file C1188_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1163_R4_mad_robustize has 384 rows
# INFO: C1163_R4_mad_robustize has 2977 features
# INFO: C1163_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1163_R4_mad_robustize_reduced-corr.csv
# Error reading file C1163_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1164_R3_mad_robustize has 384 rows
# INFO: C1164_R3_mad_robustize has 2977 features
# INFO: C1164_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1164_R3_mad_robustize_reduced-corr.csv
# Error reading file C1164_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1170_R1_mad_robustize has 384 rows
# INFO: C1170_R1_mad_robustize has 2977 features
# ...
# INFO: Saved C1186_R4_mad_robustize_reduced-corr.csv
# Error reading file C1186_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1210_R1_mad_robustize has 384 rows
# INFO: C1210_R1_mad_robustize has 2977 features
# INFO: C1210_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1210_R1_mad_robustize_reduced-corr.csv
# Error reading file C1210_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1169_R3_mad_robustize has 384 rows
# INFO: C1169_R3_mad_robustize has 2977 features
# INFO: C1169_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1169_R3_mad_robustize_reduced-corr.csv
# Error reading file C1169_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1182_R1_mad_robustize has 384 rows
# INFO: C1182_R1_mad_robustize has 2977 features
# INFO: C1182_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1182_R1_mad_robustize_reduced-corr.csv
# Error reading file C1182_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1187_R3_mad_robustize has 384 rows
# INFO: C1187_R3_mad_robustize has 2977 features
# INFO: C1187_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1187_R3_mad_robustize_reduced-corr.csv
# Error reading file C1187_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1226_R4_mad_robustize has 384 rows
# INFO: C1226_R4_mad_robustize has 2977 features
# INFO: C1226_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1226_R4_mad_robustize_reduced-corr.csv
# Error reading file C1226_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1206_R1_mad_robustize has 384 rows
# INFO: C1206_R1_mad_robustize has 2977 features
# INFO: C1206_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1206_R1_mad_robustize_reduced-corr.csv
# Error reading file C1206_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1208_R4_mad_robustize has 384 rows
# INFO: C1208_R4_mad_robustize has 2977 features
# INFO: C1208_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1208_R4_mad_robustize_reduced-corr.csv
# Error reading file C1208_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1228_R3_mad_robustize has 384 rows
# INFO: C1228_R3_mad_robustize has 2977 features
# INFO: C1228_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1228_R3_mad_robustize_reduced-corr.csv
# Error reading file C1228_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1224_R2_mad_robustize has 384 rows
# INFO: C1224_R2_mad_robustize has 2977 features
# INFO: C1224_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1224_R2_mad_robustize_reduced-corr.csv
# Error reading file C1224_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1199_R3_mad_robustize has 384 rows
# INFO: C1199_R3_mad_robustize has 2977 features
# INFO: C1199_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1199_R3_mad_robustize_reduced-corr.csv
# Error reading file C1199_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1200_R3_mad_robustize has 384 rows
# INFO: C1200_R3_mad_robustize has 2977 features
# INFO: C1200_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1200_R3_mad_robustize_reduced-corr.csv
# Error reading file C1200_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1157_R3_mad_robustize has 384 rows
# INFO: C1157_R3_mad_robustize has 2977 features
# INFO: C1157_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1157_R3_mad_robustize_reduced-corr.csv
# Error reading file C1157_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1183_R3_mad_robustize has 384 rows
# INFO: C1183_R3_mad_robustize has 2977 features
# INFO: C1183_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1183_R3_mad_robustize_reduced-corr.csv
# Error reading file C1183_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1228_R2_mad_robustize has 384 rows
# INFO: C1228_R2_mad_robustize has 2977 features
# INFO: C1228_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1228_R2_mad_robustize_reduced-corr.csv
# Error reading file C1228_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1174_R3_mad_robustize has 384 rows
# INFO: C1174_R3_mad_robustize has 2977 features
# INFO: C1174_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1174_R3_mad_robustize_reduced-corr.csv
# Error reading file C1174_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1164_R1_mad_robustize has 384 rows
# INFO: C1164_R1_mad_robustize has 2977 features
# INFO: C1164_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1164_R1_mad_robustize_reduced-corr.csv
# Error reading file C1164_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1189_R1_mad_robustize has 384 rows
# INFO: C1189_R1_mad_robustize has 2977 features
# INFO: C1189_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1189_R1_mad_robustize_reduced-corr.csv
# Error reading file C1189_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1169_R2_mad_robustize has 384 rows
# INFO: C1169_R2_mad_robustize has 2977 features
# INFO: C1169_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1169_R2_mad_robustize_reduced-corr.csv
# Error reading file C1169_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1197_R3_mad_robustize has 384 rows
# INFO: C1197_R3_mad_robustize has 2977 features
# INFO: C1197_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1197_R3_mad_robustize_reduced-corr.csv
# Error reading file C1197_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1178_R4_mad_robustize has 384 rows
# INFO: C1178_R4_mad_robustize has 2977 features
# INFO: C1178_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1178_R4_mad_robustize_reduced-corr.csv
# Error reading file C1178_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1157_R3_mad_robustize has 384 rows
# INFO: C1157_R3_mad_robustize has 2977 features
# INFO: C1157_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1157_R3_mad_robustize_reduced-corr.csv
# Error reading file C1157_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1166_R3_mad_robustize has 384 rows
# INFO: C1166_R3_mad_robustize has 2977 features
# INFO: C1166_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1166_R3_mad_robustize_reduced-corr.csv
# Error reading file C1166_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1225_R1_mad_robustize has 384 rows
# INFO: C1225_R1_mad_robustize has 2977 features
# INFO: C1225_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1225_R1_mad_robustize_reduced-corr.csv
# Error reading file C1225_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1194_R1_mad_robustize has 384 rows
# INFO: C1194_R1_mad_robustize has 2977 features
# INFO: C1194_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1194_R1_mad_robustize_reduced-corr.csv
# Error reading file C1194_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1217_R1_mad_robustize has 384 rows
# INFO: C1217_R1_mad_robustize has 2977 features
# INFO: C1217_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1217_R1_mad_robustize_reduced-corr.csv
# Error reading file C1217_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1158_R3_mad_robustize has 384 rows
# INFO: C1158_R3_mad_robustize has 2977 features
# INFO: C1158_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1158_R3_mad_robustize_reduced-corr.csv
# Error reading file C1158_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1211_R3_mad_robustize has 384 rows
# INFO: C1211_R3_mad_robustize has 2977 features
# INFO: C1211_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1211_R3_mad_robustize_reduced-corr.csv
# Error reading file C1211_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1190_R1_mad_robustize has 384 rows
# INFO: C1190_R1_mad_robustize has 2977 features
# INFO: C1190_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1190_R1_mad_robustize_reduced-corr.csv
# Error reading file C1190_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1158_R2_mad_robustize has 384 rows
# INFO: C1158_R2_mad_robustize has 2977 features
# INFO: C1158_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1158_R2_mad_robustize_reduced-corr.csv
# Error reading file C1158_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1163_R1_mad_robustize has 384 rows
# INFO: C1163_R1_mad_robustize has 2977 features
# INFO: C1163_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1163_R1_mad_robustize_reduced-corr.csv
# Error reading file C1163_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1229_R4_mad_robustize has 384 rows
# INFO: C1229_R4_mad_robustize has 2977 features
# INFO: C1229_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1229_R4_mad_robustize_reduced-corr.csv
# Error reading file C1229_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1168_R1_mad_robustize has 384 rows
# INFO: C1168_R1_mad_robustize has 2977 features
# INFO: C1168_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1168_R1_mad_robustize_reduced-corr.csv
# Error reading file C1168_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1170_R3_mad_robustize has 384 rows
# INFO: C1170_R3_mad_robustize has 2977 features
# INFO: C1170_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1170_R3_mad_robustize_reduced-corr.csv
# Error reading file C1170_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1187_R2_mad_robustize has 384 rows
# INFO: C1187_R2_mad_robustize has 2977 features
# INFO: C1187_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1187_R2_mad_robustize_reduced-corr.csv
# Error reading file C1187_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1190_R2_mad_robustize has 384 rows
# INFO: C1190_R2_mad_robustize has 2977 features
# INFO: C1190_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1190_R2_mad_robustize_reduced-corr.csv
# Error reading file C1190_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1224_R4_mad_robustize has 384 rows
# INFO: C1224_R4_mad_robustize has 2977 features
# INFO: C1224_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1224_R4_mad_robustize_reduced-corr.csv
# Error reading file C1224_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1220_R1_mad_robustize has 384 rows
# INFO: C1220_R1_mad_robustize has 2977 features
# INFO: C1220_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1220_R1_mad_robustize_reduced-corr.csv
# Error reading file C1220_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1196_R4_mad_robustize has 384 rows
# INFO: C1196_R4_mad_robustize has 2977 features
# INFO: C1196_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1196_R4_mad_robustize_reduced-corr.csv
# Error reading file C1196_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1199_R1_mad_robustize has 384 rows
# INFO: C1199_R1_mad_robustize has 2977 features
# INFO: C1199_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1199_R1_mad_robustize_reduced-corr.csv
# Error reading file C1199_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1223_R3_mad_robustize has 384 rows
# INFO: C1223_R3_mad_robustize has 2977 features
# INFO: C1223_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1223_R3_mad_robustize_reduced-corr.csv
# Error reading file C1223_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1223_R4_mad_robustize has 384 rows
# INFO: C1223_R4_mad_robustize has 2977 features
# INFO: C1223_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1223_R4_mad_robustize_reduced-corr.csv
# Error reading file C1223_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1217_R3_mad_robustize has 384 rows
# INFO: C1217_R3_mad_robustize has 2977 features
# INFO: C1217_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1217_R3_mad_robustize_reduced-corr.csv
# Error reading file C1217_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1189_R3_mad_robustize has 384 rows
# INFO: C1189_R3_mad_robustize has 2977 features
# INFO: C1189_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1189_R3_mad_robustize_reduced-corr.csv
# Error reading file C1189_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1174_R1_mad_robustize has 384 rows
# INFO: C1174_R1_mad_robustize has 2977 features
# INFO: C1174_R1_mad_robustize has 613 features after feature reduction
# INFO: Saved C1174_R1_mad_robustize_reduced-corr.csv
# Error reading file C1174_R1_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1211_R4_mad_robustize has 384 rows
# INFO: C1211_R4_mad_robustize has 2977 features
# INFO: C1211_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1211_R4_mad_robustize_reduced-corr.csv
# Error reading file C1211_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1165_R3_mad_robustize has 384 rows
# INFO: C1165_R3_mad_robustize has 2977 features
# INFO: C1165_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1165_R3_mad_robustize_reduced-corr.csv
# Error reading file C1165_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1219_R3_mad_robustize has 384 rows
# INFO: C1219_R3_mad_robustize has 2977 features
# INFO: C1219_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1219_R3_mad_robustize_reduced-corr.csv
# Error reading file C1219_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1207_R2_mad_robustize has 384 rows
# INFO: C1207_R2_mad_robustize has 2977 features
# INFO: C1207_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1207_R2_mad_robustize_reduced-corr.csv
# Error reading file C1207_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1157_R2_mad_robustize has 384 rows
# INFO: C1157_R2_mad_robustize has 2977 features
# INFO: C1157_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1157_R2_mad_robustize_reduced-corr.csv
# Error reading file C1157_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1218_R3_mad_robustize has 384 rows
# INFO: C1218_R3_mad_robustize has 2977 features
# INFO: C1218_R3_mad_robustize has 613 features after feature reduction
# INFO: Saved C1218_R3_mad_robustize_reduced-corr.csv
# Error reading file C1218_R3_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1219_R4_mad_robustize has 384 rows
# INFO: C1219_R4_mad_robustize has 2977 features
# INFO: C1219_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1219_R4_mad_robustize_reduced-corr.csv
# Error reading file C1219_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1195_R2_mad_robustize has 384 rows
# INFO: C1195_R2_mad_robustize has 2977 features
# INFO: C1195_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1195_R2_mad_robustize_reduced-corr.csv
# Error reading file C1195_R2_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1213_R4_mad_robustize has 384 rows
# INFO: C1213_R4_mad_robustize has 2977 features
# INFO: C1213_R4_mad_robustize has 613 features after feature reduction
# INFO: Saved C1213_R4_mad_robustize_reduced-corr.csv
# Error reading file C1213_R4_mad_robustize: 'str' object has no attribute 'astype'
# INFO: C1167_R2_mad_robustize has 384 rows
# INFO: C1167_R2_mad_robustize has 2977 features
# INFO: C1167_R2_mad_robustize has 613 features after feature reduction
# INFO: Saved C1167_R2_mad_robustize_reduced-corr.csv
# Error reading file C1167_R2_mad_robustize: 'str' object has no attribute 'astype'
# 613
