# %%
import time
from datetime import date
import pandas as pd
import os
import glob
import pycytominer
import sys
import CBE_utils as CBE
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import gc

# %%
import importlib
importlib.reload(CBE)
# Out:
# <module 'CBE_utils' from '/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/notebooks_revision/CBE_utils.py'>

# %%
input_path = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/output/"

annotation_dir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/annotation/"
feature_dir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/reduced_features/"

# %% [markdown]
# # Test
# input_path = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/test_output/"
#
# annotation_dir = "/home/schmiedc/FMP_Docs/Projects/ECBL_Project/QualityControl_analysis_revision/test_annotation/"

# %%
# get folder list 
# load for each site the normalized files
# reduce the features selecting the correct feature list
folders = [name for name in os.listdir(input_path) if os.path.isdir(os.path.join(input_path, name))]

# %% [markdown]
# # Correlation based feature reduction

# %%
# compute new feature set for each site using correlation based feature redcution

def reduced_features(site_name):
    
    Data = []

    site_specific_path = os.path.join(input_path, site_name)
     
    # loads mad_robustize normalized data
    pattern = "[A-Z][0-9][0-9][0-9][0-9]_R[1-4]_mad_robustize.csv"
    file_list = glob.glob(site_specific_path + os.sep + '*' + os.sep + pattern, recursive=True)

    for file in file_list:
        
        plate_map_name = os.path.splitext(os.path.basename(file))[0]
        
        try:
            dataframe = pd.read_csv(file)
            row_count = dataframe.shape[0]

            Data.append(dataframe)
        
            print(f"INFO: {plate_map_name} has {row_count} rows")
        
        except Exception as e:
        
            print(f"Error reading file {filename}: {e}")

    print("Feature reduction with correlation threshold 0.9 and Outlier threshold 100")

    Data_aggregated = pd.concat(Data)
    Data_aggregated = Data_aggregated.reset_index(drop = True)
    reduced_feature_dataframe = CBE.feature_reduction(Data_aggregated,
                                             variance_freq_cut=0.1,
                                             variance_unique_cut=0.1,
                                             outlier_cutoff=100,
                                             corr_threshold = 0.9,
                                             print_stats = True)
    
    return CBE.get_feature_vector(reduced_feature_dataframe)

# %%
fmp_feature_set = reduced_features('FMP')
# Out:
# INFO: C1102_R4_mad_robustize has 384 rows
# INFO: C1096_R2_mad_robustize has 384 rows
# INFO: C1108_R4_mad_robustize has 383 rows
# INFO: C1120_R1_mad_robustize has 384 rows
# INFO: C1109_R1_mad_robustize has 384 rows
# INFO: C1097_R4_mad_robustize has 384 rows
# INFO: C1119_R4_mad_robustize has 384 rows
# INFO: C1084_R4_mad_robustize has 384 rows
# INFO: C1084_R2_mad_robustize has 384 rows
# INFO: C1103_R2_mad_robustize has 384 rows
# INFO: C1120_R2_mad_robustize has 384 rows
# INFO: C1112_R3_mad_robustize has 384 rows
# INFO: C1100_R2_mad_robustize has 384 rows
# INFO: C1092_R1_mad_robustize has 384 rows
# INFO: C1086_R4_mad_robustize has 384 rows
# INFO: C1093_R4_mad_robustize has 384 rows
# INFO: C1089_R1_mad_robustize has 384 rows
# INFO: C1102_R2_mad_robustize has 384 rows
# INFO: C1116_R2_mad_robustize has 384 rows
# INFO: C1087_R2_mad_robustize has 384 rows
# INFO: C1085_R2_mad_robustize has 384 rows
# INFO: C1112_R2_mad_robustize has 383 rows
# INFO: C1117_R1_mad_robustize has 384 rows
# INFO: C1088_R2_mad_robustize has 384 rows
# INFO: C1123_R2_mad_robustize has 354 rows
# INFO: C1120_R3_mad_robustize has 383 rows
# INFO: C1099_R3_mad_robustize has 384 rows
# INFO: C1099_R2_mad_robustize has 384 rows
# INFO: C1085_R1_mad_robustize has 384 rows
# INFO: C1110_R2_mad_robustize has 384 rows
# INFO: C1117_R4_mad_robustize has 384 rows
# INFO: C1103_R4_mad_robustize has 384 rows
# INFO: C1099_R1_mad_robustize has 378 rows
# INFO: C1123_R3_mad_robustize has 380 rows
# INFO: C1115_R4_mad_robustize has 384 rows
# INFO: C1111_R2_mad_robustize has 384 rows
# INFO: C1108_R1_mad_robustize has 384 rows
# INFO: C1117_R3_mad_robustize has 382 rows
# INFO: C1097_R3_mad_robustize has 384 rows
# INFO: C1122_R4_mad_robustize has 384 rows
# INFO: C1114_R4_mad_robustize has 384 rows
# INFO: C1119_R1_mad_robustize has 384 rows
# INFO: C1100_R3_mad_robustize has 384 rows
# INFO: C1105_R1_mad_robustize has 384 rows
# INFO: C1118_R2_mad_robustize has 384 rows
# INFO: C1108_R2_mad_robustize has 384 rows
# INFO: C1103_R1_mad_robustize has 382 rows
# INFO: C1109_R2_mad_robustize has 384 rows
# INFO: C1102_R1_mad_robustize has 378 rows
# INFO: C1093_R1_mad_robustize has 384 rows
# INFO: C1115_R1_mad_robustize has 384 rows
# INFO: C1102_R3_mad_robustize has 384 rows
# INFO: C1119_R3_mad_robustize has 384 rows
# INFO: C1123_R4_mad_robustize has 383 rows
# INFO: C1104_R3_mad_robustize has 304 rows
# INFO: C1107_R2_mad_robustize has 383 rows
# INFO: C1105_R2_mad_robustize has 384 rows
# INFO: C1094_R1_mad_robustize has 380 rows
# INFO: C1122_R1_mad_robustize has 384 rows
# INFO: C1094_R4_mad_robustize has 384 rows
# INFO: C1095_R1_mad_robustize has 375 rows
# INFO: C1105_R3_mad_robustize has 384 rows
# INFO: C1088_R4_mad_robustize has 384 rows
# INFO: C1092_R2_mad_robustize has 375 rows
# INFO: C1086_R2_mad_robustize has 384 rows
# INFO: C1116_R4_mad_robustize has 384 rows
# INFO: C1106_R2_mad_robustize has 384 rows
# INFO: C1091_R1_mad_robustize has 384 rows
# INFO: C1112_R4_mad_robustize has 383 rows
# INFO: C1121_R3_mad_robustize has 384 rows
# INFO: C1098_R1_mad_robustize has 370 rows
# INFO: C1106_R4_mad_robustize has 384 rows
# INFO: C1095_R4_mad_robustize has 384 rows
# INFO: C1111_R3_mad_robustize has 384 rows
# INFO: C1123_R1_mad_robustize has 384 rows
# INFO: C1104_R1_mad_robustize has 384 rows
# INFO: C1100_R1_mad_robustize has 371 rows
# INFO: C1087_R4_mad_robustize has 384 rows
# INFO: C1113_R1_mad_robustize has 384 rows
# INFO: C1101_R1_mad_robustize has 376 rows
# INFO: C1090_R4_mad_robustize has 384 rows
# INFO: C1106_R1_mad_robustize has 384 rows
# INFO: C1098_R4_mad_robustize has 384 rows
# INFO: C1095_R3_mad_robustize has 384 rows
# INFO: C1113_R4_mad_robustize has 384 rows
# INFO: C1091_R4_mad_robustize has 384 rows
# INFO: C1116_R1_mad_robustize has 384 rows
# INFO: C1112_R1_mad_robustize has 384 rows
# INFO: C1113_R2_mad_robustize has 384 rows
# INFO: C1108_R3_mad_robustize has 384 rows
# INFO: C1091_R2_mad_robustize has 383 rows
# INFO: C1096_R1_mad_robustize has 370 rows
# INFO: C1094_R3_mad_robustize has 384 rows
# INFO: C1118_R4_mad_robustize has 384 rows
# INFO: C1101_R2_mad_robustize has 384 rows
# INFO: C1110_R3_mad_robustize has 384 rows
# INFO: C1117_R2_mad_robustize has 384 rows
# INFO: C1109_R4_mad_robustize has 384 rows
# INFO: C1121_R4_mad_robustize has 384 rows
# INFO: C1100_R4_mad_robustize has 384 rows
# INFO: C1120_R4_mad_robustize has 384 rows
# INFO: C1122_R2_mad_robustize has 384 rows
# INFO: C1085_R4_mad_robustize has 384 rows
# INFO: C1093_R2_mad_robustize has 384 rows
# INFO: C1115_R3_mad_robustize has 383 rows
# INFO: C1098_R3_mad_robustize has 384 rows
# INFO: C1101_R4_mad_robustize has 384 rows
# INFO: C1121_R2_mad_robustize has 384 rows
# INFO: C1122_R3_mad_robustize has 383 rows
# INFO: C1096_R3_mad_robustize has 384 rows
# INFO: C1114_R1_mad_robustize has 384 rows
# INFO: C1104_R2_mad_robustize has 384 rows
# INFO: C1113_R3_mad_robustize has 384 rows
# INFO: C1101_R3_mad_robustize has 384 rows
# INFO: C1099_R4_mad_robustize has 384 rows
# INFO: C1096_R4_mad_robustize has 384 rows
# INFO: C1095_R2_mad_robustize has 384 rows
# INFO: C1086_R1_mad_robustize has 384 rows
# INFO: C1115_R2_mad_robustize has 384 rows
# INFO: C1121_R1_mad_robustize has 384 rows
# INFO: C1087_R1_mad_robustize has 384 rows
# INFO: C1098_R2_mad_robustize has 384 rows
# INFO: C1089_R2_mad_robustize has 384 rows
# INFO: C1089_R4_mad_robustize has 383 rows
# INFO: C1114_R3_mad_robustize has 382 rows
# INFO: C1092_R4_mad_robustize has 383 rows
# INFO: C1097_R2_mad_robustize has 384 rows
# INFO: C1119_R2_mad_robustize has 384 rows
# INFO: C1118_R1_mad_robustize has 384 rows
# INFO: C1110_R4_mad_robustize has 383 rows
# INFO: C1110_R1_mad_robustize has 384 rows
# INFO: C1088_R1_mad_robustize has 384 rows
# INFO: C1116_R3_mad_robustize has 382 rows
# INFO: C1107_R1_mad_robustize has 384 rows
# INFO: C1090_R1_mad_robustize has 384 rows
# INFO: C1109_R3_mad_robustize has 384 rows
# INFO: C1084_R1_mad_robustize has 384 rows
# INFO: C1097_R1_mad_robustize has 375 rows
# INFO: C1107_R3_mad_robustize has 384 rows
# INFO: C1107_R4_mad_robustize has 384 rows
# INFO: C1118_R3_mad_robustize has 383 rows
# INFO: C1111_R1_mad_robustize has 384 rows
# INFO: C1111_R4_mad_robustize has 384 rows
# INFO: C1090_R2_mad_robustize has 383 rows
# INFO: C1105_R4_mad_robustize has 384 rows
# INFO: C1114_R2_mad_robustize has 384 rows
# INFO: C1094_R2_mad_robustize has 384 rows
# Feature reduction with correlation threshold 0.9 and Outlier threshold 100
# | Category           |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:-------------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features     |                2977 |                 2300 |         77.3 |                1218 |        40.9 |                     389 |            13.1 |
# | Intensity          |                 180 |                  180 |        100   |                 106 |        58.9 |                      33 |            18.3 |
# | Correlation        |                 180 |                  122 |         67.8 |                  61 |        33.9 |                      50 |            27.8 |
# | AreaShape          |                 162 |                  151 |         93.2 |                  82 |        50.6 |                      66 |            40.7 |
# | Granularity        |                 192 |                  161 |         83.9 |                  45 |        23.4 |                      24 |            12.5 |
# | Neighbors          |                  21 |                   10 |         47.6 |                   3 |        14.3 |                       2 |             9.5 |
# | RadialDistribution |                 366 |                  272 |         74.3 |                  75 |        20.5 |                      57 |            15.6 |
# | Texture            |                1872 |                 1403 |         74.9 |                 846 |        45.2 |                     157 |             8.4 |
# | MitoSkeleton       |                   4 |                    1 |         25   |                   0 |         0   |                       0 |             0   |
#
# | Category       |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:---------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features |                2977 |                 2300 |         77.3 |                1218 |        40.9 |                     389 |            13.1 |
# | Nucleus        |                 921 |                  719 |         78.1 |                 393 |        42.7 |                     124 |            13.5 |
# | Cell           |                1035 |                  829 |         80.1 |                 403 |        38.9 |                     115 |            11.1 |
# | Cytoplasm      |                1021 |                  752 |         73.7 |                 422 |        41.3 |                     150 |            14.7 |

# %%
len(fmp_feature_set)
# Out:
# 389

# %%
imtm_feature_set = reduced_features('IMTM')
len(imtm_feature_set)
# Out:
# INFO: C1231_R1_mad_robustize has 384 rows
# INFO: C1269_R2_mad_robustize has 384 rows
# INFO: C1240_R4_mad_robustize has 384 rows
# INFO: C1260_R1_mad_robustize has 384 rows
# INFO: C1258_R2_mad_robustize has 384 rows
# INFO: C1270_R3_mad_robustize has 384 rows
# INFO: C1259_R1_mad_robustize has 384 rows
# INFO: C1283_R2_mad_robustize has 384 rows
# INFO: C1261_R1_mad_robustize has 384 rows
# INFO: C1245_R4_mad_robustize has 384 rows
# INFO: C1234_R3_mad_robustize has 384 rows
# INFO: C1263_R1_mad_robustize has 384 rows
# INFO: C1239_R1_mad_robustize has 384 rows
# INFO: C1261_R2_mad_robustize has 384 rows
# INFO: C1248_R1_mad_robustize has 384 rows
# INFO: C1241_R1_mad_robustize has 384 rows
# INFO: C1232_R3_mad_robustize has 384 rows
# INFO: C1251_R1_mad_robustize has 384 rows
# INFO: C1264_R4_mad_robustize has 384 rows
# INFO: C1264_R3_mad_robustize has 384 rows
# INFO: C1248_R2_mad_robustize has 384 rows
# INFO: C1272_R3_mad_robustize has 384 rows
# INFO: C1254_R4_mad_robustize has 384 rows
# INFO: C1247_R4_mad_robustize has 384 rows
# INFO: C1256_R3_mad_robustize has 384 rows
# INFO: C1255_R4_mad_robustize has 384 rows
# INFO: C1254_R3_mad_robustize has 384 rows
# INFO: C1233_R3_mad_robustize has 384 rows
# INFO: C1269_R3_mad_robustize has 384 rows
# INFO: C1249_R3_mad_robustize has 384 rows
# INFO: C1240_R1_mad_robustize has 384 rows
# INFO: C1237_R1_mad_robustize has 384 rows
# INFO: C1250_R3_mad_robustize has 384 rows
# INFO: C1233_R4_mad_robustize has 383 rows
# INFO: C1265_R1_mad_robustize has 384 rows
# INFO: C1242_R1_mad_robustize has 384 rows
# INFO: C1232_R1_mad_robustize has 384 rows
# INFO: C1264_R2_mad_robustize has 384 rows
# INFO: C1238_R3_mad_robustize has 384 rows
# INFO: C1242_R2_mad_robustize has 384 rows
# INFO: C1241_R4_mad_robustize has 384 rows
# INFO: C1250_R1_mad_robustize has 384 rows
# INFO: C1243_R3_mad_robustize has 384 rows
# INFO: C1255_R3_mad_robustize has 384 rows
# INFO: C1250_R2_mad_robustize has 384 rows
# INFO: C1268_R4_mad_robustize has 384 rows
# INFO: C1286_R1_mad_robustize has 384 rows
# INFO: C1277_R2_mad_robustize has 384 rows
# INFO: C1239_R4_mad_robustize has 366 rows
# INFO: C1260_R2_mad_robustize has 384 rows
# INFO: C1285_R1_mad_robustize has 384 rows
# INFO: C1278_R1_mad_robustize has 384 rows
# INFO: C1257_R3_mad_robustize has 384 rows
# INFO: C1247_R1_mad_robustize has 384 rows
# INFO: C1230_R3_mad_robustize has 384 rows
# INFO: C1257_R1_mad_robustize has 384 rows
# INFO: C1244_R2_mad_robustize has 384 rows
# INFO: C1264_R1_mad_robustize has 384 rows
# INFO: C1252_R3_mad_robustize has 384 rows
# INFO: C1253_R2_mad_robustize has 384 rows
# INFO: C1267_R1_mad_robustize has 384 rows
# INFO: C1266_R1_mad_robustize has 384 rows
# INFO: C1234_R4_mad_robustize has 384 rows
# INFO: C1251_R2_mad_robustize has 384 rows
# INFO: C1273_R3_mad_robustize has 384 rows
# INFO: C1230_R4_mad_robustize has 384 rows
# INFO: C1271_R2_mad_robustize has 384 rows
# INFO: C1244_R4_mad_robustize has 384 rows
# INFO: C1238_R2_mad_robustize has 384 rows
# INFO: C1248_R4_mad_robustize has 384 rows
# INFO: C1249_R2_mad_robustize has 384 rows
# INFO: C1258_R3_mad_robustize has 384 rows
# INFO: C1235_R4_mad_robustize has 384 rows
# INFO: C1250_R4_mad_robustize has 384 rows
# INFO: C1266_R2_mad_robustize has 384 rows
# INFO: C1252_R4_mad_robustize has 384 rows
# INFO: C1252_R2_mad_robustize has 384 rows
# INFO: C1235_R2_mad_robustize has 384 rows
# INFO: C1249_R1_mad_robustize has 384 rows
# INFO: C1287_R1_mad_robustize has 384 rows
# INFO: C1231_R4_mad_robustize has 384 rows
# INFO: C1246_R4_mad_robustize has 384 rows
# INFO: C1240_R3_mad_robustize has 384 rows
# INFO: C1269_R1_mad_robustize has 384 rows
# INFO: C1267_R4_mad_robustize has 384 rows
# INFO: C1272_R2_mad_robustize has 384 rows
# INFO: C1232_R2_mad_robustize has 384 rows
# INFO: C1244_R1_mad_robustize has 384 rows
# INFO: C1263_R2_mad_robustize has 384 rows
# INFO: C1253_R4_mad_robustize has 384 rows
# INFO: C1271_R1_mad_robustize has 384 rows
# INFO: C1241_R2_mad_robustize has 384 rows
# INFO: C1246_R2_mad_robustize has 384 rows
# INFO: C1262_R3_mad_robustize has 384 rows
# INFO: C1259_R3_mad_robustize has 384 rows
# INFO: C1237_R2_mad_robustize has 384 rows
# INFO: C1259_R2_mad_robustize has 384 rows
# INFO: C1267_R2_mad_robustize has 384 rows
# INFO: C1258_R4_mad_robustize has 384 rows
# INFO: C1235_R1_mad_robustize has 384 rows
# INFO: C1266_R4_mad_robustize has 384 rows
# INFO: C1258_R1_mad_robustize has 384 rows
# INFO: C1257_R4_mad_robustize has 384 rows
# INFO: C1273_R1_mad_robustize has 384 rows
# INFO: C1244_R3_mad_robustize has 384 rows
# INFO: C1230_R2_mad_robustize has 384 rows
# INFO: C1253_R1_mad_robustize has 384 rows
# INFO: C1231_R2_mad_robustize has 384 rows
# INFO: C1270_R1_mad_robustize has 361 rows
# INFO: C1256_R1_mad_robustize has 384 rows
# INFO: C1238_R1_mad_robustize has 384 rows
# INFO: C1267_R3_mad_robustize has 384 rows
# INFO: C1242_R4_mad_robustize has 384 rows
# INFO: C1260_R3_mad_robustize has 384 rows
# INFO: C1241_R3_mad_robustize has 384 rows
# INFO: C1256_R4_mad_robustize has 384 rows
# INFO: C1272_R1_mad_robustize has 384 rows
# INFO: C1257_R2_mad_robustize has 384 rows
# INFO: C1243_R2_mad_robustize has 384 rows
# INFO: C1242_R3_mad_robustize has 384 rows
# INFO: C1263_R3_mad_robustize has 384 rows
# INFO: C1254_R2_mad_robustize has 384 rows
# INFO: C1247_R2_mad_robustize has 384 rows
# INFO: C1263_R4_mad_robustize has 384 rows
# INFO: C1270_R4_mad_robustize has 384 rows
# INFO: C1232_R4_mad_robustize has 384 rows
# INFO: C1245_R2_mad_robustize has 384 rows
# INFO: C1254_R1_mad_robustize has 384 rows
# INFO: C1265_R4_mad_robustize has 384 rows
# INFO: C1249_R4_mad_robustize has 384 rows
# INFO: C1243_R1_mad_robustize has 384 rows
# INFO: C1268_R2_mad_robustize has 384 rows
# INFO: C1245_R1_mad_robustize has 384 rows
# INFO: C1245_R3_mad_robustize has 384 rows
# INFO: C1239_R2_mad_robustize has 384 rows
# INFO: C1243_R4_mad_robustize has 384 rows
# INFO: C1271_R4_mad_robustize has 384 rows
# INFO: C1240_R2_mad_robustize has 384 rows
# INFO: C1255_R2_mad_robustize has 384 rows
# INFO: C1230_R1_mad_robustize has 384 rows
# INFO: C1270_R2_mad_robustize has 384 rows
# INFO: C1259_R4_mad_robustize has 384 rows
# INFO: C1272_R4_mad_robustize has 384 rows
# INFO: C1273_R2_mad_robustize has 384 rows
# INFO: C1246_R3_mad_robustize has 384 rows
# INFO: C1247_R3_mad_robustize has 384 rows
# INFO: C1284_R1_mad_robustize has 384 rows
# INFO: C1231_R3_mad_robustize has 384 rows
# INFO: C1234_R1_mad_robustize has 384 rows
# INFO: C1269_R4_mad_robustize has 384 rows
# INFO: C1260_R4_mad_robustize has 384 rows
# INFO: C1235_R3_mad_robustize has 384 rows
# INFO: C1251_R3_mad_robustize has 384 rows
# INFO: C1252_R1_mad_robustize has 384 rows
# INFO: C1239_R3_mad_robustize has 384 rows
# INFO: C1251_R4_mad_robustize has 384 rows
# INFO: C1261_R3_mad_robustize has 384 rows
# INFO: C1237_R3_mad_robustize has 384 rows
# INFO: C1268_R3_mad_robustize has 384 rows
# INFO: C1268_R1_mad_robustize has 384 rows
# INFO: C1236_R2_mad_robustize has 384 rows
# INFO: C1255_R1_mad_robustize has 384 rows
# INFO: C1246_R1_mad_robustize has 384 rows
# INFO: C1256_R2_mad_robustize has 384 rows
# INFO: C1238_R4_mad_robustize has 384 rows
# INFO: C1236_R4_mad_robustize has 384 rows
# INFO: C1283_R1_mad_robustize has 384 rows
# INFO: C1265_R2_mad_robustize has 384 rows
# INFO: C1248_R3_mad_robustize has 384 rows
# INFO: C1237_R4_mad_robustize has 384 rows
# INFO: C1236_R3_mad_robustize has 384 rows
# INFO: C1233_R1_mad_robustize has 384 rows
# INFO: C1282_R2_mad_robustize has 384 rows
# INFO: C1262_R1_mad_robustize has 384 rows
# INFO: C1265_R3_mad_robustize has 384 rows
# INFO: C1234_R2_mad_robustize has 384 rows
# INFO: C1233_R2_mad_robustize has 384 rows
# INFO: C1271_R3_mad_robustize has 384 rows
# INFO: C1253_R3_mad_robustize has 384 rows
# Feature reduction with correlation threshold 0.9 and Outlier threshold 100
# | Category           |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:-------------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features     |                2977 |                 2334 |         78.4 |                1682 |        56.5 |                     617 |            20.7 |
# | Intensity          |                 180 |                  176 |         97.8 |                 126 |        70   |                      30 |            16.7 |
# | Correlation        |                 180 |                  129 |         71.7 |                  91 |        50.6 |                      73 |            40.6 |
# | AreaShape          |                 162 |                  151 |         93.2 |                 134 |        82.7 |                     111 |            68.5 |
# | Granularity        |                 192 |                  173 |         90.1 |                 123 |        64.1 |                      58 |            30.2 |
# | Neighbors          |                  21 |                   12 |         57.1 |                   5 |        23.8 |                       3 |            14.3 |
# | RadialDistribution |                 366 |                  278 |         76   |                 225 |        61.5 |                     180 |            49.2 |
# | Texture            |                1872 |                 1414 |         75.5 |                 978 |        52.2 |                     162 |             8.7 |
# | MitoSkeleton       |                   4 |                    1 |         25   |                   0 |         0   |                       0 |             0   |
#
# | Category       |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:---------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features |                2977 |                 2334 |         78.4 |                1682 |        56.5 |                     617 |            20.7 |
# | Nucleus        |                 921 |                  729 |         79.2 |                 517 |        56.1 |                     178 |            19.3 |
# | Cell           |                1035 |                  841 |         81.3 |                 628 |        60.7 |                     226 |            21.8 |
# | Cytoplasm      |                1021 |                  764 |         74.8 |                 537 |        52.6 |                     213 |            20.9 |
# 617

# %%
medina_feature_set = reduced_features('MEDINA')
len(medina_feature_set)
# Out:
# INFO: C1019_R3_mad_robustize has 384 rows
# INFO: C1048_R1_mad_robustize has 384 rows
# INFO: C1037_R1_mad_robustize has 384 rows
# INFO: C1035_R3_mad_robustize has 384 rows
# INFO: C1040_R1_mad_robustize has 384 rows
# INFO: C1049_R3_mad_robustize has 384 rows
# INFO: C1014_R1_mad_robustize has 378 rows
# INFO: C1014_R4_mad_robustize has 384 rows
# INFO: C1011_R4_mad_robustize has 384 rows
# INFO: C1057_R3_mad_robustize has 384 rows
# INFO: C1027_R2_mad_robustize has 384 rows
# INFO: C1012_R3_mad_robustize has 384 rows
# INFO: C1028_R3_mad_robustize has 384 rows
# INFO: C1020_R1_mad_robustize has 384 rows
# INFO: C1041_R4_mad_robustize has 384 rows
# INFO: C1040_R2_mad_robustize has 384 rows
# INFO: C1042_R4_mad_robustize has 384 rows
# INFO: C1052_R1_mad_robustize has 384 rows
# INFO: C1028_R3_mad_robustize has 384 rows
# INFO: C1052_R3_mad_robustize has 384 rows
# INFO: C1060_R3_mad_robustize has 384 rows
# INFO: C1016_R3_mad_robustize has 384 rows
# INFO: C1042_R1_mad_robustize has 384 rows
# INFO: C1053_R3_mad_robustize has 384 rows
# INFO: C1024_R4_mad_robustize has 384 rows
# INFO: C1036_R3_mad_robustize has 384 rows
# INFO: C1024_R3_mad_robustize has 384 rows
# INFO: C1025_R4_mad_robustize has 384 rows
# INFO: C1018_R1_mad_robustize has 384 rows
# INFO: C1028_R2_mad_robustize has 384 rows
# INFO: C1022_R4_mad_robustize has 383 rows
# INFO: C1030_R3_mad_robustize has 384 rows
# INFO: C1038_R4_mad_robustize has 384 rows
# INFO: C1034_R3_mad_robustize has 384 rows
# INFO: C1026_R3_mad_robustize has 384 rows
# INFO: C1034_R1_mad_robustize has 384 rows
# INFO: C1031_R1_mad_robustize has 384 rows
# INFO: C1027_R3_mad_robustize has 384 rows
# INFO: C1048_R4_mad_robustize has 384 rows
# INFO: C1058_R3_mad_robustize has 384 rows
# INFO: C1055_R1_mad_robustize has 384 rows
# INFO: C1013_R3_mad_robustize has 384 rows
# INFO: C1019_R4_mad_robustize has 384 rows
# INFO: C1011_R3_mad_robustize has 384 rows
# INFO: C1011_R1_mad_robustize has 384 rows
# INFO: C1017_R3_mad_robustize has 384 rows
# INFO: C1033_R1_mad_robustize has 384 rows
# INFO: C1049_R1_mad_robustize has 384 rows
# INFO: C1017_R2_mad_robustize has 384 rows
# INFO: C1047_R3_mad_robustize has 384 rows
# INFO: C1053_R2_mad_robustize has 384 rows
# INFO: C1036_R2_mad_robustize has 384 rows
# INFO: C1012_R2_mad_robustize has 224 rows
# INFO: C1038_R1_mad_robustize has 384 rows
# INFO: C1030_R3_mad_robustize has 384 rows
# INFO: C1033_R4_mad_robustize has 384 rows
# INFO: C1015_R3_mad_robustize has 384 rows
# INFO: C1033_R2_mad_robustize has 384 rows
# INFO: C1056_R3_mad_robustize has 384 rows
# INFO: C1022_R1_mad_robustize has 384 rows
# INFO: C1040_R3_mad_robustize has 384 rows
# INFO: C1024_R2_mad_robustize has 384 rows
# INFO: C1055_R3_mad_robustize has 384 rows
# INFO: C1036_R3_mad_robustize has 384 rows
# INFO: C1043_R3_mad_robustize has 384 rows
# INFO: C1018_R4_mad_robustize has 384 rows
# INFO: C1037_R2_mad_robustize has 384 rows
# INFO: C1050_R4_mad_robustize has 384 rows
# INFO: C1031_R3_mad_robustize has 384 rows
# INFO: C1037_R3_mad_robustize has 384 rows
# INFO: C1036_R4_mad_robustize has 384 rows
# INFO: C1051_R1_mad_robustize has 384 rows
# INFO: C1045_R2_mad_robustize has 384 rows
# INFO: C1025_R3_mad_robustize has 384 rows
# INFO: C1023_R2_mad_robustize has 384 rows
# INFO: C1021_R1_mad_robustize has 384 rows
# INFO: C1022_R3_mad_robustize has 384 rows
# INFO: C1025_R3_mad_robustize has 384 rows
# INFO: C1052_R4_mad_robustize has 384 rows
# INFO: C1046_R1_mad_robustize has 384 rows
# INFO: C1017_R3_mad_robustize has 384 rows
# INFO: C1029_R1_mad_robustize has 384 rows
# INFO: C1052_R2_mad_robustize has 384 rows
# INFO: C1044_R4_mad_robustize has 384 rows
# INFO: C1059_R3_mad_robustize has 384 rows
# INFO: C1016_R2_mad_robustize has 384 rows
# INFO: C1032_R3_mad_robustize has 384 rows
# INFO: C1018_R3_mad_robustize has 384 rows
# INFO: C1025_R1_mad_robustize has 384 rows
# INFO: C1032_R2_mad_robustize has 384 rows
# INFO: C1020_R4_mad_robustize has 384 rows
# INFO: C1031_R3_mad_robustize has 384 rows
# INFO: C1044_R1_mad_robustize has 384 rows
# INFO: C1029_R2_mad_robustize has 384 rows
# INFO: C1029_R3_mad_robustize has 384 rows
# INFO: C1046_R3_mad_robustize has 384 rows
# INFO: C1012_R3_mad_robustize has 384 rows
# INFO: C1053_R1_mad_robustize has 384 rows
# INFO: C1019_R2_mad_robustize has 384 rows
# INFO: C1031_R2_mad_robustize has 384 rows
# INFO: C1034_R4_mad_robustize has 384 rows
# INFO: C1040_R3_mad_robustize has 384 rows
# INFO: C1046_R2_mad_robustize has 384 rows
# INFO: C1015_R4_mad_robustize has 384 rows
# INFO: C1015_R3_mad_robustize has 384 rows
# INFO: C1054_R1_mad_robustize has 384 rows
# INFO: C1026_R2_mad_robustize has 384 rows
# INFO: C1025_R2_mad_robustize has 384 rows
# INFO: C1019_R1_mad_robustize has 384 rows
# INFO: C1050_R3_mad_robustize has 384 rows
# INFO: C1020_R3_mad_robustize has 384 rows
# INFO: C1039_R3_mad_robustize has 384 rows
# INFO: C1047_R1_mad_robustize has 384 rows
# INFO: C1039_R2_mad_robustize has 384 rows
# INFO: C1039_R4_mad_robustize has 384 rows
# INFO: C1027_R4_mad_robustize has 384 rows
# INFO: C1046_R4_mad_robustize has 384 rows
# INFO: C1012_R1_mad_robustize has 384 rows
# INFO: C1049_R4_mad_robustize has 384 rows
# INFO: C1047_R2_mad_robustize has 384 rows
# INFO: C1035_R1_mad_robustize has 384 rows
# INFO: C1014_R2_mad_robustize has 384 rows
# INFO: C1045_R1_mad_robustize has 384 rows
# INFO: C1035_R4_mad_robustize has 384 rows
# INFO: C1021_R4_mad_robustize has 384 rows
# INFO: C1022_R2_mad_robustize has 384 rows
# INFO: C1051_R4_mad_robustize has 384 rows
# INFO: C1032_R3_mad_robustize has 384 rows
# INFO: C1042_R3_mad_robustize has 384 rows
# INFO: C1035_R2_mad_robustize has 384 rows
# INFO: C1051_R2_mad_robustize has 384 rows
# INFO: C1013_R3_mad_robustize has 384 rows
# INFO: C1021_R3_mad_robustize has 384 rows
# INFO: C1021_R2_mad_robustize has 384 rows
# INFO: C1016_R4_mad_robustize has 384 rows
# INFO: C1012_R4_mad_robustize has 384 rows
# INFO: C1027_R3_mad_robustize has 384 rows
# INFO: C1017_R4_mad_robustize has 384 rows
# INFO: C1030_R1_mad_robustize has 384 rows
# INFO: C1034_R2_mad_robustize has 384 rows
# INFO: C1019_R3_mad_robustize has 384 rows
# INFO: C1029_R4_mad_robustize has 384 rows
# INFO: C1033_R3_mad_robustize has 384 rows
# INFO: C1028_R4_mad_robustize has 384 rows
# INFO: C1026_R4_mad_robustize has 384 rows
# INFO: C1043_R1_mad_robustize has 384 rows
# INFO: C1044_R3_mad_robustize has 384 rows
# INFO: C1029_R3_mad_robustize has 384 rows
# INFO: C1015_R2_mad_robustize has 384 rows
# INFO: C1038_R3_mad_robustize has 384 rows
# INFO: C1039_R3_mad_robustize has 384 rows
# INFO: C1028_R1_mad_robustize has 384 rows
# INFO: C1036_R1_mad_robustize has 384 rows
# INFO: C1014_R3_mad_robustize has 384 rows
# INFO: C1023_R1_mad_robustize has 384 rows
# INFO: C1024_R1_mad_robustize has 384 rows
# INFO: C1035_R3_mad_robustize has 384 rows
# INFO: C1018_R3_mad_robustize has 384 rows
# INFO: C1044_R2_mad_robustize has 383 rows
# INFO: C1050_R1_mad_robustize has 384 rows
# INFO: C1023_R3_mad_robustize has 384 rows
# INFO: C1054_R2_mad_robustize has 384 rows
# INFO: C1048_R2_mad_robustize has 384 rows
# INFO: C1030_R4_mad_robustize has 384 rows
# INFO: C1013_R4_mad_robustize has 384 rows
# INFO: C1027_R1_mad_robustize has 384 rows
# INFO: C1020_R2_mad_robustize has 384 rows
# INFO: C1022_R3_mad_robustize has 384 rows
# INFO: C1026_R1_mad_robustize has 384 rows
# INFO: C1037_R3_mad_robustize has 384 rows
# INFO: C1032_R4_mad_robustize has 384 rows
# INFO: C1031_R4_mad_robustize has 384 rows
# INFO: C1045_R3_mad_robustize has 384 rows
# INFO: C1011_R2_mad_robustize has 384 rows
# INFO: C1054_R3_mad_robustize has 384 rows
# INFO: C1042_R2_mad_robustize has 27 rows
# INFO: C1047_R4_mad_robustize has 384 rows
# INFO: C1038_R3_mad_robustize has 384 rows
# INFO: C1021_R3_mad_robustize has 384 rows
# INFO: C1013_R1_mad_robustize has 384 rows
# INFO: C1023_R4_mad_robustize has 384 rows
# INFO: C1014_R3_mad_robustize has 384 rows
# INFO: C1039_R1_mad_robustize has 384 rows
# INFO: C1050_R2_mad_robustize has 384 rows
# INFO: C1023_R3_mad_robustize has 384 rows
# INFO: C1045_R4_mad_robustize has 384 rows
# INFO: C1032_R1_mad_robustize has 384 rows
# INFO: C1011_R3_mad_robustize has 224 rows
# INFO: C1024_R3_mad_robustize has 384 rows
# INFO: C1030_R2_mad_robustize has 384 rows
# INFO: C1051_R3_mad_robustize has 384 rows
# INFO: C1033_R3_mad_robustize has 384 rows
# INFO: C1043_R2_mad_robustize has 384 rows
# INFO: C1013_R2_mad_robustize has 384 rows
# INFO: C1043_R4_mad_robustize has 384 rows
# INFO: C1017_R1_mad_robustize has 384 rows
# INFO: C1040_R4_mad_robustize has 384 rows
# INFO: C1041_R3_mad_robustize has 384 rows
# INFO: C1026_R3_mad_robustize has 384 rows
# INFO: C1016_R3_mad_robustize has 384 rows
# INFO: C1034_R3_mad_robustize has 384 rows
# INFO: C1038_R2_mad_robustize has 384 rows
# INFO: C1018_R2_mad_robustize has 384 rows
# Feature reduction with correlation threshold 0.9 and Outlier threshold 100
# | Category           |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:-------------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features     |                2977 |                 2803 |         94.2 |                2227 |        74.8 |                     624 |            21   |
# | Intensity          |                 180 |                  180 |        100   |                 173 |        96.1 |                      33 |            18.3 |
# | Correlation        |                 180 |                  116 |         64.4 |                 102 |        56.7 |                      68 |            37.8 |
# | AreaShape          |                 162 |                  150 |         92.6 |                 133 |        82.1 |                     109 |            67.3 |
# | Granularity        |                 192 |                  191 |         99.5 |                 156 |        81.2 |                      68 |            35.4 |
# | Neighbors          |                  21 |                   12 |         57.1 |                   6 |        28.6 |                       4 |            19   |
# | RadialDistribution |                 366 |                  281 |         76.8 |                 270 |        73.8 |                     173 |            47.3 |
# | Texture            |                1872 |                 1872 |        100   |                1387 |        74.1 |                     169 |             9   |
# | MitoSkeleton       |                   4 |                    1 |         25   |                   0 |         0   |                       0 |             0   |
#
# | Category       |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:---------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features |                2977 |                 2803 |         94.2 |                2227 |        74.8 |                     624 |            21   |
# | Nucleus        |                 921 |                  884 |         96   |                 682 |        74   |                     180 |            19.5 |
# | Cell           |                1035 |                  999 |         96.5 |                 779 |        75.3 |                     200 |            19.3 |
# | Cytoplasm      |                1021 |                  920 |         90.1 |                 766 |        75   |                     244 |            23.9 |
# 624

# %%
usc_feature_set = reduced_features('USC')
len(usc_feature_set)
# Out:
# INFO: C1216_R4_mad_robustize has 384 rows
# INFO: C1169_R4_mad_robustize has 384 rows
# INFO: C1167_R4_mad_robustize has 384 rows
# INFO: C1184_R1_mad_robustize has 384 rows
# INFO: C1181_R4_mad_robustize has 384 rows
# INFO: C1166_R2_mad_robustize has 384 rows
# INFO: C1162_R4_mad_robustize has 384 rows
# INFO: C1193_R1_mad_robustize has 384 rows
# INFO: C1220_R1_mad_robustize has 384 rows
# INFO: C1175_R1_mad_robustize has 384 rows
# INFO: C1218_R4_mad_robustize has 384 rows
# INFO: C1160_R2_mad_robustize has 384 rows
# INFO: C1160_R3_mad_robustize has 384 rows
# INFO: C1203_R4_mad_robustize has 384 rows
# INFO: C1197_R4_mad_robustize has 384 rows
# INFO: C1165_R2_mad_robustize has 384 rows
# INFO: C1198_R1_mad_robustize has 384 rows
# INFO: C1205_R1_mad_robustize has 384 rows
# INFO: C1158_R1_mad_robustize has 384 rows
# INFO: C1204_R3_mad_robustize has 384 rows
# INFO: C1224_R3_mad_robustize has 384 rows
# INFO: C1195_R4_mad_robustize has 384 rows
# INFO: C1171_R2_mad_robustize has 384 rows
# INFO: C1188_R1_mad_robustize has 384 rows
# INFO: C1219_R4_mad_robustize has 384 rows
# INFO: C1212_R1_mad_robustize has 384 rows
# INFO: C1176_R1_mad_robustize has 384 rows
# INFO: C1183_R1_mad_robustize has 384 rows
# INFO: C1167_R3_mad_robustize has 384 rows
# INFO: C1200_R4_mad_robustize has 384 rows
# INFO: C1177_R4_mad_robustize has 384 rows
# INFO: C1189_R1_mad_robustize has 384 rows
# INFO: C1183_R3_mad_robustize has 384 rows
# INFO: C1211_R2_mad_robustize has 384 rows
# INFO: C1188_R4_mad_robustize has 384 rows
# INFO: C1178_R2_mad_robustize has 384 rows
# INFO: C1227_R4_mad_robustize has 384 rows
# INFO: C1172_R4_mad_robustize has 384 rows
# INFO: C1204_R4_mad_robustize has 384 rows
# INFO: C1204_R2_mad_robustize has 384 rows
# INFO: C1222_R1_mad_robustize has 384 rows
# INFO: C1202_R1_mad_robustize has 384 rows
# INFO: C1194_R4_mad_robustize has 384 rows
# INFO: C1180_R4_mad_robustize has 384 rows
# INFO: C1192_R4_mad_robustize has 384 rows
# INFO: C1192_R1_mad_robustize has 384 rows
# INFO: C1214_R4_mad_robustize has 384 rows
# INFO: C1208_R4_mad_robustize has 384 rows
# INFO: C1184_R2_mad_robustize has 384 rows
# INFO: C1168_R4_mad_robustize has 384 rows
# INFO: C1167_R1_mad_robustize has 384 rows
# INFO: C1211_R3_mad_robustize has 384 rows
# INFO: C1212_R2_mad_robustize has 384 rows
# INFO: C1179_R4_mad_robustize has 384 rows
# INFO: C1190_R3_mad_robustize has 384 rows
# INFO: C1219_R1_mad_robustize has 384 rows
# INFO: C1222_R4_mad_robustize has 384 rows
# INFO: C1166_R3_mad_robustize has 384 rows
# INFO: C1171_R3_mad_robustize has 384 rows
# INFO: C1198_R4_mad_robustize has 384 rows
# INFO: C1166_R1_mad_robustize has 384 rows
# INFO: C1229_R4_mad_robustize has 384 rows
# INFO: C1184_R3_mad_robustize has 384 rows
# INFO: C1174_R3_mad_robustize has 384 rows
# INFO: C1192_R3_mad_robustize has 384 rows
# INFO: C1207_R1_mad_robustize has 384 rows
# INFO: C1171_R4_mad_robustize has 384 rows
# INFO: C1199_R4_mad_robustize has 384 rows
# INFO: C1166_R4_mad_robustize has 384 rows
# INFO: C1220_R4_mad_robustize has 384 rows
# INFO: C1182_R2_mad_robustize has 384 rows
# INFO: C1202_R4_mad_robustize has 384 rows
# INFO: C1182_R4_mad_robustize has 384 rows
# INFO: C1172_R3_mad_robustize has 384 rows
# INFO: C1173_R4_mad_robustize has 384 rows
# INFO: C1188_R2_mad_robustize has 384 rows
# INFO: C1200_R1_mad_robustize has 384 rows
# INFO: C1197_R1_mad_robustize has 384 rows
# INFO: C1228_R4_mad_robustize has 384 rows
# INFO: C1179_R2_mad_robustize has 384 rows
# INFO: C1189_R2_mad_robustize has 384 rows
# INFO: C1158_R4_mad_robustize has 384 rows
# INFO: C1170_R2_mad_robustize has 384 rows
# INFO: C1183_R4_mad_robustize has 384 rows
# INFO: C1225_R4_mad_robustize has 384 rows
# INFO: C1158_R2_mad_robustize has 384 rows
# INFO: C1211_R4_mad_robustize has 384 rows
# INFO: C1170_R3_mad_robustize has 384 rows
# INFO: C1210_R4_mad_robustize has 384 rows
# INFO: C1204_R1_mad_robustize has 384 rows
# INFO: C1209_R1_mad_robustize has 384 rows
# INFO: C1201_R4_mad_robustize has 384 rows
# INFO: C1176_R4_mad_robustize has 384 rows
# INFO: C1191_R1_mad_robustize has 384 rows
# INFO: C1216_R1_mad_robustize has 384 rows
# INFO: C1176_R2_mad_robustize has 384 rows
# INFO: C1170_R1_mad_robustize has 384 rows
# INFO: C1157_R4_mad_robustize has 384 rows
# INFO: C1187_R1_mad_robustize has 384 rows
# INFO: C1162_R2_mad_robustize has 384 rows
# INFO: C1187_R2_mad_robustize has 384 rows
# INFO: C1203_R3_mad_robustize has 384 rows
# INFO: C1162_R1_mad_robustize has 384 rows
# INFO: C1201_R1_mad_robustize has 384 rows
# INFO: C1185_R1_mad_robustize has 384 rows
# INFO: C1189_R3_mad_robustize has 384 rows
# INFO: C1163_R3_mad_robustize has 384 rows
# INFO: C1162_R3_mad_robustize has 384 rows
# INFO: C1159_R4_mad_robustize has 384 rows
# INFO: C1169_R1_mad_robustize has 384 rows
# INFO: C1195_R1_mad_robustize has 384 rows
# INFO: C1218_R1_mad_robustize has 384 rows
# INFO: C1210_R2_mad_robustize has 384 rows
# INFO: C1177_R1_mad_robustize has 384 rows
# INFO: C1170_R4_mad_robustize has 384 rows
# INFO: C1215_R4_mad_robustize has 384 rows
# INFO: C1179_R1_mad_robustize has 384 rows
# INFO: C1213_R1_mad_robustize has 384 rows
# INFO: C1173_R3_mad_robustize has 384 rows
# INFO: C1215_R1_mad_robustize has 384 rows
# INFO: C1212_R4_mad_robustize has 384 rows
# INFO: C1181_R3_mad_robustize has 384 rows
# INFO: C1210_R1_mad_robustize has 384 rows
# INFO: C1184_R4_mad_robustize has 384 rows
# INFO: C1196_R1_mad_robustize has 384 rows
# INFO: C1173_R2_mad_robustize has 384 rows
# INFO: C1172_R2_mad_robustize has 383 rows
# INFO: C1171_R1_mad_robustize has 384 rows
# INFO: C1177_R2_mad_robustize has 384 rows
# INFO: C1181_R2_mad_robustize has 384 rows
# INFO: C1205_R4_mad_robustize has 384 rows
# INFO: C1180_R3_mad_robustize has 384 rows
# INFO: C1179_R3_mad_robustize has 384 rows
# INFO: C1178_R3_mad_robustize has 384 rows
# INFO: C1210_R3_mad_robustize has 384 rows
# INFO: C1159_R2_mad_robustize has 384 rows
# INFO: C1185_R2_mad_robustize has 384 rows
# INFO: C1160_R1_mad_robustize has 384 rows
# INFO: C1214_R1_mad_robustize has 384 rows
# INFO: C1192_R2_mad_robustize has 384 rows
# INFO: C1157_R3_mad_robustize has 384 rows
# INFO: C1182_R3_mad_robustize has 384 rows
# INFO: C1168_R2_mad_robustize has 384 rows
# INFO: C1190_R4_mad_robustize has 384 rows
# INFO: C1217_R4_mad_robustize has 384 rows
# INFO: C1212_R3_mad_robustize has 384 rows
# INFO: C1180_R1_mad_robustize has 384 rows
# INFO: C1206_R4_mad_robustize has 384 rows
# INFO: C1175_R4_mad_robustize has 384 rows
# INFO: C1186_R1_mad_robustize has 384 rows
# INFO: C1186_R3_mad_robustize has 384 rows
# INFO: C1180_R2_mad_robustize has 384 rows
# INFO: C1174_R2_mad_robustize has 384 rows
# INFO: C1174_R4_mad_robustize has 384 rows
# INFO: C1187_R3_mad_robustize has 384 rows
# INFO: C1172_R1_mad_robustize has 384 rows
# INFO: C1178_R1_mad_robustize has 384 rows
# INFO: C1208_R1_mad_robustize has 384 rows
# INFO: C1221_R4_mad_robustize has 384 rows
# INFO: C1181_R1_mad_robustize has 384 rows
# INFO: C1193_R4_mad_robustize has 384 rows
# INFO: C1173_R1_mad_robustize has 384 rows
# INFO: C1223_R4_mad_robustize has 384 rows
# INFO: C1175_R3_mad_robustize has 384 rows
# INFO: C1203_R1_mad_robustize has 384 rows
# INFO: C1185_R4_mad_robustize has 384 rows
# INFO: C1206_R1_mad_robustize has 384 rows
# INFO: C1207_R4_mad_robustize has 384 rows
# INFO: C1160_R4_mad_robustize has 384 rows
# INFO: C1188_R3_mad_robustize has 384 rows
# INFO: C1177_R3_mad_robustize has 384 rows
# INFO: C1164_R3_mad_robustize has 384 rows
# INFO: C1191_R3_mad_robustize has 384 rows
# INFO: C1187_R4_mad_robustize has 384 rows
# INFO: C1186_R4_mad_robustize has 384 rows
# INFO: C1182_R1_mad_robustize has 384 rows
# INFO: C1226_R4_mad_robustize has 384 rows
# INFO: C1208_R3_mad_robustize has 384 rows
# INFO: C1209_R4_mad_robustize has 384 rows
# INFO: C1164_R1_mad_robustize has 384 rows
# INFO: C1157_R1_mad_robustize has 384 rows
# INFO: C1169_R2_mad_robustize has 384 rows
# INFO: C1178_R4_mad_robustize has 384 rows
# INFO: C1168_R3_mad_robustize has 384 rows
# INFO: C1183_R2_mad_robustize has 384 rows
# INFO: C1199_R1_mad_robustize has 384 rows
# INFO: C1194_R1_mad_robustize has 384 rows
# INFO: C1165_R4_mad_robustize has 384 rows
# INFO: C1217_R1_mad_robustize has 384 rows
# INFO: C1191_R2_mad_robustize has 384 rows
# INFO: C1159_R3_mad_robustize has 384 rows
# INFO: C1163_R1_mad_robustize has 384 rows
# INFO: C1168_R1_mad_robustize has 384 rows
# INFO: C1224_R4_mad_robustize has 384 rows
# INFO: C1228_R3_mad_robustize has 384 rows
# INFO: C1196_R4_mad_robustize has 384 rows
# INFO: C1185_R3_mad_robustize has 384 rows
# INFO: C1176_R3_mad_robustize has 384 rows
# INFO: C1223_R3_mad_robustize has 384 rows
# INFO: C1175_R2_mad_robustize has 384 rows
# INFO: C1169_R3_mad_robustize has 384 rows
# INFO: C1174_R1_mad_robustize has 384 rows
# INFO: C1165_R3_mad_robustize has 384 rows
# INFO: C1189_R4_mad_robustize has 384 rows
# INFO: C1213_R4_mad_robustize has 384 rows
# INFO: C1221_R1_mad_robustize has 384 rows
# INFO: C1167_R2_mad_robustize has 384 rows
# INFO: C1191_R4_mad_robustize has 384 rows
# Feature reduction with correlation threshold 0.9 and Outlier threshold 100
# | Category           |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:-------------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features     |                2977 |                 2805 |         94.2 |                2406 |        80.8 |                     666 |            22.4 |
# | Intensity          |                 180 |                  180 |        100   |                 151 |        83.9 |                      22 |            12.2 |
# | Correlation        |                 180 |                  120 |         66.7 |                 104 |        57.8 |                      79 |            43.9 |
# | AreaShape          |                 162 |                  152 |         93.8 |                 148 |        91.4 |                     110 |            67.9 |
# | Granularity        |                 192 |                  189 |         98.4 |                 174 |        90.6 |                      71 |            37   |
# | Neighbors          |                  21 |                   12 |         57.1 |                   5 |        23.8 |                       3 |            14.3 |
# | RadialDistribution |                 366 |                  279 |         76.2 |                 267 |        73   |                     180 |            49.2 |
# | Texture            |                1872 |                 1872 |        100   |                1557 |        83.2 |                     201 |            10.7 |
# | MitoSkeleton       |                   4 |                    1 |         25   |                   0 |         0   |                       0 |             0   |
#
# | Category       |   Original Features |   Variance Threshold |   % Variance |   Outlier Threshold |   % Outlier |   Correlation Threshold |   % Correlation |
# |:---------------|--------------------:|---------------------:|-------------:|--------------------:|------------:|------------------------:|----------------:|
# | Total Features |                2977 |                 2805 |         94.2 |                2406 |        80.8 |                     666 |            22.4 |
# | Nucleus        |                 921 |                  887 |         96.3 |                 764 |        83   |                     208 |            22.6 |
# | Cell           |                1035 |                  999 |         96.5 |                 860 |        83.1 |                     223 |            21.5 |
# | Cytoplasm      |                1021 |                  919 |         90   |                 782 |        76.6 |                     235 |            23   |
# 666

# %%
dataframes_normalized_reduced_dict = {}

for folder in folders:

    site_specific_path = os.path.join(input_path, folder)

    # loads mad_robustize normalized data
    pattern = "[A-Z][0-9][0-9][0-9][0-9]_R[1-4]_mad_robustize.csv"
    file_list = glob.glob(site_specific_path + os.sep + '*' + os.sep + pattern, recursive=True)

    for file in file_list:
    
        plate_map_name = os.path.splitext(os.path.basename(file))[0]
    
        try:
        
            dataframe = pd.read_csv(file)
            row_count = dataframe.shape[0]
        
            print(f"INFO: {plate_map_name} has {row_count} rows")

            features = CBE.get_feature_vector(dataframe)
            metadata = set(dataframe.columns) - set(features)

            number_features = len(features)

            print(f"INFO: {plate_map_name} has {number_features} features")

            if folder == 'FMP':
                reduced_feature_set = set(fmp_feature_set)
            elif folder == 'IMTM':
                reduced_feature_set = set(imtm_feature_set)
            elif folder == 'MEDINA':
                reduced_feature_set = set(medina_feature_set)
            elif folder == 'USC':
                reduced_feature_set = set(usc_feature_set)

            features_to_remove = [item for item in features if item not in reduced_feature_set]
    
            dataframe_reduced_features = dataframe.drop(columns = features_to_remove)

            reduced_features = CBE.get_feature_vector(dataframe_reduced_features)

            number_reduced_features = len(reduced_features)

            print(f"INFO: {plate_map_name} has {number_reduced_features} features after feature reduction")
    
            filename_norm_reduced_data = plate_map_name + "_reduced-corr.csv"
    
            path_norm_reduced_data = os.path.dirname(file)
            file_path_norm_reduced_data = os.path.join(path_norm_reduced_data, filename_norm_reduced_data)
    
            dataframe_reduced_features.to_csv(file_path_norm_reduced_data, index=False)
    
            print(f"INFO: Saved {filename_norm_reduced_data}")

            dict_key = dataframe_reduced_features['Metadata_staining_date'][0].astype(str) + "_" + dataframe_reduced_features['Metadata_source'][0] + "_" + dataframe_reduced_features['Metadata_plate_map_name'][0]

            dataframes_normalized_reduced_dict[dict_key] = dataframe_reduced_features
        
        except Exception as e:
        
            print(f"Error reading file {plate_map_name}: {e}")
# Out:
# INFO: C1231_R1_mad_robustize has 384 rows
# INFO: C1231_R1_mad_robustize has 2977 features
# INFO: C1231_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1231_R1_mad_robustize_reduced-corr.csv
# INFO: C1269_R2_mad_robustize has 384 rows
# INFO: C1269_R2_mad_robustize has 2977 features
# INFO: C1269_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1269_R2_mad_robustize_reduced-corr.csv
# INFO: C1240_R4_mad_robustize has 384 rows
# INFO: C1240_R4_mad_robustize has 2977 features
# INFO: C1240_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1240_R4_mad_robustize_reduced-corr.csv
# INFO: C1260_R1_mad_robustize has 384 rows
# INFO: C1260_R1_mad_robustize has 2977 features
# INFO: C1260_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1260_R1_mad_robustize_reduced-corr.csv
# INFO: C1258_R2_mad_robustize has 384 rows
# INFO: C1258_R2_mad_robustize has 2977 features
# INFO: C1258_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1258_R2_mad_robustize_reduced-corr.csv
# INFO: C1270_R3_mad_robustize has 384 rows
# INFO: C1270_R3_mad_robustize has 2977 features
# INFO: C1270_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1270_R3_mad_robustize_reduced-corr.csv
# INFO: C1259_R1_mad_robustize has 384 rows
# INFO: C1259_R1_mad_robustize has 2977 features
# INFO: C1259_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1259_R1_mad_robustize_reduced-corr.csv
# INFO: C1283_R2_mad_robustize has 384 rows
# INFO: C1283_R2_mad_robustize has 2977 features
# INFO: C1283_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1283_R2_mad_robustize_reduced-corr.csv
# INFO: C1261_R1_mad_robustize has 384 rows
# INFO: C1261_R1_mad_robustize has 2977 features
# INFO: C1261_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1261_R1_mad_robustize_reduced-corr.csv
# INFO: C1245_R4_mad_robustize has 384 rows
# INFO: C1245_R4_mad_robustize has 2977 features
# INFO: C1245_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1245_R4_mad_robustize_reduced-corr.csv
# INFO: C1234_R3_mad_robustize has 384 rows
# INFO: C1234_R3_mad_robustize has 2977 features
# INFO: C1234_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1234_R3_mad_robustize_reduced-corr.csv
# INFO: C1263_R1_mad_robustize has 384 rows
# INFO: C1263_R1_mad_robustize has 2977 features
# INFO: C1263_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1263_R1_mad_robustize_reduced-corr.csv
# INFO: C1239_R1_mad_robustize has 384 rows
# INFO: C1239_R1_mad_robustize has 2977 features
# INFO: C1239_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1239_R1_mad_robustize_reduced-corr.csv
# INFO: C1261_R2_mad_robustize has 384 rows
# INFO: C1261_R2_mad_robustize has 2977 features
# INFO: C1261_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1261_R2_mad_robustize_reduced-corr.csv
# INFO: C1248_R1_mad_robustize has 384 rows
# INFO: C1248_R1_mad_robustize has 2977 features
# INFO: C1248_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1248_R1_mad_robustize_reduced-corr.csv
# INFO: C1241_R1_mad_robustize has 384 rows
# INFO: C1241_R1_mad_robustize has 2977 features
# INFO: C1241_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1241_R1_mad_robustize_reduced-corr.csv
# INFO: C1232_R3_mad_robustize has 384 rows
# INFO: C1232_R3_mad_robustize has 2977 features
# INFO: C1232_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1232_R3_mad_robustize_reduced-corr.csv
# INFO: C1251_R1_mad_robustize has 384 rows
# INFO: C1251_R1_mad_robustize has 2977 features
# INFO: C1251_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1251_R1_mad_robustize_reduced-corr.csv
# INFO: C1264_R4_mad_robustize has 384 rows
# INFO: C1264_R4_mad_robustize has 2977 features
# INFO: C1264_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1264_R4_mad_robustize_reduced-corr.csv
# INFO: C1264_R3_mad_robustize has 384 rows
# INFO: C1264_R3_mad_robustize has 2977 features
# INFO: C1264_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1264_R3_mad_robustize_reduced-corr.csv
# INFO: C1248_R2_mad_robustize has 384 rows
# INFO: C1248_R2_mad_robustize has 2977 features
# INFO: C1248_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1248_R2_mad_robustize_reduced-corr.csv
# INFO: C1272_R3_mad_robustize has 384 rows
# INFO: C1272_R3_mad_robustize has 2977 features
# INFO: C1272_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1272_R3_mad_robustize_reduced-corr.csv
# INFO: C1254_R4_mad_robustize has 384 rows
# INFO: C1254_R4_mad_robustize has 2977 features
# INFO: C1254_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1254_R4_mad_robustize_reduced-corr.csv
# INFO: C1247_R4_mad_robustize has 384 rows
# INFO: C1247_R4_mad_robustize has 2977 features
# INFO: C1247_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1247_R4_mad_robustize_reduced-corr.csv
# INFO: C1256_R3_mad_robustize has 384 rows
# INFO: C1256_R3_mad_robustize has 2977 features
# INFO: C1256_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1256_R3_mad_robustize_reduced-corr.csv
# INFO: C1255_R4_mad_robustize has 384 rows
# INFO: C1255_R4_mad_robustize has 2977 features
# INFO: C1255_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1255_R4_mad_robustize_reduced-corr.csv
# INFO: C1254_R3_mad_robustize has 384 rows
# INFO: C1254_R3_mad_robustize has 2977 features
# INFO: C1254_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1254_R3_mad_robustize_reduced-corr.csv
# INFO: C1233_R3_mad_robustize has 384 rows
# INFO: C1233_R3_mad_robustize has 2977 features
# INFO: C1233_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1233_R3_mad_robustize_reduced-corr.csv
# INFO: C1269_R3_mad_robustize has 384 rows
# INFO: C1269_R3_mad_robustize has 2977 features
# INFO: C1269_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1269_R3_mad_robustize_reduced-corr.csv
# INFO: C1249_R3_mad_robustize has 384 rows
# INFO: C1249_R3_mad_robustize has 2977 features
# INFO: C1249_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1249_R3_mad_robustize_reduced-corr.csv
# INFO: C1240_R1_mad_robustize has 384 rows
# INFO: C1240_R1_mad_robustize has 2977 features
# INFO: C1240_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1240_R1_mad_robustize_reduced-corr.csv
# INFO: C1237_R1_mad_robustize has 384 rows
# INFO: C1237_R1_mad_robustize has 2977 features
# INFO: C1237_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1237_R1_mad_robustize_reduced-corr.csv
# INFO: C1250_R3_mad_robustize has 384 rows
# INFO: C1250_R3_mad_robustize has 2977 features
# INFO: C1250_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1250_R3_mad_robustize_reduced-corr.csv
# INFO: C1233_R4_mad_robustize has 383 rows
# INFO: C1233_R4_mad_robustize has 2977 features
# INFO: C1233_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1233_R4_mad_robustize_reduced-corr.csv
# INFO: C1265_R1_mad_robustize has 384 rows
# INFO: C1265_R1_mad_robustize has 2977 features
# INFO: C1265_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1265_R1_mad_robustize_reduced-corr.csv
# INFO: C1242_R1_mad_robustize has 384 rows
# INFO: C1242_R1_mad_robustize has 2977 features
# INFO: C1242_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1242_R1_mad_robustize_reduced-corr.csv
# INFO: C1232_R1_mad_robustize has 384 rows
# INFO: C1232_R1_mad_robustize has 2977 features
# INFO: C1232_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1232_R1_mad_robustize_reduced-corr.csv
# INFO: C1264_R2_mad_robustize has 384 rows
# INFO: C1264_R2_mad_robustize has 2977 features
# INFO: C1264_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1264_R2_mad_robustize_reduced-corr.csv
# INFO: C1238_R3_mad_robustize has 384 rows
# INFO: C1238_R3_mad_robustize has 2977 features
# INFO: C1238_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1238_R3_mad_robustize_reduced-corr.csv
# INFO: C1242_R2_mad_robustize has 384 rows
# INFO: C1242_R2_mad_robustize has 2977 features
# INFO: C1242_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1242_R2_mad_robustize_reduced-corr.csv
# INFO: C1241_R4_mad_robustize has 384 rows
# INFO: C1241_R4_mad_robustize has 2977 features
# INFO: C1241_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1241_R4_mad_robustize_reduced-corr.csv
# INFO: C1250_R1_mad_robustize has 384 rows
# INFO: C1250_R1_mad_robustize has 2977 features
# INFO: C1250_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1250_R1_mad_robustize_reduced-corr.csv
# INFO: C1243_R3_mad_robustize has 384 rows
# INFO: C1243_R3_mad_robustize has 2977 features
# INFO: C1243_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1243_R3_mad_robustize_reduced-corr.csv
# INFO: C1255_R3_mad_robustize has 384 rows
# INFO: C1255_R3_mad_robustize has 2977 features
# INFO: C1255_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1255_R3_mad_robustize_reduced-corr.csv
# INFO: C1250_R2_mad_robustize has 384 rows
# INFO: C1250_R2_mad_robustize has 2977 features
# INFO: C1250_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1250_R2_mad_robustize_reduced-corr.csv
# INFO: C1268_R4_mad_robustize has 384 rows
# INFO: C1268_R4_mad_robustize has 2977 features
# INFO: C1268_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1268_R4_mad_robustize_reduced-corr.csv
# INFO: C1286_R1_mad_robustize has 384 rows
# INFO: C1286_R1_mad_robustize has 2977 features
# INFO: C1286_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1286_R1_mad_robustize_reduced-corr.csv
# INFO: C1277_R2_mad_robustize has 384 rows
# INFO: C1277_R2_mad_robustize has 2977 features
# INFO: C1277_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1277_R2_mad_robustize_reduced-corr.csv
# INFO: C1239_R4_mad_robustize has 366 rows
# INFO: C1239_R4_mad_robustize has 2977 features
# INFO: C1239_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1239_R4_mad_robustize_reduced-corr.csv
# INFO: C1260_R2_mad_robustize has 384 rows
# INFO: C1260_R2_mad_robustize has 2977 features
# INFO: C1260_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1260_R2_mad_robustize_reduced-corr.csv
# INFO: C1285_R1_mad_robustize has 384 rows
# INFO: C1285_R1_mad_robustize has 2977 features
# INFO: C1285_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1285_R1_mad_robustize_reduced-corr.csv
# INFO: C1278_R1_mad_robustize has 384 rows
# INFO: C1278_R1_mad_robustize has 2977 features
# INFO: C1278_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1278_R1_mad_robustize_reduced-corr.csv
# INFO: C1257_R3_mad_robustize has 384 rows
# INFO: C1257_R3_mad_robustize has 2977 features
# INFO: C1257_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1257_R3_mad_robustize_reduced-corr.csv
# INFO: C1247_R1_mad_robustize has 384 rows
# INFO: C1247_R1_mad_robustize has 2977 features
# INFO: C1247_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1247_R1_mad_robustize_reduced-corr.csv
# INFO: C1230_R3_mad_robustize has 384 rows
# INFO: C1230_R3_mad_robustize has 2977 features
# INFO: C1230_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1230_R3_mad_robustize_reduced-corr.csv
# INFO: C1257_R1_mad_robustize has 384 rows
# INFO: C1257_R1_mad_robustize has 2977 features
# INFO: C1257_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1257_R1_mad_robustize_reduced-corr.csv
# INFO: C1244_R2_mad_robustize has 384 rows
# INFO: C1244_R2_mad_robustize has 2977 features
# INFO: C1244_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1244_R2_mad_robustize_reduced-corr.csv
# INFO: C1264_R1_mad_robustize has 384 rows
# INFO: C1264_R1_mad_robustize has 2977 features
# INFO: C1264_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1264_R1_mad_robustize_reduced-corr.csv
# INFO: C1252_R3_mad_robustize has 384 rows
# INFO: C1252_R3_mad_robustize has 2977 features
# INFO: C1252_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1252_R3_mad_robustize_reduced-corr.csv
# INFO: C1253_R2_mad_robustize has 384 rows
# INFO: C1253_R2_mad_robustize has 2977 features
# INFO: C1253_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1253_R2_mad_robustize_reduced-corr.csv
# INFO: C1267_R1_mad_robustize has 384 rows
# INFO: C1267_R1_mad_robustize has 2977 features
# INFO: C1267_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1267_R1_mad_robustize_reduced-corr.csv
# INFO: C1266_R1_mad_robustize has 384 rows
# INFO: C1266_R1_mad_robustize has 2977 features
# INFO: C1266_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1266_R1_mad_robustize_reduced-corr.csv
# INFO: C1234_R4_mad_robustize has 384 rows
# INFO: C1234_R4_mad_robustize has 2977 features
# INFO: C1234_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1234_R4_mad_robustize_reduced-corr.csv
# INFO: C1251_R2_mad_robustize has 384 rows
# INFO: C1251_R2_mad_robustize has 2977 features
# INFO: C1251_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1251_R2_mad_robustize_reduced-corr.csv
# INFO: C1273_R3_mad_robustize has 384 rows
# INFO: C1273_R3_mad_robustize has 2977 features
# INFO: C1273_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1273_R3_mad_robustize_reduced-corr.csv
# INFO: C1230_R4_mad_robustize has 384 rows
# INFO: C1230_R4_mad_robustize has 2977 features
# INFO: C1230_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1230_R4_mad_robustize_reduced-corr.csv
# INFO: C1271_R2_mad_robustize has 384 rows
# INFO: C1271_R2_mad_robustize has 2977 features
# INFO: C1271_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1271_R2_mad_robustize_reduced-corr.csv
# INFO: C1244_R4_mad_robustize has 384 rows
# INFO: C1244_R4_mad_robustize has 2977 features
# INFO: C1244_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1244_R4_mad_robustize_reduced-corr.csv
# INFO: C1238_R2_mad_robustize has 384 rows
# INFO: C1238_R2_mad_robustize has 2977 features
# INFO: C1238_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1238_R2_mad_robustize_reduced-corr.csv
# INFO: C1248_R4_mad_robustize has 384 rows
# INFO: C1248_R4_mad_robustize has 2977 features
# INFO: C1248_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1248_R4_mad_robustize_reduced-corr.csv
# INFO: C1249_R2_mad_robustize has 384 rows
# INFO: C1249_R2_mad_robustize has 2977 features
# INFO: C1249_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1249_R2_mad_robustize_reduced-corr.csv
# INFO: C1258_R3_mad_robustize has 384 rows
# INFO: C1258_R3_mad_robustize has 2977 features
# INFO: C1258_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1258_R3_mad_robustize_reduced-corr.csv
# INFO: C1235_R4_mad_robustize has 384 rows
# INFO: C1235_R4_mad_robustize has 2977 features
# INFO: C1235_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1235_R4_mad_robustize_reduced-corr.csv
# INFO: C1250_R4_mad_robustize has 384 rows
# INFO: C1250_R4_mad_robustize has 2977 features
# INFO: C1250_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1250_R4_mad_robustize_reduced-corr.csv
# INFO: C1266_R2_mad_robustize has 384 rows
# INFO: C1266_R2_mad_robustize has 2977 features
# INFO: C1266_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1266_R2_mad_robustize_reduced-corr.csv
# INFO: C1252_R4_mad_robustize has 384 rows
# INFO: C1252_R4_mad_robustize has 2977 features
# INFO: C1252_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1252_R4_mad_robustize_reduced-corr.csv
# INFO: C1252_R2_mad_robustize has 384 rows
# INFO: C1252_R2_mad_robustize has 2977 features
# INFO: C1252_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1252_R2_mad_robustize_reduced-corr.csv
# INFO: C1235_R2_mad_robustize has 384 rows
# INFO: C1235_R2_mad_robustize has 2977 features
# INFO: C1235_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1235_R2_mad_robustize_reduced-corr.csv
# INFO: C1249_R1_mad_robustize has 384 rows
# INFO: C1249_R1_mad_robustize has 2977 features
# INFO: C1249_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1249_R1_mad_robustize_reduced-corr.csv
# INFO: C1287_R1_mad_robustize has 384 rows
# INFO: C1287_R1_mad_robustize has 2977 features
# INFO: C1287_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1287_R1_mad_robustize_reduced-corr.csv
# INFO: C1231_R4_mad_robustize has 384 rows
# INFO: C1231_R4_mad_robustize has 2977 features
# INFO: C1231_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1231_R4_mad_robustize_reduced-corr.csv
# INFO: C1246_R4_mad_robustize has 384 rows
# INFO: C1246_R4_mad_robustize has 2977 features
# INFO: C1246_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1246_R4_mad_robustize_reduced-corr.csv
# INFO: C1240_R3_mad_robustize has 384 rows
# INFO: C1240_R3_mad_robustize has 2977 features
# INFO: C1240_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1240_R3_mad_robustize_reduced-corr.csv
# INFO: C1269_R1_mad_robustize has 384 rows
# INFO: C1269_R1_mad_robustize has 2977 features
# INFO: C1269_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1269_R1_mad_robustize_reduced-corr.csv
# INFO: C1267_R4_mad_robustize has 384 rows
# INFO: C1267_R4_mad_robustize has 2977 features
# INFO: C1267_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1267_R4_mad_robustize_reduced-corr.csv
# INFO: C1272_R2_mad_robustize has 384 rows
# INFO: C1272_R2_mad_robustize has 2977 features
# INFO: C1272_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1272_R2_mad_robustize_reduced-corr.csv
# INFO: C1232_R2_mad_robustize has 384 rows
# INFO: C1232_R2_mad_robustize has 2977 features
# INFO: C1232_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1232_R2_mad_robustize_reduced-corr.csv
# INFO: C1244_R1_mad_robustize has 384 rows
# INFO: C1244_R1_mad_robustize has 2977 features
# INFO: C1244_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1244_R1_mad_robustize_reduced-corr.csv
# INFO: C1263_R2_mad_robustize has 384 rows
# INFO: C1263_R2_mad_robustize has 2977 features
# INFO: C1263_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1263_R2_mad_robustize_reduced-corr.csv
# INFO: C1253_R4_mad_robustize has 384 rows
# INFO: C1253_R4_mad_robustize has 2977 features
# INFO: C1253_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1253_R4_mad_robustize_reduced-corr.csv
# INFO: C1271_R1_mad_robustize has 384 rows
# INFO: C1271_R1_mad_robustize has 2977 features
# INFO: C1271_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1271_R1_mad_robustize_reduced-corr.csv
# INFO: C1241_R2_mad_robustize has 384 rows
# INFO: C1241_R2_mad_robustize has 2977 features
# INFO: C1241_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1241_R2_mad_robustize_reduced-corr.csv
# INFO: C1246_R2_mad_robustize has 384 rows
# INFO: C1246_R2_mad_robustize has 2977 features
# INFO: C1246_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1246_R2_mad_robustize_reduced-corr.csv
# INFO: C1262_R3_mad_robustize has 384 rows
# INFO: C1262_R3_mad_robustize has 2977 features
# INFO: C1262_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1262_R3_mad_robustize_reduced-corr.csv
# INFO: C1259_R3_mad_robustize has 384 rows
# INFO: C1259_R3_mad_robustize has 2977 features
# INFO: C1259_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1259_R3_mad_robustize_reduced-corr.csv
# INFO: C1237_R2_mad_robustize has 384 rows
# INFO: C1237_R2_mad_robustize has 2977 features
# INFO: C1237_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1237_R2_mad_robustize_reduced-corr.csv
# INFO: C1259_R2_mad_robustize has 384 rows
# INFO: C1259_R2_mad_robustize has 2977 features
# INFO: C1259_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1259_R2_mad_robustize_reduced-corr.csv
# INFO: C1267_R2_mad_robustize has 384 rows
# INFO: C1267_R2_mad_robustize has 2977 features
# INFO: C1267_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1267_R2_mad_robustize_reduced-corr.csv
# INFO: C1258_R4_mad_robustize has 384 rows
# INFO: C1258_R4_mad_robustize has 2977 features
# INFO: C1258_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1258_R4_mad_robustize_reduced-corr.csv
# INFO: C1235_R1_mad_robustize has 384 rows
# INFO: C1235_R1_mad_robustize has 2977 features
# INFO: C1235_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1235_R1_mad_robustize_reduced-corr.csv
# INFO: C1266_R4_mad_robustize has 384 rows
# INFO: C1266_R4_mad_robustize has 2977 features
# INFO: C1266_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1266_R4_mad_robustize_reduced-corr.csv
# INFO: C1258_R1_mad_robustize has 384 rows
# INFO: C1258_R1_mad_robustize has 2977 features
# INFO: C1258_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1258_R1_mad_robustize_reduced-corr.csv
# INFO: C1257_R4_mad_robustize has 384 rows
# INFO: C1257_R4_mad_robustize has 2977 features
# INFO: C1257_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1257_R4_mad_robustize_reduced-corr.csv
# INFO: C1273_R1_mad_robustize has 384 rows
# INFO: C1273_R1_mad_robustize has 2977 features
# INFO: C1273_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1273_R1_mad_robustize_reduced-corr.csv
# INFO: C1244_R3_mad_robustize has 384 rows
# INFO: C1244_R3_mad_robustize has 2977 features
# INFO: C1244_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1244_R3_mad_robustize_reduced-corr.csv
# INFO: C1230_R2_mad_robustize has 384 rows
# INFO: C1230_R2_mad_robustize has 2977 features
# INFO: C1230_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1230_R2_mad_robustize_reduced-corr.csv
# INFO: C1253_R1_mad_robustize has 384 rows
# INFO: C1253_R1_mad_robustize has 2977 features
# INFO: C1253_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1253_R1_mad_robustize_reduced-corr.csv
# INFO: C1231_R2_mad_robustize has 384 rows
# INFO: C1231_R2_mad_robustize has 2977 features
# INFO: C1231_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1231_R2_mad_robustize_reduced-corr.csv
# INFO: C1270_R1_mad_robustize has 361 rows
# INFO: C1270_R1_mad_robustize has 2977 features
# INFO: C1270_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1270_R1_mad_robustize_reduced-corr.csv
# INFO: C1256_R1_mad_robustize has 384 rows
# INFO: C1256_R1_mad_robustize has 2977 features
# INFO: C1256_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1256_R1_mad_robustize_reduced-corr.csv
# INFO: C1238_R1_mad_robustize has 384 rows
# INFO: C1238_R1_mad_robustize has 2977 features
# INFO: C1238_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1238_R1_mad_robustize_reduced-corr.csv
# INFO: C1267_R3_mad_robustize has 384 rows
# INFO: C1267_R3_mad_robustize has 2977 features
# INFO: C1267_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1267_R3_mad_robustize_reduced-corr.csv
# INFO: C1242_R4_mad_robustize has 384 rows
# INFO: C1242_R4_mad_robustize has 2977 features
# INFO: C1242_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1242_R4_mad_robustize_reduced-corr.csv
# INFO: C1260_R3_mad_robustize has 384 rows
# INFO: C1260_R3_mad_robustize has 2977 features
# INFO: C1260_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1260_R3_mad_robustize_reduced-corr.csv
# INFO: C1241_R3_mad_robustize has 384 rows
# INFO: C1241_R3_mad_robustize has 2977 features
# INFO: C1241_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1241_R3_mad_robustize_reduced-corr.csv
# INFO: C1256_R4_mad_robustize has 384 rows
# INFO: C1256_R4_mad_robustize has 2977 features
# INFO: C1256_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1256_R4_mad_robustize_reduced-corr.csv
# INFO: C1272_R1_mad_robustize has 384 rows
# INFO: C1272_R1_mad_robustize has 2977 features
# INFO: C1272_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1272_R1_mad_robustize_reduced-corr.csv
# INFO: C1257_R2_mad_robustize has 384 rows
# INFO: C1257_R2_mad_robustize has 2977 features
# INFO: C1257_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1257_R2_mad_robustize_reduced-corr.csv
# INFO: C1243_R2_mad_robustize has 384 rows
# INFO: C1243_R2_mad_robustize has 2977 features
# INFO: C1243_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1243_R2_mad_robustize_reduced-corr.csv
# INFO: C1242_R3_mad_robustize has 384 rows
# INFO: C1242_R3_mad_robustize has 2977 features
# INFO: C1242_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1242_R3_mad_robustize_reduced-corr.csv
# INFO: C1263_R3_mad_robustize has 384 rows
# INFO: C1263_R3_mad_robustize has 2977 features
# INFO: C1263_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1263_R3_mad_robustize_reduced-corr.csv
# INFO: C1254_R2_mad_robustize has 384 rows
# INFO: C1254_R2_mad_robustize has 2977 features
# INFO: C1254_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1254_R2_mad_robustize_reduced-corr.csv
# INFO: C1247_R2_mad_robustize has 384 rows
# INFO: C1247_R2_mad_robustize has 2977 features
# INFO: C1247_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1247_R2_mad_robustize_reduced-corr.csv
# INFO: C1263_R4_mad_robustize has 384 rows
# INFO: C1263_R4_mad_robustize has 2977 features
# INFO: C1263_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1263_R4_mad_robustize_reduced-corr.csv
# INFO: C1270_R4_mad_robustize has 384 rows
# INFO: C1270_R4_mad_robustize has 2977 features
# INFO: C1270_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1270_R4_mad_robustize_reduced-corr.csv
# INFO: C1232_R4_mad_robustize has 384 rows
# INFO: C1232_R4_mad_robustize has 2977 features
# INFO: C1232_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1232_R4_mad_robustize_reduced-corr.csv
# INFO: C1245_R2_mad_robustize has 384 rows
# INFO: C1245_R2_mad_robustize has 2977 features
# INFO: C1245_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1245_R2_mad_robustize_reduced-corr.csv
# INFO: C1254_R1_mad_robustize has 384 rows
# INFO: C1254_R1_mad_robustize has 2977 features
# INFO: C1254_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1254_R1_mad_robustize_reduced-corr.csv
# INFO: C1265_R4_mad_robustize has 384 rows
# INFO: C1265_R4_mad_robustize has 2977 features
# INFO: C1265_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1265_R4_mad_robustize_reduced-corr.csv
# INFO: C1249_R4_mad_robustize has 384 rows
# INFO: C1249_R4_mad_robustize has 2977 features
# INFO: C1249_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1249_R4_mad_robustize_reduced-corr.csv
# INFO: C1243_R1_mad_robustize has 384 rows
# INFO: C1243_R1_mad_robustize has 2977 features
# INFO: C1243_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1243_R1_mad_robustize_reduced-corr.csv
# INFO: C1268_R2_mad_robustize has 384 rows
# INFO: C1268_R2_mad_robustize has 2977 features
# INFO: C1268_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1268_R2_mad_robustize_reduced-corr.csv
# INFO: C1245_R1_mad_robustize has 384 rows
# INFO: C1245_R1_mad_robustize has 2977 features
# INFO: C1245_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1245_R1_mad_robustize_reduced-corr.csv
# INFO: C1245_R3_mad_robustize has 384 rows
# INFO: C1245_R3_mad_robustize has 2977 features
# INFO: C1245_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1245_R3_mad_robustize_reduced-corr.csv
# INFO: C1239_R2_mad_robustize has 384 rows
# INFO: C1239_R2_mad_robustize has 2977 features
# INFO: C1239_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1239_R2_mad_robustize_reduced-corr.csv
# INFO: C1243_R4_mad_robustize has 384 rows
# INFO: C1243_R4_mad_robustize has 2977 features
# INFO: C1243_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1243_R4_mad_robustize_reduced-corr.csv
# INFO: C1271_R4_mad_robustize has 384 rows
# INFO: C1271_R4_mad_robustize has 2977 features
# INFO: C1271_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1271_R4_mad_robustize_reduced-corr.csv
# INFO: C1240_R2_mad_robustize has 384 rows
# INFO: C1240_R2_mad_robustize has 2977 features
# INFO: C1240_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1240_R2_mad_robustize_reduced-corr.csv
# INFO: C1255_R2_mad_robustize has 384 rows
# INFO: C1255_R2_mad_robustize has 2977 features
# INFO: C1255_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1255_R2_mad_robustize_reduced-corr.csv
# INFO: C1230_R1_mad_robustize has 384 rows
# INFO: C1230_R1_mad_robustize has 2977 features
# INFO: C1230_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1230_R1_mad_robustize_reduced-corr.csv
# INFO: C1270_R2_mad_robustize has 384 rows
# INFO: C1270_R2_mad_robustize has 2977 features
# INFO: C1270_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1270_R2_mad_robustize_reduced-corr.csv
# INFO: C1259_R4_mad_robustize has 384 rows
# INFO: C1259_R4_mad_robustize has 2977 features
# INFO: C1259_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1259_R4_mad_robustize_reduced-corr.csv
# INFO: C1272_R4_mad_robustize has 384 rows
# INFO: C1272_R4_mad_robustize has 2977 features
# INFO: C1272_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1272_R4_mad_robustize_reduced-corr.csv
# INFO: C1273_R2_mad_robustize has 384 rows
# INFO: C1273_R2_mad_robustize has 2977 features
# INFO: C1273_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1273_R2_mad_robustize_reduced-corr.csv
# INFO: C1246_R3_mad_robustize has 384 rows
# INFO: C1246_R3_mad_robustize has 2977 features
# INFO: C1246_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1246_R3_mad_robustize_reduced-corr.csv
# INFO: C1247_R3_mad_robustize has 384 rows
# INFO: C1247_R3_mad_robustize has 2977 features
# INFO: C1247_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1247_R3_mad_robustize_reduced-corr.csv
# INFO: C1284_R1_mad_robustize has 384 rows
# INFO: C1284_R1_mad_robustize has 2977 features
# INFO: C1284_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1284_R1_mad_robustize_reduced-corr.csv
# INFO: C1231_R3_mad_robustize has 384 rows
# INFO: C1231_R3_mad_robustize has 2977 features
# INFO: C1231_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1231_R3_mad_robustize_reduced-corr.csv
# INFO: C1234_R1_mad_robustize has 384 rows
# INFO: C1234_R1_mad_robustize has 2977 features
# INFO: C1234_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1234_R1_mad_robustize_reduced-corr.csv
# INFO: C1269_R4_mad_robustize has 384 rows
# INFO: C1269_R4_mad_robustize has 2977 features
# INFO: C1269_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1269_R4_mad_robustize_reduced-corr.csv
# INFO: C1260_R4_mad_robustize has 384 rows
# INFO: C1260_R4_mad_robustize has 2977 features
# INFO: C1260_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1260_R4_mad_robustize_reduced-corr.csv
# INFO: C1235_R3_mad_robustize has 384 rows
# INFO: C1235_R3_mad_robustize has 2977 features
# INFO: C1235_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1235_R3_mad_robustize_reduced-corr.csv
# INFO: C1251_R3_mad_robustize has 384 rows
# INFO: C1251_R3_mad_robustize has 2977 features
# INFO: C1251_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1251_R3_mad_robustize_reduced-corr.csv
# INFO: C1252_R1_mad_robustize has 384 rows
# INFO: C1252_R1_mad_robustize has 2977 features
# INFO: C1252_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1252_R1_mad_robustize_reduced-corr.csv
# INFO: C1239_R3_mad_robustize has 384 rows
# INFO: C1239_R3_mad_robustize has 2977 features
# INFO: C1239_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1239_R3_mad_robustize_reduced-corr.csv
# INFO: C1251_R4_mad_robustize has 384 rows
# INFO: C1251_R4_mad_robustize has 2977 features
# INFO: C1251_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1251_R4_mad_robustize_reduced-corr.csv
# INFO: C1261_R3_mad_robustize has 384 rows
# INFO: C1261_R3_mad_robustize has 2977 features
# INFO: C1261_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1261_R3_mad_robustize_reduced-corr.csv
# INFO: C1237_R3_mad_robustize has 384 rows
# INFO: C1237_R3_mad_robustize has 2977 features
# INFO: C1237_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1237_R3_mad_robustize_reduced-corr.csv
# INFO: C1268_R3_mad_robustize has 384 rows
# INFO: C1268_R3_mad_robustize has 2977 features
# INFO: C1268_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1268_R3_mad_robustize_reduced-corr.csv
# INFO: C1268_R1_mad_robustize has 384 rows
# INFO: C1268_R1_mad_robustize has 2977 features
# INFO: C1268_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1268_R1_mad_robustize_reduced-corr.csv
# INFO: C1236_R2_mad_robustize has 384 rows
# INFO: C1236_R2_mad_robustize has 2977 features
# INFO: C1236_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1236_R2_mad_robustize_reduced-corr.csv
# INFO: C1255_R1_mad_robustize has 384 rows
# INFO: C1255_R1_mad_robustize has 2977 features
# INFO: C1255_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1255_R1_mad_robustize_reduced-corr.csv
# INFO: C1246_R1_mad_robustize has 384 rows
# INFO: C1246_R1_mad_robustize has 2977 features
# INFO: C1246_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1246_R1_mad_robustize_reduced-corr.csv
# INFO: C1256_R2_mad_robustize has 384 rows
# INFO: C1256_R2_mad_robustize has 2977 features
# INFO: C1256_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1256_R2_mad_robustize_reduced-corr.csv
# INFO: C1238_R4_mad_robustize has 384 rows
# INFO: C1238_R4_mad_robustize has 2977 features
# INFO: C1238_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1238_R4_mad_robustize_reduced-corr.csv
# INFO: C1236_R4_mad_robustize has 384 rows
# INFO: C1236_R4_mad_robustize has 2977 features
# INFO: C1236_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1236_R4_mad_robustize_reduced-corr.csv
# INFO: C1283_R1_mad_robustize has 384 rows
# INFO: C1283_R1_mad_robustize has 2977 features
# INFO: C1283_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1283_R1_mad_robustize_reduced-corr.csv
# INFO: C1265_R2_mad_robustize has 384 rows
# INFO: C1265_R2_mad_robustize has 2977 features
# INFO: C1265_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1265_R2_mad_robustize_reduced-corr.csv
# INFO: C1248_R3_mad_robustize has 384 rows
# INFO: C1248_R3_mad_robustize has 2977 features
# INFO: C1248_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1248_R3_mad_robustize_reduced-corr.csv
# INFO: C1237_R4_mad_robustize has 384 rows
# INFO: C1237_R4_mad_robustize has 2977 features
# INFO: C1237_R4_mad_robustize has 617 features after feature reduction
# INFO: Saved C1237_R4_mad_robustize_reduced-corr.csv
# INFO: C1236_R3_mad_robustize has 384 rows
# INFO: C1236_R3_mad_robustize has 2977 features
# INFO: C1236_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1236_R3_mad_robustize_reduced-corr.csv
# INFO: C1233_R1_mad_robustize has 384 rows
# INFO: C1233_R1_mad_robustize has 2977 features
# INFO: C1233_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1233_R1_mad_robustize_reduced-corr.csv
# INFO: C1282_R2_mad_robustize has 384 rows
# INFO: C1282_R2_mad_robustize has 2977 features
# INFO: C1282_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1282_R2_mad_robustize_reduced-corr.csv
# INFO: C1262_R1_mad_robustize has 384 rows
# INFO: C1262_R1_mad_robustize has 2977 features
# INFO: C1262_R1_mad_robustize has 617 features after feature reduction
# INFO: Saved C1262_R1_mad_robustize_reduced-corr.csv
# INFO: C1265_R3_mad_robustize has 384 rows
# INFO: C1265_R3_mad_robustize has 2977 features
# INFO: C1265_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1265_R3_mad_robustize_reduced-corr.csv
# INFO: C1234_R2_mad_robustize has 384 rows
# INFO: C1234_R2_mad_robustize has 2977 features
# INFO: C1234_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1234_R2_mad_robustize_reduced-corr.csv
# INFO: C1233_R2_mad_robustize has 384 rows
# INFO: C1233_R2_mad_robustize has 2977 features
# INFO: C1233_R2_mad_robustize has 617 features after feature reduction
# INFO: Saved C1233_R2_mad_robustize_reduced-corr.csv
# INFO: C1271_R3_mad_robustize has 384 rows
# INFO: C1271_R3_mad_robustize has 2977 features
# INFO: C1271_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1271_R3_mad_robustize_reduced-corr.csv
# INFO: C1253_R3_mad_robustize has 384 rows
# INFO: C1253_R3_mad_robustize has 2977 features
# INFO: C1253_R3_mad_robustize has 617 features after feature reduction
# INFO: Saved C1253_R3_mad_robustize_reduced-corr.csv
# INFO: C1216_R4_mad_robustize has 384 rows
# INFO: C1216_R4_mad_robustize has 2977 features
# INFO: C1216_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1216_R4_mad_robustize_reduced-corr.csv
# INFO: C1169_R4_mad_robustize has 384 rows
# INFO: C1169_R4_mad_robustize has 2977 features
# INFO: C1169_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1169_R4_mad_robustize_reduced-corr.csv
# INFO: C1167_R4_mad_robustize has 384 rows
# INFO: C1167_R4_mad_robustize has 2977 features
# INFO: C1167_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1167_R4_mad_robustize_reduced-corr.csv
# INFO: C1184_R1_mad_robustize has 384 rows
# INFO: C1184_R1_mad_robustize has 2977 features
# INFO: C1184_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1184_R1_mad_robustize_reduced-corr.csv
# INFO: C1181_R4_mad_robustize has 384 rows
# INFO: C1181_R4_mad_robustize has 2977 features
# INFO: C1181_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1181_R4_mad_robustize_reduced-corr.csv
# INFO: C1166_R2_mad_robustize has 384 rows
# INFO: C1166_R2_mad_robustize has 2977 features
# INFO: C1166_R2_mad_robustize has 666 features after feature reduction
# INFO: Saved C1166_R2_mad_robustize_reduced-corr.csv
# INFO: C1162_R4_mad_robustize has 384 rows
# INFO: C1162_R4_mad_robustize has 2977 features
# INFO: C1162_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1162_R4_mad_robustize_reduced-corr.csv
# INFO: C1193_R1_mad_robustize has 384 rows
# INFO: C1193_R1_mad_robustize has 2977 features
# INFO: C1193_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1193_R1_mad_robustize_reduced-corr.csv
# INFO: C1220_R1_mad_robustize has 384 rows
# INFO: C1220_R1_mad_robustize has 2977 features
# INFO: C1220_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1220_R1_mad_robustize_reduced-corr.csv
# INFO: C1175_R1_mad_robustize has 384 rows
# INFO: C1175_R1_mad_robustize has 2977 features
# INFO: C1175_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1175_R1_mad_robustize_reduced-corr.csv
# INFO: C1218_R4_mad_robustize has 384 rows
# INFO: C1218_R4_mad_robustize has 2977 features
# INFO: C1218_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1218_R4_mad_robustize_reduced-corr.csv
# INFO: C1160_R2_mad_robustize has 384 rows
# INFO: C1160_R2_mad_robustize has 2977 features
# INFO: C1160_R2_mad_robustize has 666 features after feature reduction
# INFO: Saved C1160_R2_mad_robustize_reduced-corr.csv
# INFO: C1160_R3_mad_robustize has 384 rows
# INFO: C1160_R3_mad_robustize has 2977 features
# INFO: C1160_R3_mad_robustize has 666 features after feature reduction
# INFO: Saved C1160_R3_mad_robustize_reduced-corr.csv
# INFO: C1203_R4_mad_robustize has 384 rows
# INFO: C1203_R4_mad_robustize has 2977 features
# INFO: C1203_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1203_R4_mad_robustize_reduced-corr.csv
# INFO: C1197_R4_mad_robustize has 384 rows
# INFO: C1197_R4_mad_robustize has 2977 features
# INFO: C1197_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1197_R4_mad_robustize_reduced-corr.csv
# INFO: C1165_R2_mad_robustize has 384 rows
# INFO: C1165_R2_mad_robustize has 2977 features
# INFO: C1165_R2_mad_robustize has 666 features after feature reduction
# INFO: Saved C1165_R2_mad_robustize_reduced-corr.csv
# INFO: C1198_R1_mad_robustize has 384 rows
# INFO: C1198_R1_mad_robustize has 2977 features
# INFO: C1198_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1198_R1_mad_robustize_reduced-corr.csv
# INFO: C1205_R1_mad_robustize has 384 rows
# INFO: C1205_R1_mad_robustize has 2977 features
# INFO: C1205_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1205_R1_mad_robustize_reduced-corr.csv
# INFO: C1158_R1_mad_robustize has 384 rows
# INFO: C1158_R1_mad_robustize has 2977 features
# INFO: C1158_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1158_R1_mad_robustize_reduced-corr.csv
# INFO: C1204_R3_mad_robustize has 384 rows
# INFO: C1204_R3_mad_robustize has 2977 features
# INFO: C1204_R3_mad_robustize has 666 features after feature reduction
# INFO: Saved C1204_R3_mad_robustize_reduced-corr.csv
# INFO: C1224_R3_mad_robustize has 384 rows
# INFO: C1224_R3_mad_robustize has 2977 features
# INFO: C1224_R3_mad_robustize has 666 features after feature reduction
# INFO: Saved C1224_R3_mad_robustize_reduced-corr.csv
# INFO: C1195_R4_mad_robustize has 384 rows
# INFO: C1195_R4_mad_robustize has 2977 features
# INFO: C1195_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1195_R4_mad_robustize_reduced-corr.csv
# INFO: C1171_R2_mad_robustize has 384 rows
# INFO: C1171_R2_mad_robustize has 2977 features
# INFO: C1171_R2_mad_robustize has 666 features after feature reduction
# INFO: Saved C1171_R2_mad_robustize_reduced-corr.csv
# INFO: C1188_R1_mad_robustize has 384 rows
# INFO: C1188_R1_mad_robustize has 2977 features
# INFO: C1188_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1188_R1_mad_robustize_reduced-corr.csv
# INFO: C1219_R4_mad_robustize has 384 rows
# INFO: C1219_R4_mad_robustize has 2977 features
# INFO: C1219_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1219_R4_mad_robustize_reduced-corr.csv
# INFO: C1212_R1_mad_robustize has 384 rows
# INFO: C1212_R1_mad_robustize has 2977 features
# INFO: C1212_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1212_R1_mad_robustize_reduced-corr.csv
# INFO: C1176_R1_mad_robustize has 384 rows
# INFO: C1176_R1_mad_robustize has 2977 features
# INFO: C1176_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1176_R1_mad_robustize_reduced-corr.csv
# INFO: C1183_R1_mad_robustize has 384 rows
# INFO: C1183_R1_mad_robustize has 2977 features
# INFO: C1183_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1183_R1_mad_robustize_reduced-corr.csv
# INFO: C1167_R3_mad_robustize has 384 rows
# INFO: C1167_R3_mad_robustize has 2977 features
# INFO: C1167_R3_mad_robustize has 666 features after feature reduction
# INFO: Saved C1167_R3_mad_robustize_reduced-corr.csv
# INFO: C1200_R4_mad_robustize has 384 rows
# INFO: C1200_R4_mad_robustize has 2977 features
# INFO: C1200_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1200_R4_mad_robustize_reduced-corr.csv
# INFO: C1177_R4_mad_robustize has 384 rows
# INFO: C1177_R4_mad_robustize has 2977 features
# INFO: C1177_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1177_R4_mad_robustize_reduced-corr.csv
# INFO: C1189_R1_mad_robustize has 384 rows
# INFO: C1189_R1_mad_robustize has 2977 features
# INFO: C1189_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1189_R1_mad_robustize_reduced-corr.csv
# INFO: C1183_R3_mad_robustize has 384 rows
# INFO: C1183_R3_mad_robustize has 2977 features
# INFO: C1183_R3_mad_robustize has 666 features after feature reduction
# INFO: Saved C1183_R3_mad_robustize_reduced-corr.csv
# INFO: C1211_R2_mad_robustize has 384 rows
# INFO: C1211_R2_mad_robustize has 2977 features
# INFO: C1211_R2_mad_robustize has 666 features after feature reduction
# INFO: Saved C1211_R2_mad_robustize_reduced-corr.csv
# INFO: C1188_R4_mad_robustize has 384 rows
# INFO: C1188_R4_mad_robustize has 2977 features
# INFO: C1188_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1188_R4_mad_robustize_reduced-corr.csv
# INFO: C1178_R2_mad_robustize has 384 rows
# INFO: C1178_R2_mad_robustize has 2977 features
# INFO: C1178_R2_mad_robustize has 666 features after feature reduction
# INFO: Saved C1178_R2_mad_robustize_reduced-corr.csv
# INFO: C1227_R4_mad_robustize has 384 rows
# INFO: C1227_R4_mad_robustize has 2977 features
# INFO: C1227_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1227_R4_mad_robustize_reduced-corr.csv
# INFO: C1172_R4_mad_robustize has 384 rows
# INFO: C1172_R4_mad_robustize has 2977 features
# INFO: C1172_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1172_R4_mad_robustize_reduced-corr.csv
# INFO: C1204_R4_mad_robustize has 384 rows
# INFO: C1204_R4_mad_robustize has 2977 features
# INFO: C1204_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1204_R4_mad_robustize_reduced-corr.csv
# INFO: C1204_R2_mad_robustize has 384 rows
# INFO: C1204_R2_mad_robustize has 2977 features
# INFO: C1204_R2_mad_robustize has 666 features after feature reduction
# INFO: Saved C1204_R2_mad_robustize_reduced-corr.csv
# INFO: C1222_R1_mad_robustize has 384 rows
# INFO: C1222_R1_mad_robustize has 2977 features
# INFO: C1222_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1222_R1_mad_robustize_reduced-corr.csv
# INFO: C1202_R1_mad_robustize has 384 rows
# INFO: C1202_R1_mad_robustize has 2977 features
# INFO: C1202_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1202_R1_mad_robustize_reduced-corr.csv
# INFO: C1194_R4_mad_robustize has 384 rows
# INFO: C1194_R4_mad_robustize has 2977 features
# INFO: C1194_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1194_R4_mad_robustize_reduced-corr.csv
# INFO: C1180_R4_mad_robustize has 384 rows
# INFO: C1180_R4_mad_robustize has 2977 features
# INFO: C1180_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1180_R4_mad_robustize_reduced-corr.csv
# INFO: C1192_R4_mad_robustize has 384 rows
# INFO: C1192_R4_mad_robustize has 2977 features
# INFO: C1192_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1192_R4_mad_robustize_reduced-corr.csv
# INFO: C1192_R1_mad_robustize has 384 rows
# INFO: C1192_R1_mad_robustize has 2977 features
# INFO: C1192_R1_mad_robustize has 666 features after feature reduction
# INFO: Saved C1192_R1_mad_robustize_reduced-corr.csv
# INFO: C1214_R4_mad_robustize has 384 rows
# INFO: C1214_R4_mad_robustize has 2977 features
# INFO: C1214_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1214_R4_mad_robustize_reduced-corr.csv
# INFO: C1208_R4_mad_robustize has 384 rows
# INFO: C1208_R4_mad_robustize has 2977 features
# INFO: C1208_R4_mad_robustize has 666 features after feature reduction
# INFO: Saved C1208_R4_mad_robustize_reduced-corr.csv
# INFO: C1184_R2_mad_robustize has 384 rows
# INFO: C1184_R2_mad_robustize has 2977 features
# ...
# INFO: C1032_R3_mad_robustize has 2977 features
# INFO: C1032_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1032_R3_mad_robustize_reduced-corr.csv
# INFO: C1042_R3_mad_robustize has 384 rows
# INFO: C1042_R3_mad_robustize has 2977 features
# INFO: C1042_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1042_R3_mad_robustize_reduced-corr.csv
# INFO: C1035_R2_mad_robustize has 384 rows
# INFO: C1035_R2_mad_robustize has 2977 features
# INFO: C1035_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1035_R2_mad_robustize_reduced-corr.csv
# INFO: C1051_R2_mad_robustize has 384 rows
# INFO: C1051_R2_mad_robustize has 2977 features
# INFO: C1051_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1051_R2_mad_robustize_reduced-corr.csv
# INFO: C1013_R3_mad_robustize has 384 rows
# INFO: C1013_R3_mad_robustize has 2977 features
# INFO: C1013_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1013_R3_mad_robustize_reduced-corr.csv
# INFO: C1021_R3_mad_robustize has 384 rows
# INFO: C1021_R3_mad_robustize has 2977 features
# INFO: C1021_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1021_R3_mad_robustize_reduced-corr.csv
# INFO: C1021_R2_mad_robustize has 384 rows
# INFO: C1021_R2_mad_robustize has 2977 features
# INFO: C1021_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1021_R2_mad_robustize_reduced-corr.csv
# INFO: C1016_R4_mad_robustize has 384 rows
# INFO: C1016_R4_mad_robustize has 2977 features
# INFO: C1016_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1016_R4_mad_robustize_reduced-corr.csv
# INFO: C1012_R4_mad_robustize has 384 rows
# INFO: C1012_R4_mad_robustize has 2977 features
# INFO: C1012_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1012_R4_mad_robustize_reduced-corr.csv
# INFO: C1027_R3_mad_robustize has 384 rows
# INFO: C1027_R3_mad_robustize has 2977 features
# INFO: C1027_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1027_R3_mad_robustize_reduced-corr.csv
# INFO: C1017_R4_mad_robustize has 384 rows
# INFO: C1017_R4_mad_robustize has 2977 features
# INFO: C1017_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1017_R4_mad_robustize_reduced-corr.csv
# INFO: C1030_R1_mad_robustize has 384 rows
# INFO: C1030_R1_mad_robustize has 2977 features
# INFO: C1030_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1030_R1_mad_robustize_reduced-corr.csv
# INFO: C1034_R2_mad_robustize has 384 rows
# INFO: C1034_R2_mad_robustize has 2977 features
# INFO: C1034_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1034_R2_mad_robustize_reduced-corr.csv
# INFO: C1019_R3_mad_robustize has 384 rows
# INFO: C1019_R3_mad_robustize has 2977 features
# INFO: C1019_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1019_R3_mad_robustize_reduced-corr.csv
# INFO: C1029_R4_mad_robustize has 384 rows
# INFO: C1029_R4_mad_robustize has 2977 features
# INFO: C1029_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1029_R4_mad_robustize_reduced-corr.csv
# INFO: C1033_R3_mad_robustize has 384 rows
# INFO: C1033_R3_mad_robustize has 2977 features
# INFO: C1033_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1033_R3_mad_robustize_reduced-corr.csv
# INFO: C1028_R4_mad_robustize has 384 rows
# INFO: C1028_R4_mad_robustize has 2977 features
# INFO: C1028_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1028_R4_mad_robustize_reduced-corr.csv
# INFO: C1026_R4_mad_robustize has 384 rows
# INFO: C1026_R4_mad_robustize has 2977 features
# INFO: C1026_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1026_R4_mad_robustize_reduced-corr.csv
# INFO: C1043_R1_mad_robustize has 384 rows
# INFO: C1043_R1_mad_robustize has 2977 features
# INFO: C1043_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1043_R1_mad_robustize_reduced-corr.csv
# INFO: C1044_R3_mad_robustize has 384 rows
# INFO: C1044_R3_mad_robustize has 2977 features
# INFO: C1044_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1044_R3_mad_robustize_reduced-corr.csv
# INFO: C1029_R3_mad_robustize has 384 rows
# INFO: C1029_R3_mad_robustize has 2977 features
# INFO: C1029_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1029_R3_mad_robustize_reduced-corr.csv
# INFO: C1015_R2_mad_robustize has 384 rows
# INFO: C1015_R2_mad_robustize has 2977 features
# INFO: C1015_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1015_R2_mad_robustize_reduced-corr.csv
# INFO: C1038_R3_mad_robustize has 384 rows
# INFO: C1038_R3_mad_robustize has 2977 features
# INFO: C1038_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1038_R3_mad_robustize_reduced-corr.csv
# INFO: C1039_R3_mad_robustize has 384 rows
# INFO: C1039_R3_mad_robustize has 2977 features
# INFO: C1039_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1039_R3_mad_robustize_reduced-corr.csv
# INFO: C1028_R1_mad_robustize has 384 rows
# INFO: C1028_R1_mad_robustize has 2977 features
# INFO: C1028_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1028_R1_mad_robustize_reduced-corr.csv
# INFO: C1036_R1_mad_robustize has 384 rows
# INFO: C1036_R1_mad_robustize has 2977 features
# INFO: C1036_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1036_R1_mad_robustize_reduced-corr.csv
# INFO: C1014_R3_mad_robustize has 384 rows
# INFO: C1014_R3_mad_robustize has 2977 features
# INFO: C1014_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1014_R3_mad_robustize_reduced-corr.csv
# INFO: C1023_R1_mad_robustize has 384 rows
# INFO: C1023_R1_mad_robustize has 2977 features
# INFO: C1023_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1023_R1_mad_robustize_reduced-corr.csv
# INFO: C1024_R1_mad_robustize has 384 rows
# INFO: C1024_R1_mad_robustize has 2977 features
# INFO: C1024_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1024_R1_mad_robustize_reduced-corr.csv
# INFO: C1035_R3_mad_robustize has 384 rows
# INFO: C1035_R3_mad_robustize has 2977 features
# INFO: C1035_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1035_R3_mad_robustize_reduced-corr.csv
# INFO: C1018_R3_mad_robustize has 384 rows
# INFO: C1018_R3_mad_robustize has 2977 features
# INFO: C1018_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1018_R3_mad_robustize_reduced-corr.csv
# INFO: C1044_R2_mad_robustize has 383 rows
# INFO: C1044_R2_mad_robustize has 2977 features
# INFO: C1044_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1044_R2_mad_robustize_reduced-corr.csv
# INFO: C1050_R1_mad_robustize has 384 rows
# INFO: C1050_R1_mad_robustize has 2977 features
# INFO: C1050_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1050_R1_mad_robustize_reduced-corr.csv
# INFO: C1023_R3_mad_robustize has 384 rows
# INFO: C1023_R3_mad_robustize has 2977 features
# INFO: C1023_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1023_R3_mad_robustize_reduced-corr.csv
# INFO: C1054_R2_mad_robustize has 384 rows
# INFO: C1054_R2_mad_robustize has 2977 features
# INFO: C1054_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1054_R2_mad_robustize_reduced-corr.csv
# INFO: C1048_R2_mad_robustize has 384 rows
# INFO: C1048_R2_mad_robustize has 2977 features
# INFO: C1048_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1048_R2_mad_robustize_reduced-corr.csv
# INFO: C1030_R4_mad_robustize has 384 rows
# INFO: C1030_R4_mad_robustize has 2977 features
# INFO: C1030_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1030_R4_mad_robustize_reduced-corr.csv
# INFO: C1013_R4_mad_robustize has 384 rows
# INFO: C1013_R4_mad_robustize has 2977 features
# INFO: C1013_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1013_R4_mad_robustize_reduced-corr.csv
# INFO: C1027_R1_mad_robustize has 384 rows
# INFO: C1027_R1_mad_robustize has 2977 features
# INFO: C1027_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1027_R1_mad_robustize_reduced-corr.csv
# INFO: C1020_R2_mad_robustize has 384 rows
# INFO: C1020_R2_mad_robustize has 2977 features
# INFO: C1020_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1020_R2_mad_robustize_reduced-corr.csv
# INFO: C1022_R3_mad_robustize has 384 rows
# INFO: C1022_R3_mad_robustize has 2977 features
# INFO: C1022_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1022_R3_mad_robustize_reduced-corr.csv
# INFO: C1026_R1_mad_robustize has 384 rows
# INFO: C1026_R1_mad_robustize has 2977 features
# INFO: C1026_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1026_R1_mad_robustize_reduced-corr.csv
# INFO: C1037_R3_mad_robustize has 384 rows
# INFO: C1037_R3_mad_robustize has 2977 features
# INFO: C1037_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1037_R3_mad_robustize_reduced-corr.csv
# INFO: C1032_R4_mad_robustize has 384 rows
# INFO: C1032_R4_mad_robustize has 2977 features
# INFO: C1032_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1032_R4_mad_robustize_reduced-corr.csv
# INFO: C1031_R4_mad_robustize has 384 rows
# INFO: C1031_R4_mad_robustize has 2977 features
# INFO: C1031_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1031_R4_mad_robustize_reduced-corr.csv
# INFO: C1045_R3_mad_robustize has 384 rows
# INFO: C1045_R3_mad_robustize has 2977 features
# INFO: C1045_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1045_R3_mad_robustize_reduced-corr.csv
# INFO: C1011_R2_mad_robustize has 384 rows
# INFO: C1011_R2_mad_robustize has 2977 features
# INFO: C1011_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1011_R2_mad_robustize_reduced-corr.csv
# INFO: C1054_R3_mad_robustize has 384 rows
# INFO: C1054_R3_mad_robustize has 2977 features
# INFO: C1054_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1054_R3_mad_robustize_reduced-corr.csv
# INFO: C1042_R2_mad_robustize has 27 rows
# INFO: C1042_R2_mad_robustize has 2977 features
# INFO: C1042_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1042_R2_mad_robustize_reduced-corr.csv
# INFO: C1047_R4_mad_robustize has 384 rows
# INFO: C1047_R4_mad_robustize has 2977 features
# INFO: C1047_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1047_R4_mad_robustize_reduced-corr.csv
# INFO: C1038_R3_mad_robustize has 384 rows
# INFO: C1038_R3_mad_robustize has 2977 features
# INFO: C1038_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1038_R3_mad_robustize_reduced-corr.csv
# INFO: C1021_R3_mad_robustize has 384 rows
# INFO: C1021_R3_mad_robustize has 2977 features
# INFO: C1021_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1021_R3_mad_robustize_reduced-corr.csv
# INFO: C1013_R1_mad_robustize has 384 rows
# INFO: C1013_R1_mad_robustize has 2977 features
# INFO: C1013_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1013_R1_mad_robustize_reduced-corr.csv
# INFO: C1023_R4_mad_robustize has 384 rows
# INFO: C1023_R4_mad_robustize has 2977 features
# INFO: C1023_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1023_R4_mad_robustize_reduced-corr.csv
# INFO: C1014_R3_mad_robustize has 384 rows
# INFO: C1014_R3_mad_robustize has 2977 features
# INFO: C1014_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1014_R3_mad_robustize_reduced-corr.csv
# INFO: C1039_R1_mad_robustize has 384 rows
# INFO: C1039_R1_mad_robustize has 2977 features
# INFO: C1039_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1039_R1_mad_robustize_reduced-corr.csv
# INFO: C1050_R2_mad_robustize has 384 rows
# INFO: C1050_R2_mad_robustize has 2977 features
# INFO: C1050_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1050_R2_mad_robustize_reduced-corr.csv
# INFO: C1023_R3_mad_robustize has 384 rows
# INFO: C1023_R3_mad_robustize has 2977 features
# INFO: C1023_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1023_R3_mad_robustize_reduced-corr.csv
# INFO: C1045_R4_mad_robustize has 384 rows
# INFO: C1045_R4_mad_robustize has 2977 features
# INFO: C1045_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1045_R4_mad_robustize_reduced-corr.csv
# INFO: C1032_R1_mad_robustize has 384 rows
# INFO: C1032_R1_mad_robustize has 2977 features
# INFO: C1032_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1032_R1_mad_robustize_reduced-corr.csv
# INFO: C1011_R3_mad_robustize has 224 rows
# INFO: C1011_R3_mad_robustize has 2977 features
# INFO: C1011_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1011_R3_mad_robustize_reduced-corr.csv
# INFO: C1024_R3_mad_robustize has 384 rows
# INFO: C1024_R3_mad_robustize has 2977 features
# INFO: C1024_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1024_R3_mad_robustize_reduced-corr.csv
# INFO: C1030_R2_mad_robustize has 384 rows
# INFO: C1030_R2_mad_robustize has 2977 features
# INFO: C1030_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1030_R2_mad_robustize_reduced-corr.csv
# INFO: C1051_R3_mad_robustize has 384 rows
# INFO: C1051_R3_mad_robustize has 2977 features
# INFO: C1051_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1051_R3_mad_robustize_reduced-corr.csv
# INFO: C1033_R3_mad_robustize has 384 rows
# INFO: C1033_R3_mad_robustize has 2977 features
# INFO: C1033_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1033_R3_mad_robustize_reduced-corr.csv
# INFO: C1043_R2_mad_robustize has 384 rows
# INFO: C1043_R2_mad_robustize has 2977 features
# INFO: C1043_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1043_R2_mad_robustize_reduced-corr.csv
# INFO: C1013_R2_mad_robustize has 384 rows
# INFO: C1013_R2_mad_robustize has 2977 features
# INFO: C1013_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1013_R2_mad_robustize_reduced-corr.csv
# INFO: C1043_R4_mad_robustize has 384 rows
# INFO: C1043_R4_mad_robustize has 2977 features
# INFO: C1043_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1043_R4_mad_robustize_reduced-corr.csv
# INFO: C1017_R1_mad_robustize has 384 rows
# INFO: C1017_R1_mad_robustize has 2977 features
# INFO: C1017_R1_mad_robustize has 624 features after feature reduction
# INFO: Saved C1017_R1_mad_robustize_reduced-corr.csv
# INFO: C1040_R4_mad_robustize has 384 rows
# INFO: C1040_R4_mad_robustize has 2977 features
# INFO: C1040_R4_mad_robustize has 624 features after feature reduction
# INFO: Saved C1040_R4_mad_robustize_reduced-corr.csv
# INFO: C1041_R3_mad_robustize has 384 rows
# INFO: C1041_R3_mad_robustize has 2977 features
# INFO: C1041_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1041_R3_mad_robustize_reduced-corr.csv
# INFO: C1026_R3_mad_robustize has 384 rows
# INFO: C1026_R3_mad_robustize has 2977 features
# INFO: C1026_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1026_R3_mad_robustize_reduced-corr.csv
# INFO: C1016_R3_mad_robustize has 384 rows
# INFO: C1016_R3_mad_robustize has 2977 features
# INFO: C1016_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1016_R3_mad_robustize_reduced-corr.csv
# INFO: C1034_R3_mad_robustize has 384 rows
# INFO: C1034_R3_mad_robustize has 2977 features
# INFO: C1034_R3_mad_robustize has 624 features after feature reduction
# INFO: Saved C1034_R3_mad_robustize_reduced-corr.csv
# INFO: C1038_R2_mad_robustize has 384 rows
# INFO: C1038_R2_mad_robustize has 2977 features
# INFO: C1038_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1038_R2_mad_robustize_reduced-corr.csv
# INFO: C1018_R2_mad_robustize has 384 rows
# INFO: C1018_R2_mad_robustize has 2977 features
# INFO: C1018_R2_mad_robustize has 624 features after feature reduction
# INFO: Saved C1018_R2_mad_robustize_reduced-corr.csv

# %% [markdown]
# # Feature reduction based on bioactive features

# %%
# Read in reduced feature set
fmp_features_path = feature_dir + "fmp_HepG2_features.txt"

with open(fmp_features_path, 'r') as f:
    fmp_features = f.read().split()

# Read in reduced feature set
imtm_features_path = feature_dir + "imtm_features.txt"

with open(imtm_features_path, 'r') as f:
    imtm_features = f.read().split()

# Read in reduced feature set
medina_features_path = feature_dir + "medina_features.txt"

with open(medina_features_path, 'r') as f:
    medina_features = f.read().split()

# Read in reduced feature set
usc_features_path = feature_dir + "usc_features.txt"

with open(usc_features_path, 'r') as f:
    usc_features = f.read().split()

# %%
dataframes_normalized_reduced_dict = {}

for folder in folders:

    site_specific_path = os.path.join(input_path, folder)

    # loads mad_robustize normalized data
    pattern = "[A-Z][0-9][0-9][0-9][0-9]_R[1-4]_mad_robustize.csv"
    file_list = glob.glob(site_specific_path + os.sep + '*' + os.sep + pattern, recursive=True)

    for file in file_list:
    
        plate_map_name = os.path.splitext(os.path.basename(file))[0]
    
        try:
        
            dataframe = pd.read_csv(file)
            row_count = dataframe.shape[0]
        
            print(f"INFO: {plate_map_name} has {row_count} rows")

            features = CBE.get_feature_vector(dataframe)
            metadata = set(dataframe.columns) - set(features)

            number_features = len(features_list)

            print(f"INFO: {plate_map_name} has {number_features} features")

            if folder == 'FMP':
                reduced_feature_set = set(fmp_features)
            elif folder == 'IMTM':
                reduced_feature_set = set(imtm_features)
            elif folder == 'MEDINA':
                reduced_feature_set = set(medina_features)
            elif folder == 'USC':
                reduced_feature_set = set(usc_features)

            features_to_remove = [item for item in features if item not in reduced_feature_set]
    
            dataframe_reduced_features = dataframe.drop(columns = features_to_remove)

            reduced_features = CBE.get_feature_vector(dataframe_reduced_features)

            number_reduced_features = len(reduced_features)

            print(f"INFO: {plate_map_name} has {number_reduced_features} features after feature reduction")
    
            filename_norm_reduced_data = plate_map_name + "_reduced.csv"
    
            path_norm_reduced_data = os.path.dirname(file)
            file_path_norm_reduced_data = os.path.join(path_norm_reduced_data, filename_norm_reduced_data)
    
            dataframe_reduced_features.to_csv(file_path_norm_reduced_data, index=False)
    
            print(f"INFO: Saved {filename_norm_reduced_data}")

            # TODO: collect them in dictionary for further processing. 
            # TODO: Based on key Date_Source_Plate_replicate
            dict_key = dataframe_reduced_features['Metadata_staining_date'][0].astype(str) + "_" + dataframe_reduced_features['Metadata_source'][0] + "_" + dataframe_reduced_features['Metadata_plate_map_name'][0]

            dataframes_normalized_reduced_dict[dict_key] = dataframe_reduced_features
        
        except Exception as e:
        
            print(f"Error reading file {plate_map_name}: {e}")
